# %% [markdown]
# <a href="https://colab.research.google.com/github/ritaalamino/candc_master/blob/main/CANDC_BERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## *CANDC*

# %% [markdown]
# Funções não suportadas
#
# *   --semantics
# *   --modal
# *   --elimeq não muda nada
# *   --vpe  não muda nada
# *   --robust  não muda nada
# *   --roles  não muda nada

# %% [markdown]
# ##Importa bibliotecas

# %%
# Import das bibliotecas.

# Biblioteca de logging
import logging
import subprocess
import os
import csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Instala as libraries necessárias

# %%
# Diretório do cohebert
DIRETORIO_CANDC = "CANDC"

# Diretório local para os arquivos pré-processados
DIRETORIO_LOCAL = "/content/" + DIRETORIO_CANDC + "/"

# Diretório no google drive com os arquivos pré-processados
DIRETORIO_DRIVE = "/content/drive/MyDrive/Colab Notebooks/Data/" + DIRETORIO_CANDC + "/"

# %%
# !git clone https://github.com/valeriobasile/learningbyreading.git
# Out:
# Cloning into 'learningbyreading'...
# remote: Enumerating objects: 1870, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 1870 (delta 30), reused 58 (delta 22), pack-reused 1797
# Receiving objects: 100% (1870/1870), 295.87 MiB | 14.35 MiB/s, done.
# Resolving deltas: 100% (722/722), done.
# Updating files: 100% (970/970), done.

# %%
os.chdir('./learningbyreading/ext')

# %%
# !./install_candc.sh
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/writer_multi_vert.o src/lib/io/writer_multi_vert.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/writer_format.o src/lib/io/writer_format.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/writer_factory.o src/lib/io/writer_factory.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/tagdict.o src/lib/tagger/tagdict.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/tagsetdict.o src/lib/tagger/tagsetdict.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/_baseimpl.o src/lib/tagger/_baseimpl.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/_baseimpl.cc:18:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/_baseimpl.h:42,
#                  from src/lib/tagger/_baseimpl.cc:18:
# src/include/tagger/lattice.h: In member function ‘void NLP::Taggers::Node::update(const NLP::Taggers::Node*, float)’:
# src/include/tagger/lattice.h:42:27: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    42 |         this->pid = prev->id;
#       |                           ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/_baseimpl.cc:18:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/_baseimpl.cc:18:
# src/include/tagger/_baseimpl.h: In member function ‘void NLP::Taggers::Tagger::Impl::_calc_greedy_probs(NLP::Taggers::State&, ulong, double) const’:
# src/include/tagger/_baseimpl.h:489:21: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   489 |     hist.pid = hist.id;
#       |                     ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/_baseimpl.cc:18:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/_baseimpl.cc:18:
# src/include/tagger/_baseimpl.h:490:15: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   490 |     hist.id = max_tag;
#       |               ^~~~~~~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/_baseimpl.cc:18:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# src/lib/tagger/_baseimpl.cc: In member function ‘void NLP::Taggers::Tagger::Impl::_read_attributes(const NLP::Model::Model&, const NLP::Model::Info&, std::vector<NLP::Model::Feature*>&)’:
# src/lib/tagger/_baseimpl.cc:133:25: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   133 |   }catch(NLP::Exception e){
#       |                         ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/tagger.o src/lib/tagger/tagger.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/tagger.cc:11:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/_baseimpl.h:42,
#                  from src/lib/tagger/tagger.cc:11:
# src/include/tagger/lattice.h: In member function ‘void NLP::Taggers::Node::update(const NLP::Taggers::Node*, float)’:
# src/include/tagger/lattice.h:42:27: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    42 |         this->pid = prev->id;
#       |                           ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/tagger.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/tagger.cc:11:
# src/include/tagger/_baseimpl.h: In member function ‘void NLP::Taggers::Tagger::Impl::_calc_greedy_probs(NLP::Taggers::State&, ulong, double) const’:
# src/include/tagger/_baseimpl.h:489:21: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   489 |     hist.pid = hist.id;
#       |                     ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/tagger.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/tagger.cc:11:
# src/include/tagger/_baseimpl.h:490:15: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   490 |     hist.id = max_tag;
#       |               ^~~~~~~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/tagger.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/taghist.o src/lib/tagger/taghist.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/types.o src/lib/model/types.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/types.cc:24:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/registry.o src/lib/model/registry.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/registry.cc:23:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/affix.o src/lib/model/affix.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/affix.cc:18:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/unigram.o src/lib/model/unigram.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/unigram.cc:21:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/bigram.o src/lib/model/bigram.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/bigram.cc:21:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/trigram.o src/lib/model/trigram.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/trigram.cc:21:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/model.o src/lib/model/model.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/model.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/cache.o src/lib/model/cache.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/gazetteers.o src/lib/gazetteers.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/unigram.o src/lib/tagger/unigram.cc
# src/lib/tagger/unigram.cc: In member function ‘void NLP::Taggers::Unigram::_Impl::load(std::string)’:
# src/lib/tagger/unigram.cc:75:44: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    75 |           add(word)->value = tagset[max_tag];
#       |                                            ^
# In file included from src/include/base.h:48,
#                  from src/lib/tagger/unigram.cc:19:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# src/lib/tagger/unigram.cc:89:40: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    89 |       add(word)->value = tagset[max_tag];
#       |                                        ^
# In file included from src/include/base.h:48,
#                  from src/lib/tagger/unigram.cc:19:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/pos.o src/lib/tagger/pos.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/pos.cc:17:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/_baseimpl.h:42,
#                  from src/lib/tagger/pos.cc:17:
# src/include/tagger/lattice.h: In member function ‘void NLP::Taggers::Node::update(const NLP::Taggers::Node*, float)’:
# src/include/tagger/lattice.h:42:27: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    42 |         this->pid = prev->id;
#       |                           ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/pos.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/pos.cc:17:
# src/include/tagger/_baseimpl.h: In member function ‘void NLP::Taggers::Tagger::Impl::_calc_greedy_probs(NLP::Taggers::State&, ulong, double) const’:
# src/include/tagger/_baseimpl.h:489:21: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   489 |     hist.pid = hist.id;
#       |                     ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/pos.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/pos.cc:17:
# src/include/tagger/_baseimpl.h:490:15: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   490 |     hist.id = max_tag;
#       |               ^~~~~~~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/pos.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/pos.o src/main/pos.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/pos.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/pos.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/cluster_no_mpi.o src/lib/cluster_no_mpi.cc
# g++ -fPIC -o bin/pos src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/pos.o src/main/pos.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/mpos.o src/main/mpos.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/mpos.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/mpos.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/mpos src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/pos.o src/main/mpos.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/chunk.o src/lib/tagger/chunk.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/chunk.cc:11:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/_baseimpl.h:42,
#                  from src/lib/tagger/chunk.cc:11:
# src/include/tagger/lattice.h: In member function ‘void NLP::Taggers::Node::update(const NLP::Taggers::Node*, float)’:
# src/include/tagger/lattice.h:42:27: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    42 |         this->pid = prev->id;
#       |                           ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/chunk.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/chunk.cc:11:
# src/include/tagger/_baseimpl.h: In member function ‘void NLP::Taggers::Tagger::Impl::_calc_greedy_probs(NLP::Taggers::State&, ulong, double) const’:
# src/include/tagger/_baseimpl.h:489:21: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   489 |     hist.pid = hist.id;
#       |                     ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/chunk.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/chunk.cc:11:
# src/include/tagger/_baseimpl.h:490:15: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   490 |     hist.id = max_tag;
#       |               ^~~~~~~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/chunk.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/chunk.o src/main/chunk.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/chunk.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/chunk.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/chunk src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/chunk.o src/main/chunk.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/mchunk.o src/main/mchunk.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/mchunk.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/mchunk.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/mchunk src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/chunk.o src/main/mchunk.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/ner.o src/lib/tagger/ner.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/ner.cc:17:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/_baseimpl.h:42,
#                  from src/lib/tagger/ner.cc:17:
# src/include/tagger/lattice.h: In member function ‘void NLP::Taggers::Node::update(const NLP::Taggers::Node*, float)’:
# src/include/tagger/lattice.h:42:27: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    42 |         this->pid = prev->id;
#       |                           ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/ner.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/ner.cc:17:
# src/include/tagger/_baseimpl.h: In member function ‘void NLP::Taggers::Tagger::Impl::_calc_greedy_probs(NLP::Taggers::State&, ulong, double) const’:
# src/include/tagger/_baseimpl.h:489:21: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   489 |     hist.pid = hist.id;
#       |                     ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/ner.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/ner.cc:17:
# src/include/tagger/_baseimpl.h:490:15: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   490 |     hist.id = max_tag;
#       |               ^~~~~~~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/ner.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# src/lib/tagger/ner.cc: In member function ‘void NLP::Taggers::NER::Impl::add_special(const RawWord&, NLP::PDF&) const’:
# src/lib/tagger/ner.cc:206:17: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   206 |         case 1: if(types.use_one_digit())
#       |                 ^~
# src/lib/tagger/ner.cc:208:19: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   208 |                   break;
#       |                   ^~~~~
# src/lib/tagger/ner.cc:209:17: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   209 |         case 2: if(types.use_two_digits())
#       |                 ^~
# src/lib/tagger/ner.cc:211:19: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   211 |                   break;
#       |                   ^~~~~
# src/lib/tagger/ner.cc:212:17: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   212 |         case 3: if(types.use_three_digits())
#       |                 ^~
# src/lib/tagger/ner.cc:214:19: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   214 |                   break;
#       |                   ^~~~~
# src/lib/tagger/ner.cc:215:17: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   215 |         case 4: if(types.use_four_digits())
#       |                 ^~
# src/lib/tagger/ner.cc:217:19: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   217 |                   break;
#       |                   ^~~~~
# src/lib/tagger/ner.cc:218:18: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   218 |         default: if(types.use_digits())
#       |                  ^~
# src/lib/tagger/ner.cc:220:19: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   220 |                   break;
#       |                   ^~~~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/ner.o src/main/ner.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/ner.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/ner.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/ner src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/ner.o src/main/ner.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/mner.o src/main/mner.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/mner.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/mner.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/mner src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/ner.o src/main/mner.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/super.o src/lib/tagger/super.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/super.cc:11:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/_baseimpl.h:42,
#                  from src/lib/tagger/super.cc:11:
# src/include/tagger/lattice.h: In member function ‘void NLP::Taggers::Node::update(const NLP::Taggers::Node*, float)’:
# src/include/tagger/lattice.h:42:27: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    42 |         this->pid = prev->id;
#       |                           ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/super.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/super.cc:11:
# src/include/tagger/_baseimpl.h: In member function ‘void NLP::Taggers::Tagger::Impl::_calc_greedy_probs(NLP::Taggers::State&, ulong, double) const’:
# src/include/tagger/_baseimpl.h:489:21: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   489 |     hist.pid = hist.id;
#       |                     ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/super.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/super.cc:11:
# src/include/tagger/_baseimpl.h:490:15: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   490 |     hist.id = max_tag;
#       |               ^~~~~~~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/super.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/super.o src/main/super.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/super.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/super.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/super src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/super.o src/main/super.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/msuper.o src/main/msuper.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/msuper.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/msuper.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/msuper src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/super.o src/main/msuper.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/maxent/gis.o src/lib/maxent/gis.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/maxent/gis.cc:30:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/maxent/bfgs.o src/lib/maxent/bfgs.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/maxent/bfgs.cc:22:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/lib/maxent/bfgs.cc:32:
# src/include/maxent/solver.h: In instantiation of ‘void NLP::MaxEnt::Solver<T>::zoom_search(double, double, double, double, double, double, double, double, double) [with Objective = NLP::MaxEnt::BFGS]’:
# src/include/maxent/solver.h:198:20:   required from ‘void NLP::MaxEnt::Solver<T>::line_search() [with Objective = NLP::MaxEnt::BFGS]’
# src/include/maxent/solver.h:310:9:   required from ‘void NLP::MaxEnt::Solver<T>::lbfgs() [with Objective = NLP::MaxEnt::BFGS]’
# src/include/maxent/solver.h:345:9:   required from ‘bool NLP::MaxEnt::Solver<T>::iteration() [with Objective = NLP::MaxEnt::BFGS]’
# src/lib/maxent/bfgs.cc:92:28:   required from here
# src/include/maxent/solver.h:93:48: warning: parameter ‘hi_value’ set but not used [-Wunused-but-set-parameter]
#    93 |                        double lo_value, double hi_value,
#       |                                         ~~~~~~~^~~~~~~~
# src/include/maxent/solver.h:94:50: warning: parameter ‘hi_del_phi’ set but not used [-Wunused-but-set-parameter]
#    94 |                        double lo_del_phi, double hi_del_phi,
#       |                                           ~~~~~~~^~~~~~~~~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/maxent/perceptron.o src/lib/maxent/perceptron.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/maxent/perceptron.cc:29:
# ...
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/reestimate.o src/main/reestimate.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/main/reestimate.cc:18:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/main/reestimate.cc:20:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/reestimate src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/maxent/gis.o src/lib/maxent/bfgs.o src/lib/maxent/perceptron.o src/lib/extract/_baseimpl.o src/lib/extract/attributes.o src/lib/extract/contexts.o src/main/reestimate.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# make: *** No rule to make target 'ext/bin/soapcpp2', needed by 'soap'.  Stop.
# bin/swipl -g "['src/prolog/nutcracker/ntokkie'], qsave_program('bin/t',[goal=start,stand_alone=true]), halt."
# %   library(error) compiled into error 0.00 sec, 81 clauses
# %   library(pairs) compiled into pairs 0.00 sec, 22 clauses
# %  library(lists) compiled into lists 0.01 sec, 206 clauses
# %   library(shlib) compiled into shlib 0.00 sec, 39 clauses
# %   library(option) compiled into swi_option 0.00 sec, 32 clauses
# %  library(readutil) compiled into read_util 0.01 sec, 112 clauses
# %  semlib(abbreviations) compiled into abbreviations 0.00 sec, 46 clauses
# %   semlib(options) compiled into options 0.00 sec, 112 clauses
# %  semlib(errors) compiled into errors 0.01 sec, 123 clauses
# % src/prolog/nutcracker/ntokkie compiled 0.03 sec, 635 clauses
# % autoloading prolog_codewalk:must_be/2 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/error
# % autoloading prolog_debug:backtrace/1 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_stack
# % autoloading oset:reverse/2 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/lists
# % autoloading record:member/2 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/lists
# % autoloading error:assertion/1 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/debug
# % autoloading qsave:current_foreign_library/2 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/shlib
# % autoloading prolog_codewalk:portray_clause/1 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/listing
# % autoloading prolog_codewalk:clause_info/4 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % autoloading prolog_codewalk:initialization_layout/4 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % autoloading prolog_codewalk:clause_name/2 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % Autoloader: iteration 1 resolved 9 predicates and loaded 10 files in 0.087 seconds.  Restarting ...
# % Autoloader: loaded 9 files in 2 iterations in 0.128 seconds
# src/scripts/version unix
# src/scripts/version: line 53: svnversion: command not found
# Usage: grep [OPTION]... PATTERNS [FILE]...
# Try 'grep --help' for more information.
# bin/swipl -g "['src/prolog/boxer/boxer'], qsave_program('bin/boxer',[global=128000,local=128000,goal=start,stand_alone=true]), halt."
# %   library(error) compiled into error 0.00 sec, 81 clauses
# %   library(pairs) compiled into pairs 0.00 sec, 22 clauses
# %  library(lists) compiled into lists 0.01 sec, 206 clauses
# %   boxer(slashes) compiled into slashes 0.00 sec, 5 clauses
# %      semlib(options) compiled into options 0.00 sec, 112 clauses
# %     semlib(errors) compiled into errors 0.01 sec, 123 clauses
# %    boxer(alphaConversionDRT) compiled into alphaConversionDRT 0.01 sec, 166 clauses
# %     boxer(noncomp) compiled into noncomp 0.00 sec, 17 clauses
# %    boxer(mergeDRT) compiled into mergeDRT 0.01 sec, 89 clauses
# %   boxer(betaConversionDRT) compiled into betaConversionDRT 0.02 sec, 293 clauses
# %    boxer(bindingViolation) compiled into bindingViolation 0.00 sec, 33 clauses
# %    boxer(freeVarCheck) compiled into freeVarCheck 0.00 sec, 57 clauses
# %     lex(verbnet) compiled into verbnet 0.63 sec, 30,594 clauses
# %    boxer(categories) compiled into categories 0.63 sec, 30,662 clauses
# %    knowledge(antecedent) compiled into antecedent 0.01 sec, 825 clauses
# %   boxer(resolveDRT) compiled into resolveDRT 0.65 sec, 31,717 clauses
# %    boxer(morpha) compiled into morpha 0.00 sec, 62 clauses
# %   boxer(transform) compiled into transform 0.01 sec, 164 clauses
# %    knowledge(relations) compiled into relations 0.08 sec, 9,437 clauses
# %   boxer(relation) compiled into relation 0.09 sec, 9,460 clauses
# %     boxer(string2digit) compiled into string2digit 0.00 sec, 42 clauses
# %     knowledge(ne) compiled into ne 0.00 sec, 32 clauses
# %     knowledge(dates) compiled into dates 0.00 sec, 155 clauses
# %     knowledge(punctuation) compiled into punctuation 0.00 sec, 13 clauses
# %     lex(determiners) compiled into determiners 0.00 sec, 33 clauses
# %      lex(tense) compiled into tense 0.00 sec, 18 clauses
# %     lex(verbs) compiled into verbs 0.01 sec, 110 clauses
# %     boxer(coordination) compiled into coordination 0.00 sec, 11 clauses
# %     (lex/pp) compiled into lexicon 0.00 sec, 27 clauses
# %     (lex/n) compiled into lexicon 0.01 sec, 93 clauses
# %    boxer(lexicon) compiled into lexicon 0.05 sec, 844 clauses
# %   boxer(closure) compiled into closure 0.06 sec, 881 clauses
# %   boxer(typechange) compiled into typechange 0.00 sec, 26 clauses
# %   boxer(evaluation) compiled into evaluation 0.00 sec, 6 clauses
# %   boxer(input) compiled into input 0.00 sec, 23 clauses
# %   boxer(sdrt) compiled into sdrt 0.00 sec, 27 clauses
# %   boxer(drs2fdrs) compiled into drs2fdrs 0.00 sec, 76 clauses
# %    semlib(drs2tacitus) compiled into drs2tacitus 0.00 sec, 104 clauses
# %   boxer(tuples) compiled into tuples 0.01 sec, 235 clauses
# %    knowledge(amrmfs) compiled into amrmfs 0.00 sec, 244 clauses
# %    knowledge(verbalization-list-v1.01) compiled into verbalization 0.00 sec, 475 clauses
# %    knowledge(role91) compiled into role91 0.00 sec, 121 clauses
# %    knowledge(negprefix) compiled into negprefix 0.02 sec, 1,597 clauses
# %    knowledge(negsuffix) compiled into negsuffix 0.01 sec, 472 clauses
# %    knowledge(nationality) compiled into nationality 0.01 sec, 305 clauses
# %    knowledge(wiki) compiled into wiki 0.04 sec, 3,158 clauses
# %   semlib(drs2amr) compiled into drs2amr 0.09 sec, 6,840 clauses
# %   semlib(pdrs2drs) compiled into pdrs2drs 0.00 sec, 35 clauses
# %   semlib(drs2fol) compiled into drs2fol 0.01 sec, 126 clauses
# %  boxer(ccg2drs) compiled into ccg2drs 0.95 sec, 50,070 clauses
# %  boxer(version) compiled into version 0.00 sec, 2 clauses
# %  boxer(printCCG) compiled into printCCG 0.00 sec, 53 clauses
# %   boxer(xdrs2xml) compiled into xdrs2xml 0.01 sec, 127 clauses
# %   boxer(printDrs) compiled into printDrs 0.00 sec, 106 clauses
# %   semlib(drs2tex) compiled into drs2tex 0.00 sec, 32 clauses
# %  boxer(output) compiled into output 0.02 sec, 338 clauses
# % src/prolog/boxer/boxer compiled 0.98 sec, 50,723 clauses
# % autoloading prolog_codewalk:(must_be/2) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/error
# % autoloading prolog_debug:(backtrace/1) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_stack
# % autoloading oset:(reverse/2) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/lists
# % autoloading record:(member/2) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/lists
# % autoloading error:(assertion/1) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/debug
# % autoloading qsave:(current_foreign_library/2) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/shlib
# % autoloading prolog_codewalk:(portray_clause/1) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/listing
# % autoloading prolog_codewalk:(clause_info/4) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % autoloading prolog_codewalk:(initialization_layout/4) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % autoloading prolog_codewalk:(clause_name/2) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % Autoloader: iteration 1 resolved 10 predicates and loaded 10 files in 0.102 seconds.  Restarting ...
# % Autoloader: loaded 10 files in 2 iterations in 0.180 seconds
# models/
# models/config
# models/pos
# models/super
# models/parser/
# models/parser/log
# models/parser/cats/
# models/parser/cats/markedup
# models/parser/cats/trAP
# models/parser/cats/trNP
# models/parser/cats/trPP
# models/parser/cats/trPP_qus
# models/parser/cats/trVP_to
# models/parser/features
# models/parser/lexicon
# models/parser/rules
# models/parser/model.config
# models/parser/info
# models/parser/weights
# models/parser/stats
# models/parser/config
# models/pos_quotes/
# models/pos_quotes/log
# models/pos_quotes/classes
# models/pos_quotes/lexicon
# models/pos_quotes/tagdict
# models/pos_quotes/attributes
# models/pos_quotes/unknowns
# models/pos_quotes/number_unknowns
# models/pos_quotes/info
# models/pos_quotes/config
# models/pos_quotes/weights
# models/super_quotes/
# models/super_quotes/log
# models/super_quotes/classes
# models/super_quotes/lexicon
# models/super_quotes/tagdict
# models/super_quotes/postags
# models/super_quotes/posdict
# models/super_quotes/attributes
# models/super_quotes/unknowns
# models/super_quotes/info
# models/super_quotes/config
# models/super_quotes/weights
# models/muc/
# models/muc/gazetteer/
# models/muc/gazetteer/common
# models/muc/gazetteer/firstnames
# models/muc/gazetteer/lastnames
# models/muc/gazetteers
# models/muc/classes
# models/muc/lexicon
# models/muc/tagdict
# models/muc/postags
# models/muc/chunktags
# models/muc/attributes
# models/muc/unknowns
# models/muc/info
# models/muc/config
# models/muc/weights
# models/chunk_quotes/
# models/chunk_quotes/classes
# models/chunk_quotes/lexicon
# models/chunk_quotes/tagdict
# models/chunk_quotes/postags
# models/chunk_quotes/attributes
# models/chunk_quotes/unknowns
# models/chunk_quotes/info
# models/chunk_quotes/config
# models/chunk_quotes/weights
# models/pos_questions/
# models/pos_questions/log
# models/pos_questions/classes
# models/pos_questions/lexicon
# models/pos_questions/tagdict
# models/pos_questions/attributes
# models/pos_questions/unknowns
# models/pos_questions/number_unknowns
# models/pos_questions/info
# models/pos_questions/config
# models/pos_questions/weights
# models/super_questions/
# models/super_questions/log
# models/super_questions/classes
# models/super_questions/lexicon
# models/super_questions/tagdict
# models/super_questions/postags
# models/super_questions/posdict
# models/super_questions/attributes
# models/super_questions/unknowns
# models/super_questions/info
# models/super_questions/config
# models/super_questions/weights
# models/questions/
# models/questions/parser
# models/questions/ner
# models/questions/pos
# models/questions/super
# models/questions/chunk
# models/questions/verbstem.list
# models/questions/config
# models/noquotes/
# models/noquotes/pos
# models/noquotes/super
# models/noquotes/parser
# models/noquotes/muc
# models/noquotes/chunk
# models/noquotes/config
# models/noquotes/verbstem.list
# models/pos_noquotes/
# models/pos_noquotes/log
# models/pos_noquotes/classes
# models/pos_noquotes/lexicon
# models/pos_noquotes/tagdict
# models/pos_noquotes/attributes
# models/pos_noquotes/unknowns
# models/pos_noquotes/number_unknowns
# models/pos_noquotes/info
# models/pos_noquotes/config
# models/pos_noquotes/weights
# models/super_noquotes/
# models/super_noquotes/log
# models/super_noquotes/classes
# models/super_noquotes/lexicon
# models/super_noquotes/tagdict
# models/super_noquotes/postags
# models/super_noquotes/posdict
# models/super_noquotes/attributes
# models/super_noquotes/unknowns
# models/super_noquotes/info
# models/super_noquotes/config
# models/super_noquotes/weights
# models/ner
# models/chunk
# models/verbstem.list
# models/boxer/
# models/boxer/config
# models/boxer/super
# models/boxer/parser
# models/boxer/pos
# models/boxer/ner
# models/boxer/chunk
# models/boxer/verbstem.list

# %%
# # Gera boxer em xml
# command = "./install_candc.sh"
# subprocess.run(command, shell=True, check=True, capture_output=True)

# %%
# Import das bibliotecas.
import sys # Biblioteca para acessar módulos do sistema

# Se estiver executando no Google Colaboratory
# Retorna true ou false se estiver no Google Colaboratory
IN_COLAB = "google.colab" in sys.modules

# %%
# Importando as bibliotecas.
import os

# Cria o diretório para receber os arquivos Originais e Permutados
# Diretório a ser criado
dirbase = DIRETORIO_LOCAL[:-1]

if not os.path.exists(dirbase):
    # Cria o diretório
    os.makedirs(dirbase)
    logging.info("Diretório criado: {}".format(dirbase))
else:
    logging.info("Diretório já existe: {}".format(dirbase))

# %% [markdown]
# ## Verifica se arquivos estão corretos

# %%
os.chdir('/content/learningbyreading/ext/candc')
# !ls
# Out:
# bin	    lib		       Makefile.cygwin	 Makefile.mingw    models	     RELEASE.txt
# doc	    LICENCE-BOXER.txt  Makefile.deps	 Makefile.sunos    models-1.02.tbz2  share
# ext	    LICENCE.txt        Makefile.macosx	 Makefile.targets  pl-6.6.6	     src
# grepsource  Makefile	       Makefile.macosxu  Makefile.unix	   pl-6.6.6.tar.gz   working

# %%
#!chmod +x bin/candc
# !bin/candc --version
# !bin/boxer --version
# Out:
# candc v1.00 (unix build on 12 February 2024, 22:42:33)
# boxer v1.00 (unix build on 12 February 2024, 22:46:41)

# %% [markdown]
# Roda teste

# %% [markdown]
# #Importa word2vec

# %%
import re
import numpy as np

# %%
from nltk.corpus import wordnet as wn
from scipy.spatial.distance import cosine
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# #Carrega word2vec

# %%
# from gensim.models import KeyedVectors
# import gensim.downloader as api

# # Carregar o modelo Word2Vec
# word2vec_model = api.load('glove-wiki-gigaword-300')

# %%
# word2vec_model.init_sims(replace=True)

# %% [markdown]
# #Carrega bert

# %%
from transformers import BertTokenizer, BertModel
import torch

# Inicializa o tokenizer e o modelo
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased',
                                          do_lower_case=False)
model = BertModel.from_pretrained('bert-base-multilingual-cased',
                                  output_attentions=False,
                                  output_hidden_states=True)

# Função para obter embeddings do BERT
def get_bert_embeddings(text):
    # Tokeniza a entrada e converte para tensor
    inputs = tokenizer(text, return_tensors="pt")

    # Obtém os embeddings
    with torch.no_grad():
        outputs = model(**inputs)

    # Retorna os embeddings da última camada
    return outputs.last_hidden_state
# Out:
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]

# %%
# from transformers import BertTokenizer, BertModel
# import torch

# # Initialize the tokenizer and the model
# tokenizer = BertTokenizer.from_pretrained('bert-large-cased')
# model = BertModel.from_pretrained('bert-large-cased')

# # Set the model to evaluation mode
# model.eval()

# # Function to obtain BERT embeddings
# def get_bert_embeddings(text_list):
#     # Ensure text_list is not empty
#     if not text_list:
#         return None

#     # Tokenize the input batch and convert to tensors
#     inputs = tokenizer(text_list, return_tensors="pt", padding=True, truncation=True)

#     # Obtain the embeddings
#     with torch.no_grad():
#         outputs = model(**inputs)

#     # Return the embeddings from the last layer
#     return outputs.last_hidden_state

# # Example usage
# text_list = ["This is an example sentence.", "Another sentence for illustration."]
# embeddings = get_bert_embeddings(text_list)
# print(embeddings.shape)  # Print the shape of the embeddings tensor
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# torch.Size([2, 8, 1024])

# %%
# Exemplo de uso
embeddings = get_bert_embeddings("Hello, world!")
print(embeddings)
# Out:
# tensor([[[-0.4218, -0.2564,  0.1639,  ..., -0.2528,  0.2395,  0.0357],
#          [-0.6650, -0.1311,  0.6369,  ..., -0.5864,  0.1911, -0.4358],
#          [-0.5932, -0.1694,  0.0448,  ..., -0.6263,  0.3855, -0.0178],
#          [-0.9403, -0.0142,  0.4910,  ..., -1.0551,  0.5379, -0.7017],
#          [-0.5232, -0.2376,  0.0461,  ..., -0.4888,  0.2440, -0.0680],
#          [-0.4428, -0.2193,  0.4927,  ..., -0.6848,  0.2164, -0.0179]]])

# %% [markdown]
# # Importa Paragram300

# %%
# from gensim.models import KeyedVectors

# # Path to the downloaded model files
# model_path = DIRETORIO_DRIVE + 'paragram-300-sl999.model'

# # # Carregar o modelo Word2Vec
# word2vec_model = KeyedVectors.load(model_path)

# %%
# word2vec_model.init_sims(replace=True)

# %% [markdown]
# #Define função do grafo

# %%
class Graph:
    def __init__(self, sentence: str, debug: bool = False):
        self.words = sentence.split(" ")
        self.count = len([word for word in self.words if len(word) > 0])
        self.gLen = self.count
        self.nodes = [None] * (self.count * 2)  # Armazenamento para conceitos
        self.edges = [None] * (self.count * 2)  # Armazenamento para arestas
        self.conceptCount = 0  # Contador para conceitos
        self.edgeCount = 0  # Contador para arestas
        self.repeated = 0
        self.autoInc = 0  # Variável para auto-incremento
        self.debug = debug  # Variável para debug

        if debug:
            print(sentence)

    def get_vector(self, word):
        return word2vec_model[word] if word in word2vec_model else np.zeros(word2vec_model.vector_size)

    def get_vector_bert(self, dic, word):
      # Sua lógica para obter o vetor BERT
      return dic[word] if word in dic else np.zeros(len(next(iter(dic.values()))))

    def getCode(self):
        # Implementação do método getCode
        code = f"ma{self.autoInc}"
        self.autoInc += 1
        return code

    def addConcept(self, name: str, code: str, pos: str):
        # Verifica se o conceito já existe e adiciona uma nova instância se necessário
        for i in range(self.conceptCount):
            if self.nodes[i]['code'] == code:
                nCode = self.getCode()
                self.addConcept(name, nCode, pos)
                rName = self.getCode()
                self.addRelationIn("equality", rName, code)
                self.addRelationEx("equality", rName, nCode)
                return

        # Expandir a lista se necessário
        if self.conceptCount >= len(self.nodes):
            self.nodes.append(None)

        # Adicionar o novo conceito
        self.nodes[self.conceptCount] = {'lemma': name, 'code': code, 'pos': pos}
        self.conceptCount += 1

    def addRelationIn(self, name: str, code: str, in_relation: str):
        found = False
        for i in range(self.edgeCount):
            if self.edges[i]['code'] == code:
                found = True
                self.edges[i]['in'] = in_relation
                break
        if not found:
            if self.edgeCount >= len(self.edges):
                self.edges.append(None)  # Expande a lista
            self.edges[self.edgeCount] = {'code': code, 'name': name, 'in': in_relation}
            self.edgeCount += 1

    def addRelationEx(self, name: str, code: str, ex: str):
        found = False
        for i in range(self.edgeCount):
            if self.edges[i]['code'] == code:
                found = True
                self.edges[i]['ex'] = ex
                break
        if not found:
            if self.edgeCount >= len(self.edges):
                self.edges.append(None)  # Expande a lista
            self.edges[self.edgeCount] = {'code': code, 'name': name, 'ex': ex}
            self.edgeCount += 1

    def addIsRelation(self, name: str, code: str):
        found = False
        for i in range(self.edgeCount):
            if self.edges[i]['code'] == code:
                self.edges[i]['name'] = name
                return
        self.edges[self.edgeCount] = {'code': code, 'name': name}
        self.edgeCount += 1

    def getWeight(self, relation: str) -> int:
        if relation == "equality":
            return 1
        elif relation == "is":
            return 4
        elif relation == "rep":
            return 1
        elif relation == "for":
            return 1
        elif relation == "on":
            return 1
        elif relation == "of":
            return 1
        elif relation == "in":
            return 3
        elif relation == "experiencer":
            return 6
        elif relation == "agent":
            return 8
        elif relation == "theme":
            return 8
        else:
            return 1

    def printNodes(self):
        for i in range(self.conceptCount):
            node = self.nodes[i]
            print(f"{node['code']}   {node['lemma']}   {node['pos']}")

    def printEdges(self):
        for i in range(self.edgeCount):
            edge = self.edges[i]
            print(f"{edge['name']}\t{edge.get('in', '')}\t{edge.get('ex', '')}")

    def getNode(self, code: str):
        for i in range(self.conceptCount):
            if self.nodes[i] and self.nodes[i]['code'] == code:
                return self.nodes[i]

        for i in range(self.edgeCount):
            edge = self.edges[i]
            if edge:
                if 'name' in edge and edge['name'] == "equality":
                    if 'ex' in edge and edge['ex'] == code:
                        in_code = edge.get('in')  # Use .get() to avoid KeyError
                        if in_code:
                            return self.getNode(in_code)
        return None  # Return None or a default value if no node is found

    def finalize(self):
        for i in range(self.edgeCount):
            if self.edges[i]['name'] == "is":
                for j in range(self.edgeCount):
                    if self.edges[i]['code'] == self.edges[j]['code']:
                        self.edges[i]['ex'] = self.edges[j]['ex']
                        self.edges[i]['in'] = self.edges[j]['in']
                        print("found")
                        break

    def checkGraph(self) -> bool:
            if self.debug:
                for i in range(self.conceptCount):
                    node = self.nodes[i]
                    if node:
                        print(f"{node['code']}   {node['lemma']}")

            for i in range(self.edgeCount):
                print(i)
                edge = self.edges[i]
                print(edge)
                if edge:
                    in_node_obj = self.getNode(edge.get('in'))
                    ex_node_obj = self.getNode(edge.get('ex'))

                    in_node = in_node_obj['lemma'] if in_node_obj is not None else None
                    ex_node = ex_node_obj['lemma'] if ex_node_obj is not None else None

                    print(f"{in_node}  {edge['name']}   {ex_node}")

                    if edge['name'] == "equality" and in_node == ex_node:
                        self.repeated += 1

                    for j in range(self.edgeCount):
                        other_edge = self.edges[j]
                        if other_edge and edge['name'] == other_edge['name']:
                            in_node_other_obj = self.getNode(other_edge.get('in'))
                            ex_node_other_obj = self.getNode(other_edge.get('ex'))
                            in_node_other = in_node_other_obj['lemma'] if in_node_other_obj is not None else None
                            ex_node_other = ex_node_other_obj['lemma'] if ex_node_other_obj is not None else None

                            if in_node == in_node_other and ex_node == ex_node_other:
                                other_edge['name'] = "rep"
                                self.repeated += 1

            return True if self.repeated > 0 else False

    def matchRelationNameSTS(self, r1, r2):
        print(f"{r1}    {r2}")
        if r1 == "rep" or r2 == "rep":
            return 0.5
        if r1 == "topic" or r2 == "topic":
            return 0.3
        if r1 == "is" and r2 == "is":
            return 0.7
        if r1 == "equality" and r2 == "equality":
            return 0.7
        if r1 == "rep":
            return 0.0
        if r1 == r2:
            return 1
        if (r1 == "experiencer" and r2 == "of") or (r1 == "of" and r2 == "experiencer"):
            return 0.8
        if (r1 == "theme" and r2 == "agent") or (r1 == "agent" and r2 == "theme"):
            return 0.6
        else:
            return 0.79 - 0.01 * (self.getWeight(r1) + self.getWeight(r2))

    # Convertendo a função matchRelationName para Python
    def matchRelationName(self, r1: str, r2: str) -> float:
        if r1 == "is" and r2 == "is":
            return 0.7
        if r1 == "equality" and r2 == "equality":
            return 0.7
        if r1 == "rep":
            return 0.0
        if r1 == r2:
            return 1.0
        else:
            return 0.73


    # Corrigindo a função stringSim uma última vez
    def stringSim(self, s1: str, s2: str) -> float:
        m, n = len(s1), len(s2)

        if m == 0 and n == 0: return 1.0
        if m == 0 or n == 0: return 0.0

        costs = [0] * (n + 1)

        # Initialize the array
        for k in range(n + 1):
            costs[k] = k

        for i, c1 in enumerate(s1):
            costs[0] = i + 1
            corner = i

            for j, c2 in enumerate(s2):
                upper = costs[j + 1]
                if c1 == c2:
                    costs[j + 1] = corner
                else:
                    t = min(upper, corner)
                    costs[j + 1] = min(costs[j], t) + 1
                corner = upper

        result = costs[n]
        return 1 - float(result) / max(m, n)

    def expand(self, word):
      ewords = [word]
      for edge in self.edges:
          if edge and edge['name'] in ["equality", "is", "of"]:
              node_ex = self.getNode(edge['ex'])
              node_in = self.getNode(edge['in'])

              if node_ex and node_ex['lemma'] == word:
                  ewords.append(node_in['lemma']) if node_in else None
              elif node_in and node_in['lemma'] == word:
                  ewords.append(node_ex['lemma']) if node_ex else None

      return ewords

# %% [markdown]
# #GraphSTSBert

# %%
class GraphSTSBert(Graph):
    def __init__(self, sentence: str, debug: bool = False):
        super().__init__(sentence, debug)

    def matchConceptBert(self, dic1, dic2, c1, c2):
        vec1 = self.get_vector_bert(dic1, c1)
        vec2 = self.get_vector_bert(dic2, c2)
        # Similaridade do cosseno
        return 1 - cosine(vec1, vec2) if np.any(vec1) and np.any(vec2) else 0

    def matchConceptWithExpansionBert(self, dic1, dic2, g1, c1, g2, c2):
        all1 = g1.expand(c1)
        all2 = g2.expand(c2)
        print("expansions:", all1, all2)
        max_similarity = 0

        for word1 in all1:
            for word2 in all2:
                similarity = self.matchConceptBert(dic1, dic2, word1, word2)
                if similarity > max_similarity:
                    max_similarity = similarity

        return max_similarity

    def matchRelationBert(self, dic1, dic2, g1, r1, g2, r2):
        node_g1_in = g1.getNode(r1['in'])
        node_g1_ex = g1.getNode(r1['ex'])
        node_g2_in = g2.getNode(r2['in'])
        node_g2_ex = g2.getNode(r2['ex'])

        # Verifica se algum dos nós é None e retorna 0 em tal caso
        if not all([node_g1_in, node_g1_ex, node_g2_in, node_g2_ex]):
            return 0

        node_in_g1 = node_g1_in['lemma']
        node_ex_g1 = node_g1_ex['lemma']
        node_in_g2 = node_g2_in['lemma']
        node_ex_g2 = node_g2_ex['lemma']

        # d1 = self.matchConceptWithExpansionBert(dic1, dic2, g1, node_in_g1, g2, node_in_g2)
        # d2 = self.matchConceptWithExpansionBert(dic2, dic2, g1, node_ex_g1, g2, node_ex_g2)
        d1 = self.matchConceptBert(dic1, dic2, node_in_g1, node_in_g2)
        d2 = self.matchConceptBert(dic1, dic2, node_ex_g1, node_ex_g2)
        d3 = self.matchRelationNameSTS(r1['name'], r2['name'])

        return ((d2 + d1) / 2.0) * d3

    def matchGraphBert(self, dic1, dic2, g):
        matrix = np.zeros((self.edgeCount, g.edgeCount))

        for i in range(self.edgeCount):
            for j in range(g.edgeCount):
                similarity = self.matchRelationBert(dic1, dic2, self, self.edges[i], g, g.edges[j])
                matrix[i, j] = similarity

        sum_d1, sum_d2, weight_sum_d1, weight_sum_d2 = 0, 0, 0, 0
        nan_count_d1, nan_count_d2 = 0, 0

        for i in range(self.edgeCount):
            max_val = np.max(matrix[i, :])
            if max_val == 0:
                nan_count_d1 += 1
            else:
                rel = g.edges[np.argmax(matrix[i, :])]['name']
                weight = self.getWeight(rel)
                sum_d1 += max_val * weight
                weight_sum_d1 += weight

        for j in range(g.edgeCount):
            max_val = np.max(matrix[:, j])
            if max_val == 0:
                nan_count_d2 += 1
            else:
                rel = self.edges[np.argmax(matrix[:, j])]['name']
                weight = self.getWeight(rel)
                sum_d2 += max_val * weight
                weight_sum_d2 += weight

        d1 = sum_d1 / weight_sum_d1 if weight_sum_d1 > 0 else 0
        d2 = sum_d2 / weight_sum_d2 if weight_sum_d2 > 0 else 0

        g1.printRelationMatrix(matrix, g1, g2, export_csv=True, filename="relation_matrix.csv")

        return (d1 + d2) / 2 if self.edgeCount - nan_count_d1 > 0 and g.edgeCount - nan_count_d2 > 0 else 0


    def getNodeLemma(self, code):
        node = self.getNode(code)
        return node['lemma'] if node else 'N/A'

    def printRelationMatrix(self, matrix, g1, g2, export_csv=False, filename="relation_matrix.csv"):
        print("Matriz de Relações:")
        header = [""] + [f"{g2.edges[j]['name']} ({self.getNodeLemma(g2.edges[j]['in'])} - {self.getNodeLemma(g2.edges[j]['ex'])})" for j in range(g2.edgeCount)]
        print("     ".join(header))

        rows = []
        for i in range(self.edgeCount):
            row = [f"{g1.edges[i]['name']} ({self.getNodeLemma(g1.edges[i]['in'])} - {self.getNodeLemma(g1.edges[i]['ex'])})"]
            for j in range(g2.edgeCount):
                cell_value = f"{matrix[i, j]:.4f} ({self.getNodeLemma(g1.edges[i]['in'])} - {self.getNodeLemma(g1.edges[i]['ex'])}, {self.getNodeLemma(g2.edges[j]['in'])} - {self.getNodeLemma(g2.edges[j]['ex'])})"
                row.append(cell_value)
            rows.append(row)

        # Imprimir a matriz de relações
        for row in rows:
            print("     ".join(row))

        # Exportar para CSV se necessário
        if export_csv:
            with open(filename, 'w', newline='') as csvfile:
                csvwriter = csv.writer(csvfile)
                csvwriter.writerow(header)
                csvwriter.writerows(rows)
            print(f"Matriz exportada para {filename}")


    def calculateGraph(self):
        matrix = np.zeros((self.edgeCount, g.edgeCount))
        for j in range(self.edgeCount):
            max_val = np.max(matrix[:, j])
            if max_val == 0:
                nan_count_d2 += 1
            else:
                rel = self.edges[np.argmax(matrix[:, j])]['name']
                weight = self.getWeight(rel)
                sum_d2 += max_val * weight
                weight_sum_d2 += weight

# %% [markdown]
# #Define função similaridade dos grafos

# %%
class GraphSTS(Graph):
    def __init__(self, sentence: str, debug: bool = False):
        super().__init__(sentence, debug)

    def matchConcept(self, c1, c2):
        vec1 = self.get_vector(c1)
        vec2 = self.get_vector(c2)
        # Similaridade do cosseno
        return 1 - cosine(vec1, vec2) if np.any(vec1) and np.any(vec2) else 0

    def matchConceptWithExpansion(self, g1, c1, g2, c2):
        all1 = g1.expand(c1)
        all2 = g2.expand(c2)
        print("expansions:", all1, all2)
        max_similarity = 0

        for word1 in all1:
            for word2 in all2:
                similarity = self.matchConcept(word1, word2)
                if similarity > max_similarity:
                    max_similarity = similarity

        return max_similarity

    def matchRelation(self, g1, r1, g2, r2):
        node_g1_in = g1.getNode(r1['in'])
        node_g1_ex = g1.getNode(r1['ex'])
        node_g2_in = g2.getNode(r2['in'])
        node_g2_ex = g2.getNode(r2['ex'])

        # Verifica se algum dos nós é None e retorna 0 em tal caso
        if not all([node_g1_in, node_g1_ex, node_g2_in, node_g2_ex]):
            return 0

        node_in_g1 = node_g1_in['lemma']
        node_ex_g1 = node_g1_ex['lemma']
        node_in_g2 = node_g2_in['lemma']
        node_ex_g2 = node_g2_ex['lemma']

        # d1 = self.matchConceptWithExpansion(g1, node_in_g1, g2, node_in_g2)
        # d2 = self.matchConceptWithExpansion(g1, node_ex_g1, g2, node_ex_g2)
        d1 = self.matchConcept(node_in_g1, node_in_g2)
        d2 = self.matchConcept(node_ex_g1, node_ex_g2)
        d3 = self.matchRelationNameSTS(r1['name'], r2['name'])

        return ((d2 + d1) / 2.0) * d3

    def calculateGraph(self):
        matrix = np.zeros((self.edgeCount, g.edgeCount))
        for j in range(self.edgeCount):
            max_val = np.max(matrix[:, j])
            if max_val == 0:
                nan_count_d2 += 1
            else:
                rel = self.edges[np.argmax(matrix[:, j])]['name']
                weight = self.getWeight(rel)
                sum_d2 += max_val * weight
                weight_sum_d2 += weight

    def printRelationMatrix(self, matrix, g, export_csv=False, filename="relation_matrix.csv"):
        print("Matriz de Relações:")
        print("     ", end="")
        header = [""] + [g.edges[j]['name'] for j in range(g.edgeCount)]
        print("     ".join(header))

        rows = []
        for i in range(self.edgeCount):
            row = [self.edges[i]['name']]
            print(f"{self.edges[i]['name']:>12}", end="     ")
            for j in range(g.edgeCount):
                print(f"{matrix[i, j]:>12.4f}", end="     ")
                row.append(matrix[i, j])
            rows.append(row)
            print()

        if export_csv:
            with open(filename, 'w', newline='') as csvfile:
                csvwriter = csv.writer(csvfile)
                csvwriter.writerow(header)
                csvwriter.writerows(rows)
            print(f"Matriz exportada para {filename}")

    def matchGraph(self, g):
        matrix = np.zeros((self.edgeCount, g.edgeCount))

        for i in range(self.edgeCount):
            for j in range(g.edgeCount):
                similarity = self.matchRelation(self, self.edges[i], g, g.edges[j])
                matrix[i, j] = similarity

        sum_d1, sum_d2, weight_sum_d1, weight_sum_d2 = 0, 0, 0, 0
        nan_count_d1, nan_count_d2 = 0, 0

        for i in range(self.edgeCount):
            max_val = np.max(matrix[i, :])
            if max_val == 0:
                nan_count_d1 += 1
            else:
                rel = g.edges[np.argmax(matrix[i, :])]['name']
                weight = self.getWeight(rel)
                sum_d1 += max_val * weight
                weight_sum_d1 += weight

        for j in range(g.edgeCount):
            max_val = np.max(matrix[:, j])
            if max_val == 0:
                nan_count_d2 += 1
            else:
                rel = self.edges[np.argmax(matrix[:, j])]['name']
                weight = self.getWeight(rel)
                sum_d2 += max_val * weight
                weight_sum_d2 += weight

        d1 = sum_d1 / weight_sum_d1 if weight_sum_d1 > 0 else 0
        d2 = sum_d2 / weight_sum_d2 if weight_sum_d2 > 0 else 0

        self.printRelationMatrix(matrix, g)

        return (d1 + d2) / 2 if self.edgeCount - nan_count_d1 > 0 and g.edgeCount - nan_count_d2 > 0 else 0

# %%
# # Exemplo de uso
# graph = GraphSTS("A cock is an adult male chicken")
# idf_value = graph.get_idf("is")
# print(f"Valor IDF para 'cock': {idf_value}")

# %% [markdown]
# #Gera os grafos a partir da classe

# %%
def generate_graphs(fres):
    # Regular expressions
    conceptReg = re.compile(r"c\d+:(.+?):.+instance (.+?) ")
    argReg = re.compile(r"c\d+:(.+?):.+arg (.+?) ")
    inRelReg = re.compile(r"(.*?):(.*?):.* int (.*?) ")
    exRelReg = re.compile(r"(.*?):(.*?):.* ext (.*?) ")
    inEqRelReg = re.compile(r"(.*?):equality int (.*?) ")
    exEqRelReg = re.compile(r"(.*?):equality ext (.*?) ")
    isReg = re.compile(r".* (.*?):equality \d+ . is ")
    refReg = re.compile(r".+referent (.+?) .* (.+?) ")

    for i in range(3):
      sentence = fres.readline()

    sentence = sentence.replace("%%% ", "")
    g1 = GraphSTSBert(sentence, True)
    # g1 = GraphSTS(sentence, True)

    # print(g1.words)
    for line in fres:
        # Initialize your GraphSTS object here (Placeholder)
        if line and line[0] == '%':
            continue
        else:
            match = conceptReg.search(line)
        if match:
            g1.addConcept(match.group(1), match.group(2), "")
            pass
        elif (match := argReg.search(line)):
            g1.addConcept(match.group(1), match.group(2), "jj")
            pass
        elif (match := inRelReg.search(line)):
            g1.addRelationIn(match.group(2), match.group(1), match.group(3))
            pass
        elif (match := exRelReg.search(line)):
            g1.addRelationEx(match.group(2), match.group(1), match.group(3))
            pass
        elif (match := inEqRelReg.search(line)):
            g1.addRelationIn("equality", match.group(1), match.group(2))
            pass
        elif (match := exEqRelReg.search(line)):
            g1.addRelationEx("equality", match.group(1), match.group(2))
            pass
        elif (match := isReg.search(line)):
            g1.addIsRelation("is", match.group(1))
            pass
        elif (match := refReg.search(line)):
            temp = match.group(2)
            if len(temp) > 3:
                g1.addConcept(match.group(2), match.group(1), "ref")
                pass

    return g1

# %% [markdown]
# # Processa usando BERT

# %%
# Função para obter embeddings de uma sentença
def get_sentence_embeddings(sentence):
  # Tokeniza a sentença
  inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=512)

  # Obtém os embeddings
  with torch.no_grad():
      outputs = model(**inputs)

  # Mapeia tokens para palavras
  token_embeddings = outputs.last_hidden_state.squeeze().numpy()
  tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"][0])

  # Cria um dicionário para mapear palavras aos seus embeddings
  word_embeddings = {}
  current_word = ""
  word_embedding = None

  for i, token in enumerate(tokens):
      # Se é o primeiro subtoken de uma nova palavra
      if token.startswith("##"):
          token = token[2:]  # Remove o prefixo '##'
          current_word += token
          word_embedding += token_embeddings[i]
      else:
          if current_word:
              # Adiciona a palavra anterior ao dicionário
              word_embeddings[current_word] = word_embedding / len(current_word.split("##"))
          current_word = token
          word_embedding = token_embeddings[i]

  # Adiciona a última palavra
  if current_word:
      word_embeddings[current_word] = word_embedding / len(current_word.split("##"))

  return word_embeddings

# %% [markdown]
# #Importa dataset

# %%
# Nome do arquivo
NOME_ARQUIVO_ORIGINAL_COMPACTADO = "dataset.csv"

# %%
# Se estiver executando no Google Colaboratory
if IN_COLAB:

  # !cp "$DIRETORIO_DRIVE$NOME_ARQUIVO_ORIGINAL_COMPACTADO" "$DIRETORIO_LOCAL"

  logging.info("Terminei a cópia.")

# %% [markdown]
# #Processa dataset

# %%
import pandas as pd
import os
import subprocess

# Função para processar sentenças e gerar os grafos
def process_sentence(sentence, file_name):
    # Grava a sentença em um arquivo temporário
    with open(file_name, 'w') as file:
        file.write(sentence)

    # Chama o CandC e o Boxer
    subprocess.run(f'echo "{sentence}" | bin/candc --models models/boxer --candc-printer boxer --output /content/CANDC/{file_name}_candc', shell=True)
    subprocess.run(f'bin/boxer --input /content/CANDC/{file_name}_candc --output /content/CANDC/{file_name}_drg --semantics drg', shell=True)

# %%
# Lê o arquivo CSV
df = pd.read_csv('/content/CANDC/dataset.csv')
# df = df[58:59]
df
# Out:
#             Sentence_Pair                                         Sentence_1  \
# 0            1.cord:smile                      Cord is strong, thick string.
# 1        2.rooster:voyage                A rooster is an adult male chicken.
# 2           3.noon:string       Noon is 12 o'clock in the middle of the day.
# 3         4.fruit:furnace  Fruit or a fruit is something which grows on a...
# 4       5.autograph:shore  An autograph is the signature of someone famou...
# ..                    ...                                                ...
# 60      61.cushion:pillow  A cushion is a fabric case filled with soft ma...
# 61  62.cemetery:graveyard  A cemetery is a place where dead people's bodi...
# 62      63.automobile:car                            An automobile is a car.
# 63         64.midday:noon     Midday is 12 o'clock in the middle of the day.
# 64           65.gem:jewel  A gem is a jewel or stone that is used in jewe...
#
#                                            Sentence_2
# 0   A smile is the expression that you have on you...
# 1   A voyage is a long journey on a ship or in a s...
# 2   String is thin rope made of twisted threads, u...
# 3   A furnace is a container or enclosed space in ...
# 4   The shores or shore of a sea, lake or wide riv...
# ..                                                ...
# 60  A pillow is a rectangular cushion which you re...
# 61  A graveyard is an area of land, sometimes near...
# 62  A car is a motor vehicle with room for a small...
# 63       Noon is 12 o'clock in the middle of the day.
# 64  A jewel is a precious stone used to decorate v...
#
# [65 rows x 3 columns]

# %% [markdown]
# ##Processa usando word2vec

# %%
import re

# Função para limpar a sentença removendo pontos e vírgulas
def clean_sentence(sentence):
    return re.sub(r'[.,]', '', sentence)

# Lista para armazenar os resultados de similaridade
similarities = []

for index, row in df.iterrows():
    # Limpa e processa as duas sentenças
    sentence1_clean = clean_sentence(row['Sentence_1'])
    process_sentence(sentence1_clean, 'sentence1')
    print(sentence1_clean)
    dict1 = get_sentence_embeddings(sentence1_clean)
    sentence2_clean = clean_sentence(row['Sentence_2'])
    process_sentence(sentence2_clean, 'sentence2')
    print(sentence2_clean)
    dict2 = get_sentence_embeddings(sentence2_clean)

    # Abre os arquivos processados
    with open("/content/CANDC/sentence1_drg", "r") as fres, open("/content/CANDC/sentence2_drg", "r") as fres2:
        # Gera os grafos
        g1 = generate_graphs(fres)
        g2 = generate_graphs(fres2)

        # Calcula e armazena a similaridade
        similarity = g1.matchGraphBert(dict1, dict2, g2)
        # similarity = g1.matchGraph(g2)
        similarities.append(similarity)

# Adiciona a coluna de similaridade ao DataFrame
df['Similarity'] = similarities

# Salva o DataFrame modificado como CSV
# df.to_csv('/content/CANDC/results.csv', index=False)
# Out:
# Cord is strong thick string
# A smile is the expression that you have on your face when you are pleased or amused or when you are being friendly
# Cord is strong thick string
#
# A smile is the expression that you have on your face when you are pleased or amused or when you are being friendly
#
# Theme    Theme
# Theme    Theme
# Theme    equality
# Theme    Actor
# Theme    of
# Theme    Theme
# Theme    is
# Theme    equality
# Theme    Actor
# Theme    of
# Theme    Theme
# Theme    Theme
# Theme    on
# Theme    on
# Theme    Theme
# Theme    Theme
# Theme    equality
# Theme    Actor
# Theme    of
# Theme    Theme
# Theme    is
# Theme    equality
# Theme    Actor
# Theme    of
# Theme    Theme
# Theme    Theme
# Theme    on
# Theme    on
# is    Theme
# is    Theme
# is    equality
# is    Actor
# is    of
# is    Theme
# is    is
# is    equality
# is    Actor
# is    of
# is    Theme
# is    Theme
# is    on
# is    on
# Matriz de Relações:
#      Theme (N/A - N/A)     Theme (N/A - N/A)     equality (N/A - N/A)     Actor (N/A - N/A)     of (N/A - N/A)     Theme (N/A - N/A)     is (N/A - N/A)     equality (N/A - N/A)     Actor (N/A - N/A)     of (N/A - N/A)     Theme (N/A - N/A)     Theme (N/A - N/A)     on (N/A - N/A)     on (N/A - N/A)     when (N/A - N/A)     when (N/A - N/A)
# Theme (string - strong)     0.1381 (string - strong, N/A - N/A)     0.1312 (string - strong, N/A - N/A)     0.2521 (string - strong, N/A - N/A)     0.0999 (string - strong, N/A - N/A)     0.1016 (string - strong, N/A - N/A)     0.1119 (string - strong, N/A - N/A)     0.2562 (string - strong, N/A - N/A)     0.2569 (string - strong, N/A - N/A)     0.0999 (string - strong, N/A - N/A)     0.1016 (string - strong, N/A - N/A)     0.2993 (string - strong, N/A - N/A)     0.3078 (string - strong, N/A - N/A)     0.2024 (string - strong, N/A - N/A)     0.2024 (string - strong, N/A - N/A)     0.0000 (string - strong, N/A - N/A)     0.0000 (string - strong, N/A - N/A)
# Theme (string - thick)     0.1381 (string - thick, N/A - N/A)     0.1312 (string - thick, N/A - N/A)     0.2212 (string - thick, N/A - N/A)     0.0999 (string - thick, N/A - N/A)     0.1016 (string - thick, N/A - N/A)     0.1119 (string - thick, N/A - N/A)     0.2265 (string - thick, N/A - N/A)     0.2373 (string - thick, N/A - N/A)     0.0999 (string - thick, N/A - N/A)     0.1016 (string - thick, N/A - N/A)     0.2723 (string - thick, N/A - N/A)     0.2807 (string - thick, N/A - N/A)     0.1955 (string - thick, N/A - N/A)     0.1955 (string - thick, N/A - N/A)     0.0000 (string - thick, N/A - N/A)     0.0000 (string - thick, N/A - N/A)
# is (cord - string)     0.0000 (cord - string, N/A - N/A)     0.0000 (cord - string, N/A - N/A)     0.1105 (cord - string, N/A - N/A)     0.0000 (cord - string, N/A - N/A)     0.0000 (cord - string, N/A - N/A)     0.0000 (cord - string, N/A - N/A)     0.1045 (cord - string, N/A - N/A)     0.1167 (cord - string, N/A - N/A)     0.0000 (cord - string, N/A - N/A)     0.0000 (cord - string, N/A - N/A)     0.0960 (cord - string, N/A - N/A)     0.0960 (cord - string, N/A - N/A)     0.0976 (cord - string, N/A - N/A)     0.0976 (cord - string, N/A - N/A)     0.0000 (cord - string, N/A - N/A)     0.0000 (cord - string, N/A - N/A)
# Matriz exportada para relation_matrix.csv
# A rooster is an adult male chicken
# A voyage is a long journey on a ship or in a spacecraft
# A rooster is an adult male chicken
#
# A voyage is a long journey on a ship or in a spacecraft
#
# of    equality
# of    Theme
# of    is
# of    Theme
# of    equality
# of    Theme
# of    is
# of    Theme
# is    equality
# is    Theme
# is    is
# is    Theme
# Matriz de Relações:
#      equality (N/A - N/A)     Theme (N/A - N/A)     is (N/A - N/A)     Theme (N/A - N/A)     on (N/A - N/A)     in (N/A - N/A)
# of (chicken - adult)     0.2227 (chicken - adult, N/A - N/A)     0.2383 (chicken - adult, N/A - N/A)     0.2140 (chicken - adult, N/A - N/A)     0.2383 (chicken - adult, N/A - N/A)     0.0000 (chicken - adult, N/A - N/A)     0.0000 (chicken - adult, N/A - N/A)
# of (chicken - male)     0.2542 (chicken - male, N/A - N/A)     0.2796 (chicken - male, N/A - N/A)     0.2443 (chicken - male, N/A - N/A)     0.2796 (chicken - male, N/A - N/A)     0.0000 (chicken - male, N/A - N/A)     0.0000 (chicken - male, N/A - N/A)
# is (rooster - chicken)     0.2615 (rooster - chicken, N/A - N/A)     0.2408 (rooster - chicken, N/A - N/A)     0.2474 (rooster - chicken, N/A - N/A)     0.2408 (rooster - chicken, N/A - N/A)     0.0000 (rooster - chicken, N/A - N/A)     0.0000 (rooster - chicken, N/A - N/A)
# Matriz exportada para relation_matrix.csv
# Noon is 12 o'clock in the middle of the day
# String is thin rope made of twisted threads used for tying things together or tying up parcels
# Noon is 12 o'clock in the middle of the day
#
# String is thin rope made of twisted threads used for tying things together or tying up parcels
#
# equality    Theme
# equality    equality
# equality    Theme
# equality    Manner
# equality    Theme
# equality    Manner
# equality    is
# equality    equality
# equality    Theme
# equality    Theme
# equality    Theme
# equality    of
# equality    for
# equality    for
# is    Theme
# is    equality
# is    Theme
# is    Manner
# is    Theme
# is    Manner
# is    is
# is    equality
# is    Theme
# is    Theme
# is    Theme
# is    of
# is    for
# is    for
# equality    Theme
# equality    equality
# equality    Theme
# equality    Manner
# equality    Theme
# equality    Manner
# equality    is
# equality    equality
# equality    Theme
# equality    Theme
# equality    Theme
# equality    of
# equality    for
# equality    for
# equality    Theme
# equality    equality
# equality    Theme
# equality    Manner
# equality    Theme
# equality    Manner
# equality    is
# equality    equality
# equality    Theme
# equality    Theme
# equality    Theme
# equality    of
# equality    for
# equality    for
# of    Theme
# of    equality
# of    Theme
# of    Manner
# of    Theme
# of    Manner
# of    is
# of    equality
# of    Theme
# of    Theme
# of    Theme
# of    of
# of    for
# of    for
# Matriz de Relações:
#      Theme (N/A - N/A)     equality (N/A - N/A)     Actor (N/A - N/A)     Theme (N/A - N/A)     Manner (N/A - N/A)     Actor (N/A - N/A)     Theme (N/A - N/A)     Manner (N/A - N/A)     is (N/A - N/A)     equality (N/A - N/A)     Theme (N/A - N/A)     Theme (N/A - N/A)     Theme (N/A - N/A)     of (N/A - N/A)     for (N/A - N/A)     for (N/A - N/A)
# equality (XXXX - XX)     0.0000 (XXXX - XX, N/A - N/A)     0.0000 (XXXX - XX, N/A - N/A)     0.0000 (XXXX - XX, N/A - N/A)     0.0000 (XXXX - XX, N/A - N/A)     0.0000 (XXXX - XX, N/A - N/A)     0.0000 (XXXX - XX, N/A - N/A)     0.0000 (XXXX - XX, N/A - N/A)     0.0000 (XXXX - XX, N/A - N/A)     0.0000 (XXXX - XX, N/A - N/A)     0.0000 (XXXX - XX, N/A - N/A)     0.0000 (XXXX - XX, N/A - N/A)     0.0000 (XXXX - XX, N/A - N/A)     0.0000 (XXXX - XX, N/A - N/A)     0.0000 (XXXX - XX, N/A - N/A)     0.0000 (XXXX - XX, N/A - N/A)     0.0000 (XXXX - XX, N/A - N/A)
# is (noon - XXXX)     0.0000 (noon - XXXX, N/A - N/A)     0.0000 (noon - XXXX, N/A - N/A)     0.0000 (noon - XXXX, N/A - N/A)     0.0000 (noon - XXXX, N/A - N/A)     0.0000 (noon - XXXX, N/A - N/A)     0.0000 (noon - XXXX, N/A - N/A)     0.0000 (noon - XXXX, N/A - N/A)     0.0000 (noon - XXXX, N/A - N/A)     0.0000 (noon - XXXX, N/A - N/A)     0.0000 (noon - XXXX, N/A - N/A)     0.0000 (noon - XXXX, N/A - N/A)     0.0000 (noon - XXXX, N/A - N/A)     0.0000 (noon - XXXX, N/A - N/A)     0.0000 (noon - XXXX, N/A - N/A)     0.0000 (noon - XXXX, N/A - N/A)     0.0000 (noon - XXXX, N/A - N/A)
# equality (XXXX - 12)     0.1119 (XXXX - 12, N/A - N/A)     0.0000 (XXXX - 12, N/A - N/A)     0.0000 (XXXX - 12, N/A - N/A)     0.0000 (XXXX - 12, N/A - N/A)     0.1170 (XXXX - 12, N/A - N/A)     0.0000 (XXXX - 12, N/A - N/A)     0.0000 (XXXX - 12, N/A - N/A)     0.0944 (XXXX - 12, N/A - N/A)     0.1110 (XXXX - 12, N/A - N/A)     0.1050 (XXXX - 12, N/A - N/A)     0.1010 (XXXX - 12, N/A - N/A)     0.0000 (XXXX - 12, N/A - N/A)     0.0000 (XXXX - 12, N/A - N/A)     0.0000 (XXXX - 12, N/A - N/A)     0.0000 (XXXX - 12, N/A - N/A)     0.0000 (XXXX - 12, N/A - N/A)
# equality (XXXX - o'clock)     0.0000 (XXXX - o'clock, N/A - N/A)     0.0000 (XXXX - o'clock, N/A - N/A)     0.0000 (XXXX - o'clock, N/A - N/A)     0.0000 (XXXX - o'clock, N/A - N/A)     0.0000 (XXXX - o'clock, N/A - N/A)     0.0000 (XXXX - o'clock, N/A - N/A)     0.0000 (XXXX - o'clock, N/A - N/A)     0.0000 (XXXX - o'clock, N/A - N/A)     0.0000 (XXXX - o'clock, N/A - N/A)     0.0000 (XXXX - o'clock, N/A - N/A)     0.0000 (XXXX - o'clock, N/A - N/A)     0.0000 (XXXX - o'clock, N/A - N/A)     0.0000 (XXXX - o'clock, N/A - N/A)     0.0000 (XXXX - o'clock, N/A - N/A)     0.0000 (XXXX - o'clock, N/A - N/A)     0.0000 (XXXX - o'clock, N/A - N/A)
# in (N/A - middle)     0.0000 (N/A - middle, N/A - N/A)     0.0000 (N/A - middle, N/A - N/A)     0.0000 (N/A - middle, N/A - N/A)     0.0000 (N/A - middle, N/A - N/A)     0.0000 (N/A - middle, N/A - N/A)     0.0000 (N/A - middle, N/A - N/A)     0.0000 (N/A - middle, N/A - N/A)     0.0000 (N/A - middle, N/A - N/A)     0.0000 (N/A - middle, N/A - N/A)     0.0000 (N/A - middle, N/A - N/A)     0.0000 (N/A - middle, N/A - N/A)     0.0000 (N/A - middle, N/A - N/A)     0.0000 (N/A - middle, N/A - N/A)     0.0000 (N/A - middle, N/A - N/A)     0.0000 (N/A - middle, N/A - N/A)     0.0000 (N/A - middle, N/A - N/A)
# of (middle - day)     0.2160 (middle - day, N/A - N/A)     0.0000 (middle - day, N/A - N/A)     0.0000 (middle - day, N/A - N/A)     0.0000 (middle - day, N/A - N/A)     0.1095 (middle - day, N/A - N/A)     0.0000 (middle - day, N/A - N/A)     0.0000 (middle - day, N/A - N/A)     0.1029 (middle - day, N/A - N/A)     0.1072 (middle - day, N/A - N/A)     0.2310 (middle - day, N/A - N/A)     0.0968 (middle - day, N/A - N/A)     0.0000 (middle - day, N/A - N/A)     0.1194 (middle - day, N/A - N/A)     0.0000 (middle - day, N/A - N/A)     0.0000 (middle - day, N/A - N/A)     0.0000 (middle - day, N/A - N/A)
# Matriz exportada para relation_matrix.csv
# Fruit or a fruit is something which grows on a tree or bush and which contains seeds or a stone covered by a substance that you can eat
# A furnace is a container or enclosed space in which a very hot fire is made for example to melt metal burn rubbish or produce steam
# Fruit or a fruit is something which grows on a tree or bush and which contains seeds or a stone covered by a substance that you can eat
#
# A furnace is a container or enclosed space in which a very hot fire is made for example to melt metal burn rubbish or produce steam
#
# is    Theme
# is    equality
# is    Theme
# is    Theme
# is    Actor
# is    Theme
# is    Actor
# is    Theme
# is    Theme
# is    is
# is    Theme
# is    Actor
# is    in
# is    equality
# is    equality
# is    equality
# is    for
# equality    Theme
# equality    equality
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    is
# equality    Theme
# equality    Actor
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    for
# Theme    Theme
# Theme    equality
# Theme    Theme
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Theme
# Theme    is
# Theme    Theme
# Theme    Actor
# Theme    in
# Theme    equality
# Theme    equality
# Theme    equality
# Theme    for
# equality    Theme
# equality    equality
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    is
# equality    Theme
# equality    Actor
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    for
# Actor    Theme
# Actor    equality
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    is
# Actor    Theme
# Actor    Actor
# Actor    in
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    for
# equality    Theme
# equality    equality
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    is
# equality    Theme
# equality    Actor
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    for
# Actor    Theme
# Actor    equality
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    is
# Actor    Theme
# Actor    Actor
# Actor    in
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    for
# equality    Theme
# equality    equality
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    is
# equality    Theme
# equality    Actor
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    for
# Theme    Theme
# Theme    equality
# Theme    Theme
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Theme
# Theme    is
# Theme    Theme
# Theme    Actor
# Theme    in
# Theme    equality
# Theme    equality
# Theme    equality
# Theme    for
# equality    Theme
# equality    equality
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    is
# equality    Theme
# equality    Actor
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    for
# equality    Theme
# equality    equality
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    is
# equality    Theme
# equality    Actor
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    for
# equality    Theme
# equality    equality
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    is
# equality    Theme
# equality    Actor
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    for
# equality    Theme
# equality    equality
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    is
# equality    Theme
# equality    Actor
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    for
# Theme    Theme
# Theme    equality
# Theme    Theme
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Theme
# Theme    is
# Theme    Theme
# Theme    Actor
# Theme    in
# Theme    equality
# Theme    equality
# Theme    equality
# Theme    for
# equality    Theme
# equality    equality
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    is
# equality    Theme
# equality    Actor
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    for
# Actor    Theme
# Actor    equality
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    is
# Actor    Theme
# Actor    Actor
# Actor    in
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    for
# equality    Theme
# equality    equality
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    is
# equality    Theme
# equality    Actor
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    for
# Actor    Theme
# Actor    equality
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    is
# Actor    Theme
# Actor    Actor
# Actor    in
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    for
# Theme    Theme
# Theme    equality
# Theme    Theme
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Theme
# Theme    is
# Theme    Theme
# Theme    Actor
# Theme    in
# Theme    equality
# Theme    equality
# Theme    equality
# Theme    for
# equality    Theme
# equality    equality
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    is
# equality    Theme
# equality    Actor
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    for
# Actor    Theme
# Actor    equality
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    is
# Actor    Theme
# Actor    Actor
# Actor    in
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    for
# Theme    Theme
# Theme    equality
# Theme    Theme
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Theme
# Theme    is
# Theme    Theme
# Theme    Actor
# Theme    in
# Theme    equality
# Theme    equality
# Theme    equality
# Theme    for
# Theme    Theme
# Theme    equality
# Theme    Theme
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Theme
# Theme    is
# Theme    Theme
# Theme    Actor
# Theme    in
# Theme    equality
# Theme    equality
# Theme    equality
# Theme    for
# Actor    Theme
# Actor    equality
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    is
# Actor    Theme
# Actor    Actor
# Actor    in
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    for
# Actor    Theme
# Actor    equality
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    is
# Actor    Theme
# Actor    Actor
# Actor    in
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    for
# Actor    Theme
# Actor    equality
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    is
# Actor    Theme
# Actor    Actor
# Actor    in
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    for
# Actor    Theme
# Actor    equality
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    is
# Actor    Theme
# Actor    Actor
# Actor    in
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    for
# Theme    Theme
# Theme    equality
# Theme    Theme
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Theme
# Theme    is
# Theme    Theme
# Theme    Actor
# Theme    in
# Theme    equality
# Theme    equality
# Theme    equality
# Theme    for
# Theme    Theme
# Theme    equality
# Theme    Theme
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Theme
# Theme    is
# Theme    Theme
# Theme    Actor
# Theme    in
# Theme    equality
# Theme    equality
# Theme    equality
# Theme    for
# Actor    Theme
# Actor    equality
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    is
# Actor    Theme
# Actor    Actor
# Actor    in
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    for
# on    Theme
# on    equality
# on    Theme
# on    Theme
# on    Actor
# on    Theme
# on    Actor
# on    Theme
# on    Theme
# on    is
# on    Theme
# on    Actor
# on    in
# on    equality
# on    equality
# on    equality
# on    for
# on    Theme
# on    equality
# on    Theme
# on    Theme
# on    Actor
# on    Theme
# on    Actor
# on    Theme
# on    Theme
# on    is
# on    Theme
# on    Actor
# on    in
# on    equality
# on    equality
# on    equality
# on    for
# equality    Theme
# equality    equality
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    is
# equality    Theme
# equality    Actor
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    for
# equality    Theme
# equality    equality
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    is
# equality    Theme
# equality    Actor
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    for
# Actor    Theme
# Actor    equality
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    is
# Actor    Theme
# Actor    Actor
# Actor    in
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    for
# Actor    Theme
# Actor    equality
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    is
# Actor    Theme
# Actor    Actor
# Actor    in
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    for
# Matriz de Relações:
#      Theme (N/A - N/A)     equality (N/A - N/A)     Theme (N/A - N/A)     Theme (N/A - N/A)     Actor (N/A - N/A)     Theme (N/A - N/A)     Actor (N/A - N/A)     Theme (N/A - N/A)     Topic (N/A - N/A)     Theme (N/A - N/A)     is (N/A - N/A)     Theme (N/A - N/A)     Actor (N/A - N/A)     in (N/A - N/A)     equality (N/A - bush)     equality (N/A - bush)     equality (N/A - N/A)     for (N/A - N/A)
# is (fruit - thing)     0.0000 (fruit - thing, N/A - N/A)     0.1765 (fruit - thing, N/A - N/A)     0.1539 (fruit - thing, N/A - N/A)     0.1517 (fruit - thing, N/A - N/A)     0.1693 (fruit - thing, N/A - N/A)     0.1693 (fruit - thing, N/A - N/A)     0.1822 (fruit - thing, N/A - N/A)     0.1822 (fruit - thing, N/A - N/A)     0.0000 (fruit - thing, N/A - N/A)     0.1907 (fruit - thing, N/A - N/A)     0.1795 (fruit - thing, N/A - N/A)     0.1517 (fruit - thing, N/A - N/A)     0.1765 (fruit - thing, N/A - N/A)     0.0000 (fruit - thing, N/A - N/A)     0.1907 (fruit - thing, N/A - bush)     0.1517 (fruit - thing, N/A - bush)     0.1517 (fruit - thing, N/A - N/A)     0.0000 (fruit - thing, N/A - N/A)
# equality (thing - which)     0.1674 (thing - which, N/A - N/A)     0.1521 (thing - which, N/A - N/A)     0.1556 (thing - which, N/A - N/A)     0.1533 (thing - which, N/A - N/A)     0.1674 (thing - which, N/A - N/A)     0.1673 (thing - which, N/A - N/A)     0.1674 (thing - which, N/A - N/A)     0.1760 (thing - which, N/A - N/A)     0.0000 (thing - which, N/A - N/A)     0.0000 (thing - which, N/A - N/A)     0.1831 (thing - which, N/A - N/A)     0.1533 (thing - which, N/A - N/A)     0.1520 (thing - which, N/A - N/A)     0.1856 (thing - which, N/A - N/A)     0.1719 (thing - which, N/A - bush)     0.1580 (thing - which, N/A - bush)     0.1580 (thing - which, N/A - N/A)     0.1884 (thing - which, N/A - N/A)
# Theme (contain - seed)     0.0000 (contain - seed, N/A - N/A)     0.0000 (contain - seed, N/A - N/A)     0.0000 (contain - seed, N/A - N/A)     0.0000 (contain - seed, N/A - N/A)     0.0000 (contain - seed, N/A - N/A)     0.0000 (contain - seed, N/A - N/A)     0.0000 (contain - seed, N/A - N/A)     0.0000 (contain - seed, N/A - N/A)     0.0000 (contain - seed, N/A - N/A)     0.0000 (contain - seed, N/A - N/A)     0.0000 (contain - seed, N/A - N/A)     0.0000 (contain - seed, N/A - N/A)     0.0000 (contain - seed, N/A - N/A)     0.0000 (contain - seed, N/A - N/A)     0.0000 (contain - seed, N/A - bush)     0.0000 (contain - seed, N/A - bush)     0.0000 (contain - seed, N/A - N/A)     0.0000 (contain - seed, N/A - N/A)
# equality (stone - stone)     0.1699 (stone - stone, N/A - N/A)     0.3732 (stone - stone, N/A - N/A)     0.3529 (stone - stone, N/A - N/A)     0.3304 (stone - stone, N/A - N/A)     0.3566 (stone - stone, N/A - N/A)     0.3920 (stone - stone, N/A - N/A)     0.3597 (stone - stone, N/A - N/A)     0.4143 (stone - stone, N/A - N/A)     0.0000 (stone - stone, N/A - N/A)     0.2101 (stone - stone, N/A - N/A)     0.4026 (stone - stone, N/A - N/A)     0.3304 (stone - stone, N/A - N/A)     0.3816 (stone - stone, N/A - N/A)     0.2046 (stone - stone, N/A - N/A)     0.3736 (stone - stone, N/A - bush)     0.3305 (stone - stone, N/A - bush)     0.3305 (stone - stone, N/A - N/A)     0.1702 (stone - stone, N/A - N/A)
# Theme (which - put)     0.4848 (which - put, N/A - N/A)     0.1709 (which - put, N/A - N/A)     0.5288 (which - put, N/A - N/A)     0.0000 (which - put, N/A - N/A)     0.3683 (which - put, N/A - N/A)     0.1753 (which - put, N/A - N/A)     0.0000 (which - put, N/A - N/A)     0.0000 (which - put, N/A - N/A)     0.1688 (which - put, N/A - N/A)
# Theme (case - fill)     0.3296 (case - fill, N/A - N/A)     0.1757 (case - fill, N/A - N/A)     0.2282 (case - fill, N/A - N/A)     0.0000 (case - fill, N/A - N/A)     0.2046 (case - fill, N/A - N/A)     0.1884 (case - fill, N/A - N/A)     0.0000 (case - fill, N/A - N/A)     0.0000 (case - fill, N/A - N/A)     0.0000 (case - fill, N/A - N/A)
# with (fill - material)     0.1989 (fill - material, N/A - N/A)     0.0000 (fill - material, N/A - N/A)     0.2113 (fill - material, N/A - N/A)     0.0000 (fill - material, N/A - N/A)     0.2382 (fill - material, N/A - N/A)     0.0000 (fill - material, N/A - N/A)     0.0000 (fill - material, N/A - N/A)     0.0000 (fill - material, N/A - N/A)     0.1826 (fill - material, N/A - N/A)
# on (put - seat)     0.3972 (put - seat, N/A - N/A)     0.2601 (put - seat, N/A - N/A)     0.4996 (put - seat, N/A - N/A)     0.0000 (put - seat, N/A - N/A)     0.4209 (put - seat, N/A - N/A)     0.2363 (put - seat, N/A - N/A)     0.0000 (put - seat, N/A - N/A)     0.0000 (put - seat, N/A - N/A)     0.2075 (put - seat, N/A - N/A)
# Matriz exportada para relation_matrix.csv
# A cemetery is a place where dead people's bodies or their ashes are buried
# A graveyard is an area of land sometimes near a church where dead people are buried
# A cemetery is a place where dead people's bodies or their ashes are buried
#
# A graveyard is an area of land sometimes near a church where dead people are buried
#
# Theme    Theme
# Theme    is
# Theme    Theme
# Theme    of
# of    Theme
# of    is
# of    Theme
# of    of
# Theme    Theme
# Theme    is
# Theme    Theme
# Theme    of
# is    Theme
# is    is
# is    Theme
# is    of
# Theme    Theme
# Theme    is
# Theme    Theme
# Theme    of
# of    Theme
# of    is
# of    Theme
# of    of
# Matriz de Relações:
#      Theme (N/A - N/A)     is (N/A - N/A)     Manner (N/A - N/A)     Theme (N/A - N/A)     of (N/A - N/A)     near (N/A - N/A)     where (N/A - N/A)
# Theme (bury - body)     0.0000 (bury - body, N/A - N/A)     0.0000 (bury - body, N/A - N/A)     0.0000 (bury - body, N/A - N/A)     0.0000 (bury - body, N/A - N/A)     0.0000 (bury - body, N/A - N/A)     0.0000 (bury - body, N/A - N/A)     0.0000 (bury - body, N/A - N/A)
# of (ash - thing)     0.0000 (ash - thing, N/A - N/A)     0.0000 (ash - thing, N/A - N/A)     0.0000 (ash - thing, N/A - N/A)     0.0000 (ash - thing, N/A - N/A)     0.0000 (ash - thing, N/A - N/A)     0.0000 (ash - thing, N/A - N/A)     0.0000 (ash - thing, N/A - N/A)
# Theme (bury - ash)     0.0000 (bury - ash, N/A - N/A)     0.0000 (bury - ash, N/A - N/A)     0.0000 (bury - ash, N/A - N/A)     0.0000 (bury - ash, N/A - N/A)     0.0000 (bury - ash, N/A - N/A)     0.0000 (bury - ash, N/A - N/A)     0.0000 (bury - ash, N/A - N/A)
# is (cemetery - place)     0.2448 (cemetery - place, N/A - N/A)     0.5158 (cemetery - place, N/A - N/A)     0.0000 (cemetery - place, N/A - N/A)     0.4691 (cemetery - place, N/A - N/A)     0.4787 (cemetery - place, N/A - N/A)     0.0000 (cemetery - place, N/A - N/A)     0.0000 (cemetery - place, N/A - N/A)
# Theme (body - dead)     0.3877 (body - dead, N/A - N/A)     0.1858 (body - dead, N/A - N/A)     0.0000 (body - dead, N/A - N/A)     0.4434 (body - dead, N/A - N/A)     0.2121 (body - dead, N/A - N/A)     0.0000 (body - dead, N/A - N/A)     0.0000 (body - dead, N/A - N/A)
# of (body - people's)     0.0000 (body - people's, N/A - N/A)     0.0000 (body - people's, N/A - N/A)     0.0000 (body - people's, N/A - N/A)     0.0000 (body - people's, N/A - N/A)     0.0000 (body - people's, N/A - N/A)     0.0000 (body - people's, N/A - N/A)     0.0000 (body - people's, N/A - N/A)
# where (place - N/A)     0.0000 (place - N/A, N/A - N/A)     0.0000 (place - N/A, N/A - N/A)     0.0000 (place - N/A, N/A - N/A)     0.0000 (place - N/A, N/A - N/A)     0.0000 (place - N/A, N/A - N/A)     0.0000 (place - N/A, N/A - N/A)     0.0000 (place - N/A, N/A - N/A)
# Matriz exportada para relation_matrix.csv
# An automobile is a car
# A car is a motor vehicle with room for a small number of passengers
# An automobile is a car
#
# A car is a motor vehicle with room for a small number of passengers
#
# is    is
# is    of
# is    Theme
# is    with
# is    for
# is    of
# Matriz de Relações:
#      is (automobile - car)     of (car - N/A)     Theme (N/A - N/A)     with (car - N/A)     for (N/A - N/A)     of (N/A - N/A)
# is (automobile - car)     0.4811 (automobile - car, automobile - car)     0.4793 (automobile - car, car - N/A)     0.3432 (automobile - car, N/A - N/A)     0.3820 (automobile - car, car - N/A)     0.3160 (automobile - car, N/A - N/A)     0.1722 (automobile - car, N/A - N/A)
# Matriz exportada para relation_matrix.csv
# Midday is 12 o'clock in the middle of the day
# Noon is 12 o'clock in the middle of the day
# Midday is 12 o'clock in the middle of the day
#
# Noon is 12 o'clock in the middle of the day
#
# equality    equality
# equality    is
# equality    equality
# equality    equality
# equality    of
# is    equality
# is    is
# is    equality
# is    equality
# is    of
# equality    equality
# equality    is
# equality    equality
# equality    equality
# equality    of
# equality    equality
# equality    is
# equality    equality
# equality    equality
# equality    of
# of    equality
# of    is
# of    equality
# of    equality
# of    of
# Matriz de Relações:
#      equality (XXXX - XX)     is (midday - XXXX)     equality (XXXX - 12)     equality (XXXX - o'clock)     in (N/A - middle)     of (middle - day)
# equality (XXXX - XX)     0.0000 (XXXX - XX, XXXX - XX)     0.0000 (XXXX - XX, midday - XXXX)     0.0000 (XXXX - XX, XXXX - 12)     0.0000 (XXXX - XX, XXXX - o'clock)     0.0000 (XXXX - XX, N/A - middle)     0.0000 (XXXX - XX, middle - day)
# is (midday - XXXX)     0.0000 (midday - XXXX, XXXX - XX)     0.0000 (midday - XXXX, midday - XXXX)     0.0000 (midday - XXXX, XXXX - 12)     0.0000 (midday - XXXX, XXXX - o'clock)     0.0000 (midday - XXXX, N/A - middle)     0.0000 (midday - XXXX, middle - day)
# equality (XXXX - 12)     0.0000 (XXXX - 12, XXXX - XX)     0.0000 (XXXX - 12, midday - XXXX)     0.3381 (XXXX - 12, XXXX - 12)     0.0000 (XXXX - 12, XXXX - o'clock)     0.0000 (XXXX - 12, N/A - middle)     0.1770 (XXXX - 12, middle - day)
# equality (XXXX - o'clock)     0.0000 (XXXX - o'clock, XXXX - XX)     0.0000 (XXXX - o'clock, midday - XXXX)     0.0000 (XXXX - o'clock, XXXX - 12)     0.0000 (XXXX - o'clock, XXXX - o'clock)     0.0000 (XXXX - o'clock, N/A - middle)     0.0000 (XXXX - o'clock, middle - day)
# in (N/A - middle)     0.0000 (N/A - middle, XXXX - XX)     0.0000 (N/A - middle, midday - XXXX)     0.0000 (N/A - middle, XXXX - 12)     0.0000 (N/A - middle, XXXX - o'clock)     0.0000 (N/A - middle, N/A - middle)     0.0000 (N/A - middle, middle - day)
# of (middle - day)     0.0000 (middle - day, XXXX - XX)     0.0000 (middle - day, midday - XXXX)     0.1845 (middle - day, XXXX - 12)     0.0000 (middle - day, XXXX - o'clock)     0.0000 (middle - day, N/A - middle)     0.9571 (middle - day, middle - day)
# Matriz exportada para relation_matrix.csv
# A gem is a jewel or stone that is used in jewellery
# A jewel is a precious stone used to decorate valuable things that you wear such as rings or necklaces
# A gem is a jewel or stone that is used in jewellery
#
# A jewel is a precious stone used to decorate valuable things that you wear such as rings or necklaces
#
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    is
# equality    equality
# equality    Theme
# equality    equality
# equality    Theme
# equality    Actor
# equality    Actor
# equality    Topic
# equality    equality
# equality    as
# equality    as
# is    Theme
# is    Actor
# is    Theme
# is    Theme
# is    is
# is    equality
# is    Theme
# is    equality
# is    Theme
# is    Actor
# is    Actor
# is    Topic
# is    equality
# is    as
# is    as
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Theme
# Theme    is
# Theme    equality
# Theme    Theme
# Theme    equality
# Theme    Theme
# Theme    Actor
# Theme    Actor
# Theme    Topic
# Theme    equality
# Theme    as
# Theme    as
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    is
# equality    equality
# equality    Theme
# equality    equality
# equality    Theme
# equality    Actor
# equality    Actor
# equality    Topic
# equality    equality
# equality    as
# equality    as
# in    Theme
# in    Actor
# in    Theme
# in    Theme
# in    is
# in    equality
# in    Theme
# in    equality
# in    Theme
# in    Actor
# in    Actor
# in    Topic
# in    equality
# in    as
# in    as
# Matriz de Relações:
#      Theme (N/A - N/A)     Actor (N/A - N/A)     Theme (N/A - N/A)     Theme (N/A - N/A)     Recipient (N/A - N/A)     is (N/A - N/A)     equality (N/A - N/A)     Theme (N/A - N/A)     equality (N/A - N/A)     Theme (N/A - N/A)     Actor (N/A - N/A)     Actor (N/A - N/A)     Topic (N/A - N/A)     equality (N/A - stone)     as (N/A - N/A)     as (N/A - N/A)
# equality (jewel - that)     0.5321 (jewel - that, N/A - N/A)     0.2216 (jewel - that, N/A - N/A)     0.2395 (jewel - that, N/A - N/A)     0.2395 (jewel - that, N/A - N/A)     0.0000 (jewel - that, N/A - N/A)     0.5602 (jewel - that, N/A - N/A)     0.5009 (jewel - that, N/A - N/A)     0.1999 (jewel - that, N/A - N/A)     0.2387 (jewel - that, N/A - N/A)     0.4107 (jewel - that, N/A - N/A)     0.4989 (jewel - that, N/A - N/A)     0.4989 (jewel - that, N/A - N/A)     0.2882 (jewel - that, N/A - N/A)     0.3945 (jewel - that, N/A - stone)     0.0000 (jewel - that, N/A - N/A)     0.0000 (jewel - that, N/A - N/A)
# is (gem - jewel)     0.4494 (gem - jewel, N/A - N/A)     0.1642 (gem - jewel, N/A - N/A)     0.1830 (gem - jewel, N/A - N/A)     0.1830 (gem - jewel, N/A - N/A)     0.0000 (gem - jewel, N/A - N/A)     0.4756 (gem - jewel, N/A - N/A)     0.4819 (gem - jewel, N/A - N/A)     0.2012 (gem - jewel, N/A - N/A)     0.2010 (gem - jewel, N/A - N/A)     0.3636 (gem - jewel, N/A - N/A)     0.4351 (gem - jewel, N/A - N/A)     0.4351 (gem - jewel, N/A - N/A)     0.2049 (gem - jewel, N/A - N/A)     0.3433 (gem - jewel, N/A - stone)     0.0000 (gem - jewel, N/A - N/A)     0.0000 (gem - jewel, N/A - N/A)
# Theme (that - use)     0.3412 (that - use, N/A - N/A)     0.2016 (that - use, N/A - N/A)     0.2736 (that - use, N/A - N/A)     0.2736 (that - use, N/A - N/A)     0.0000 (that - use, N/A - N/A)     0.2269 (that - use, N/A - N/A)     0.2628 (that - use, N/A - N/A)     0.0000 (that - use, N/A - N/A)     0.0000 (that - use, N/A - N/A)     0.3410 (that - use, N/A - N/A)     0.2628 (that - use, N/A - N/A)     0.2628 (that - use, N/A - N/A)     0.2628 (that - use, N/A - N/A)     0.2626 (that - use, N/A - stone)     0.0000 (that - use, N/A - N/A)     0.0000 (that - use, N/A - N/A)
# equality (jewel - stone)     0.5348 (jewel - stone, N/A - N/A)     0.2216 (jewel - stone, N/A - N/A)     0.2395 (jewel - stone, N/A - N/A)     0.2395 (jewel - stone, N/A - N/A)     0.0000 (jewel - stone, N/A - N/A)     0.6133 (jewel - stone, N/A - N/A)     0.5512 (jewel - stone, N/A - N/A)     0.2054 (jewel - stone, N/A - N/A)     0.1730 (jewel - stone, N/A - N/A)     0.4108 (jewel - stone, N/A - N/A)     0.4998 (jewel - stone, N/A - N/A)     0.4998 (jewel - stone, N/A - N/A)     0.2882 (jewel - stone, N/A - N/A)     0.3761 (jewel - stone, N/A - stone)     0.0000 (jewel - stone, N/A - N/A)     0.0000 (jewel - stone, N/A - N/A)
# in (use - jewellery)     0.2137 (use - jewellery, N/A - N/A)     0.0000 (use - jewellery, N/A - N/A)     0.0000 (use - jewellery, N/A - N/A)     0.0000 (use - jewellery, N/A - N/A)     0.0000 (use - jewellery, N/A - N/A)     0.2218 (use - jewellery, N/A - N/A)     0.2310 (use - jewellery, N/A - N/A)     0.1853 (use - jewellery, N/A - N/A)     0.1868 (use - jewellery, N/A - N/A)     0.2067 (use - jewellery, N/A - N/A)     0.2128 (use - jewellery, N/A - N/A)     0.2128 (use - jewellery, N/A - N/A)     0.0000 (use - jewellery, N/A - N/A)     0.1822 (use - jewellery, N/A - stone)     0.0000 (use - jewellery, N/A - N/A)     0.0000 (use - jewellery, N/A - N/A)
# Matriz exportada para relation_matrix.csv

# %%
similarities
# Out:
# [0.2090099872010095,
#  0.2596228754073381,
#  0.15831176429454769,
#  0.31920888561113137,
#  0.24004398056678475,
#  0.2729843339920044,
#  0.3027580660400646,
#  0.3878445852920413,
#  0.26134298867526207,
#  0.3533485798131336,
#  0.273022679798305,
#  0.24155203537705044,
#  0.3062128094881773,
#  0.3912428460425728,
#  0.3727705158936706,
#  0.29145501226186754,
#  0.43156221519224347,
#  0.3662818387026588,
#  0.2650926766482492,
#  0.3065923188990829,
#  0.38641736042499547,
#  0.2433099226653576,
#  0.3596692054303629,
#  0.37250331249708935,
#  0.3775070300524111,
#  0.12237958434969187,
#  0.20391207878788312,
#  0.3413080347568861,
#  0.20720813139208724,
#  0.5132121476419269,
#  0.39104915309540866,
#  0.24993409044685816,
#  0.2719219016085068,
#  0.23849486002077658,
#  0.253671829521656,
#  0.394311330200961,
#  0.31522882334662206,
#  0.3949367370722549,
#  0.3991733197371165,
#  0.32512656950950625,
#  0.29200497647036205,
#  0.28375962837326985,
#  0.3190937677238669,
#  0.26410179926082494,
#  0.2803592672881981,
#  0.3029579643625766,
#  0.4322641070873079,
#  0.4293214198450247,
#  0.3505264907516539,
#  0.33921853801324253,
#  0.26382660027593374,
#  0.3494064572234364,
#  0.378543329684475,
#  0.3424239598918292,
#  0.3160723366037659,
#  0.4963322015888989,
#  0.2728464600419005,
#  0.6659174051609906,
#  0.6947112073500952,
#  0.5350467470089595,
#  0.4005965405814593,
#  0.4907500850237333,
#  0.4216856319457293,
#  0.647569426894188,
#  0.4537883384817547]

# %%
df
# Out:
#             Sentence_Pair                                         Sentence_1  \
# 0            1.cord:smile                      Cord is strong, thick string.
# 1        2.rooster:voyage                A rooster is an adult male chicken.
# 2           3.noon:string       Noon is 12 o'clock in the middle of the day.
# 3         4.fruit:furnace  Fruit or a fruit is something which grows on a...
# 4       5.autograph:shore  An autograph is the signature of someone famou...
# ..                    ...                                                ...
# 60      61.cushion:pillow  A cushion is a fabric case filled with soft ma...
# 61  62.cemetery:graveyard  A cemetery is a place where dead people's bodi...
# 62      63.automobile:car                            An automobile is a car.
# 63         64.midday:noon     Midday is 12 o'clock in the middle of the day.
# 64           65.gem:jewel  A gem is a jewel or stone that is used in jewe...
#
#                                            Sentence_2  Similarity
# 0   A smile is the expression that you have on you...    0.209010
# 1   A voyage is a long journey on a ship or in a s...    0.259623
# 2   String is thin rope made of twisted threads, u...    0.158312
# 3   A furnace is a container or enclosed space in ...    0.319209
# 4   The shores or shore of a sea, lake or wide riv...    0.240044
# ..                                                ...         ...
# 60  A pillow is a rectangular cushion which you re...    0.400597
# 61  A graveyard is an area of land, sometimes near...    0.490750
# 62  A car is a motor vehicle with room for a small...    0.421686
# 63       Noon is 12 o'clock in the middle of the day.    0.647569
# 64  A jewel is a precious stone used to decorate v...    0.453788
#
# [65 rows x 4 columns]

# %%
df.to_csv('/content/CANDC/results.csv', index=False)
