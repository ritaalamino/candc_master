# %% [markdown]
# <a href="https://colab.research.google.com/github/ritaalamino/candc_master/blob/main/CANDC_BERT_MSRP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## *CANDC*

# %% [markdown]
# Funções não suportadas
#
# *   --semantics
# *   --modal
# *   --elimeq não muda nada
# *   --vpe  não muda nada
# *   --robust  não muda nada
# *   --roles  não muda nada

# %% [markdown]
# ##Importa bibliotecas

# %%
# Import das bibliotecas.

# Biblioteca de logging
import logging
import subprocess
import os
import csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Instala as libraries necessárias

# %%
# Diretório do cohebert
DIRETORIO_CANDC = "CANDC"

# Diretório local para os arquivos pré-processados
DIRETORIO_LOCAL = "/content/" + DIRETORIO_CANDC + "/"

# Diretório no google drive com os arquivos pré-processados
DIRETORIO_DRIVE = "/content/drive/MyDrive/Colab Notebooks/Data/" + DIRETORIO_CANDC + "/"

# %%
# !git clone https://github.com/valeriobasile/learningbyreading.git
# Out:
# Cloning into 'learningbyreading'...
# remote: Enumerating objects: 1870, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 1870 (delta 30), reused 58 (delta 22), pack-reused 1797 (from 1)
# Receiving objects: 100% (1870/1870), 295.87 MiB | 21.07 MiB/s, done.
# Resolving deltas: 100% (722/722), done.
# Updating files: 100% (970/970), done.

# %%
os.chdir('./learningbyreading/ext')

# %%
# !./install_candc.sh
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# /usr/bin/install -c -m 644 ../demo/README /content/learningbyreading/ext/candc/lib/swipl-6.6.6/demo/README
# /usr/bin/install -c -m 644 swipl.prc "/content/learningbyreading/ext/candc/lib/swipl-6.6.6/boot64.prc"
# echo . > "/content/learningbyreading/ext/candc/lib/swipl-6.6.6/swipl.home"
# echo .. > "/content/learningbyreading/ext/candc/lib/swipl-6.6.6/bin/swipl.home"
# ./swipl.sh -C "/content/learningbyreading/ext/candc/lib/swipl-6.6.6" -f none -F none \
# 		-g 'make_library_index(library)' \
# 		-t halt
# % Updating index for library /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/
# if [ -d ../man/Manual ]; then \
# 	  if [ ! -d /content/learningbyreading/ext/candc/lib/swipl-6.6.6/doc ]; then mkdir -p /content/learningbyreading/ext/candc/lib/swipl-6.6.6/doc; fi; \
# 	  if [ ! -d /content/learningbyreading/ext/candc/lib/swipl-6.6.6/doc/Manual ]; then mkdir -p /content/learningbyreading/ext/candc/lib/swipl-6.6.6/doc/Manual; fi; \
# 	  for f in ../man/Manual/*.html ../man/Manual/*.gif; do \
# 	    /usr/bin/install -c -m 644 $f /content/learningbyreading/ext/candc/lib/swipl-6.6.6/doc/Manual; \
# 	  done; \
# 	fi
# if [ ! -d /content/learningbyreading/ext/candc/bin  ]; then mkdir -p /content/learningbyreading/ext/candc/bin; fi
# for f in swipl swipl-ld swipl-rc; do \
# 	    ./rel-ln /content/learningbyreading/ext/candc/lib/swipl-6.6.6/bin/x86_64-linux/$f /content/learningbyreading/ext/candc/bin; \
# 	done
# if [ ! -d /content/learningbyreading/ext/candc/lib/pkgconfig ]; then mkdir -p /content/learningbyreading/ext/candc/lib/pkgconfig; fi
# /usr/bin/install -c -m 644 swipl.pc /content/learningbyreading/ext/candc/lib/pkgconfig/
# if [ ! -d /content/learningbyreading/ext/candc/share/man ]; then mkdir -p /content/learningbyreading/ext/candc/share/man; fi
# if [ ! -d /content/learningbyreading/ext/candc/share/man/man1  ];    then mkdir -p /content/learningbyreading/ext/candc/share/man/man1; fi
# /usr/bin/install -c -m 644 swipl.1 /content/learningbyreading/ext/candc/share/man/man1/swipl.1
# /usr/bin/install -c -m 644 ./swipl-rc.1 /content/learningbyreading/ext/candc/share/man/man1/swipl-rc.1
# /usr/bin/install -c -m 644 ./swipl-ld.1 /content/learningbyreading/ext/candc/share/man/man1/swipl-ld.1
# make[1]: Leaving directory '/content/learningbyreading/ext/candc/pl-6.6.6/src'
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/base.o src/lib/base.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/ports/unix.o src/lib/ports/unix.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/ports/unix_common.o src/lib/ports/unix_common.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/ports/colour.o src/lib/ports/colour.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/timer.o src/lib/timer.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/input.o src/lib/input.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/word.o src/lib/word.cc
# src/scripts/version unix
# src/scripts/version: line 53: svnversion: command not found
# Usage: grep [OPTION]... PATTERNS [FILE]...
# Try 'grep --help' for more information.
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/version.o src/lib/version.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/licence.o src/lib/licence.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagset.o src/lib/tagset.cc
# src/lib/tagset.cc: In member function ‘std::string NLP::TagSet::load_tags(const string&, NLP::Tags&) const’:
# src/lib/tagset.cc:167:20: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   167 |   }catch(Exception e){
#       |                    ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/lexicon.o src/lib/lexicon.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/utils/escape.o src/lib/utils/escape.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/config/node.o src/lib/config/node.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/config/option.o src/lib/config/option.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/config/option.cc:15:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# src/lib/config/option.cc: In member function ‘virtual void NLP::Config::Alias::check()’:
# src/lib/config/option.cc:108:22: warning: catching polymorphic type ‘class NLP::ConfigError’ by value [-Wcatch-value=]
#   108 |   }catch(ConfigError e){
#       |                      ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/config/config.o src/lib/config/config.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/config/config.cc:15:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# src/lib/config/config.cc: In member function ‘virtual bool NLP::Config::Cfg::has(const string&) const’:
# src/lib/config/config.cc:126:22: warning: catching polymorphic type ‘class NLP::ConfigError’ by value [-Wcatch-value=]
#   126 |   }catch(ConfigError e){
#       |                      ^
# src/lib/config/config.cc: In member function ‘virtual NLP::Config::Node& NLP::Config::Cfg::get(const string&)’:
# src/lib/config/config.cc:153:22: warning: catching polymorphic type ‘class NLP::ConfigError’ by value [-Wcatch-value=]
#   153 |   }catch(ConfigError e){
#       |                      ^
# src/lib/config/config.cc: In member function ‘virtual void NLP::Config::Cfg::check()’:
# src/lib/config/config.cc:166:22: warning: catching polymorphic type ‘class NLP::ConfigError’ by value [-Wcatch-value=]
#   166 |   }catch(ConfigError e){
#       |                      ^
# src/lib/config/config.cc: In instantiation of ‘void NLP::Config::load_config(Cfg&, NLP::Config::RecursiveCheck&, std::istream&, const string&) [with Cfg = NLP::Config::Cfg; NLP::Config::RecursiveCheck = std::map<std::__cxx11::basic_string<char>, int>; std::istream = std::basic_istream<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/lib/config/config.cc:176:27:   required from here
# src/lib/config/config.cc:70:23: warning: catching polymorphic type ‘class NLP::ConfigError’ by value [-Wcatch-value=]
#    70 |     catch(ConfigError e) {
#       |                       ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/format.o src/lib/io/format.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/stream.o src/lib/io/stream.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/reader.o src/lib/io/reader.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/reader_group.o src/lib/io/reader_group.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/reader_horiz.o src/lib/io/reader_horiz.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/reader_multi_horiz.o src/lib/io/reader_multi_horiz.cc
# src/lib/io/reader_multi_horiz.cc: In member function ‘virtual bool NLP::IO::MultiHReader::next(NLP::Sentence&, bool, bool)’:
# src/lib/io/reader_multi_horiz.cc:65:23: warning: this statement may fall through [-Wimplicit-fallthrough=]
#    65 |         case '\0': die(msg << "unexpected end of sentence (missing separator and field '" << *field << "')");
#       |                    ~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/lib/io/reader_multi_horiz.cc:66:9: note: here
#    66 |         case ' ': die(msg << "whitespace at the end of the sentence is illegal");
#       |         ^~~~
# src/lib/io/reader_multi_horiz.cc:66:22: warning: this statement may fall through [-Wimplicit-fallthrough=]
#    66 |         case ' ': die(msg << "whitespace at the end of the sentence is illegal");
#       |                   ~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/lib/io/reader_multi_horiz.cc:67:9: note: here
#    67 |         default:
#       |         ^~~~~~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/reader_factory.o src/lib/io/reader_factory.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/writer.o src/lib/io/writer.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/writer_stream.o src/lib/io/writer_stream.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/writer_group.o src/lib/io/writer_group.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/writer_horiz.o src/lib/io/writer_horiz.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/writer_multi_horiz.o src/lib/io/writer_multi_horiz.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/writer_vert.o src/lib/io/writer_vert.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/writer_multi_vert.o src/lib/io/writer_multi_vert.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/writer_format.o src/lib/io/writer_format.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/writer_factory.o src/lib/io/writer_factory.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/tagdict.o src/lib/tagger/tagdict.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/tagsetdict.o src/lib/tagger/tagsetdict.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/_baseimpl.o src/lib/tagger/_baseimpl.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/_baseimpl.cc:18:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/_baseimpl.h:42,
#                  from src/lib/tagger/_baseimpl.cc:18:
# src/include/tagger/lattice.h: In member function ‘void NLP::Taggers::Node::update(const NLP::Taggers::Node*, float)’:
# src/include/tagger/lattice.h:42:27: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    42 |         this->pid = prev->id;
#       |                           ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/_baseimpl.cc:18:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/_baseimpl.cc:18:
# src/include/tagger/_baseimpl.h: In member function ‘void NLP::Taggers::Tagger::Impl::_calc_greedy_probs(NLP::Taggers::State&, ulong, double) const’:
# src/include/tagger/_baseimpl.h:489:21: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   489 |     hist.pid = hist.id;
#       |                     ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/_baseimpl.cc:18:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/_baseimpl.cc:18:
# src/include/tagger/_baseimpl.h:490:15: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   490 |     hist.id = max_tag;
#       |               ^~~~~~~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/_baseimpl.cc:18:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# src/lib/tagger/_baseimpl.cc: In member function ‘void NLP::Taggers::Tagger::Impl::_read_attributes(const NLP::Model::Model&, const NLP::Model::Info&, std::vector<NLP::Model::Feature*>&)’:
# src/lib/tagger/_baseimpl.cc:133:25: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   133 |   }catch(NLP::Exception e){
#       |                         ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/tagger.o src/lib/tagger/tagger.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/tagger.cc:11:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/_baseimpl.h:42,
#                  from src/lib/tagger/tagger.cc:11:
# src/include/tagger/lattice.h: In member function ‘void NLP::Taggers::Node::update(const NLP::Taggers::Node*, float)’:
# src/include/tagger/lattice.h:42:27: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    42 |         this->pid = prev->id;
#       |                           ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/tagger.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/tagger.cc:11:
# src/include/tagger/_baseimpl.h: In member function ‘void NLP::Taggers::Tagger::Impl::_calc_greedy_probs(NLP::Taggers::State&, ulong, double) const’:
# src/include/tagger/_baseimpl.h:489:21: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   489 |     hist.pid = hist.id;
#       |                     ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/tagger.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/tagger.cc:11:
# src/include/tagger/_baseimpl.h:490:15: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   490 |     hist.id = max_tag;
#       |               ^~~~~~~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/tagger.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/taghist.o src/lib/tagger/taghist.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/types.o src/lib/model/types.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/types.cc:24:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/registry.o src/lib/model/registry.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/registry.cc:23:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/affix.o src/lib/model/affix.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/affix.cc:18:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/unigram.o src/lib/model/unigram.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/unigram.cc:21:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/bigram.o src/lib/model/bigram.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/bigram.cc:21:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/trigram.o src/lib/model/trigram.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/trigram.cc:21:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/model.o src/lib/model/model.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/model.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/cache.o src/lib/model/cache.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/gazetteers.o src/lib/gazetteers.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/unigram.o src/lib/tagger/unigram.cc
# src/lib/tagger/unigram.cc: In member function ‘void NLP::Taggers::Unigram::_Impl::load(std::string)’:
# src/lib/tagger/unigram.cc:75:44: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    75 |           add(word)->value = tagset[max_tag];
#       |                                            ^
# In file included from src/include/base.h:48,
#                  from src/lib/tagger/unigram.cc:19:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# src/lib/tagger/unigram.cc:89:40: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    89 |       add(word)->value = tagset[max_tag];
#       |                                        ^
# In file included from src/include/base.h:48,
#                  from src/lib/tagger/unigram.cc:19:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/pos.o src/lib/tagger/pos.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/pos.cc:17:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/_baseimpl.h:42,
#                  from src/lib/tagger/pos.cc:17:
# src/include/tagger/lattice.h: In member function ‘void NLP::Taggers::Node::update(const NLP::Taggers::Node*, float)’:
# src/include/tagger/lattice.h:42:27: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    42 |         this->pid = prev->id;
#       |                           ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/pos.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/pos.cc:17:
# src/include/tagger/_baseimpl.h: In member function ‘void NLP::Taggers::Tagger::Impl::_calc_greedy_probs(NLP::Taggers::State&, ulong, double) const’:
# src/include/tagger/_baseimpl.h:489:21: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   489 |     hist.pid = hist.id;
#       |                     ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/pos.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/pos.cc:17:
# src/include/tagger/_baseimpl.h:490:15: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   490 |     hist.id = max_tag;
#       |               ^~~~~~~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/pos.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/pos.o src/main/pos.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/pos.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/pos.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/cluster_no_mpi.o src/lib/cluster_no_mpi.cc
# g++ -fPIC -o bin/pos src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/pos.o src/main/pos.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/mpos.o src/main/mpos.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/mpos.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/mpos.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/mpos src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/pos.o src/main/mpos.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/chunk.o src/lib/tagger/chunk.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/chunk.cc:11:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/_baseimpl.h:42,
#                  from src/lib/tagger/chunk.cc:11:
# src/include/tagger/lattice.h: In member function ‘void NLP::Taggers::Node::update(const NLP::Taggers::Node*, float)’:
# src/include/tagger/lattice.h:42:27: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    42 |         this->pid = prev->id;
#       |                           ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/chunk.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/chunk.cc:11:
# src/include/tagger/_baseimpl.h: In member function ‘void NLP::Taggers::Tagger::Impl::_calc_greedy_probs(NLP::Taggers::State&, ulong, double) const’:
# src/include/tagger/_baseimpl.h:489:21: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   489 |     hist.pid = hist.id;
#       |                     ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/chunk.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/chunk.cc:11:
# src/include/tagger/_baseimpl.h:490:15: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   490 |     hist.id = max_tag;
#       |               ^~~~~~~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/chunk.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/chunk.o src/main/chunk.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/chunk.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/chunk.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/chunk src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/chunk.o src/main/chunk.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/mchunk.o src/main/mchunk.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/mchunk.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/mchunk.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/mchunk src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/chunk.o src/main/mchunk.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/ner.o src/lib/tagger/ner.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/ner.cc:17:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/_baseimpl.h:42,
#                  from src/lib/tagger/ner.cc:17:
# src/include/tagger/lattice.h: In member function ‘void NLP::Taggers::Node::update(const NLP::Taggers::Node*, float)’:
# src/include/tagger/lattice.h:42:27: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    42 |         this->pid = prev->id;
#       |                           ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/ner.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/ner.cc:17:
# src/include/tagger/_baseimpl.h: In member function ‘void NLP::Taggers::Tagger::Impl::_calc_greedy_probs(NLP::Taggers::State&, ulong, double) const’:
# src/include/tagger/_baseimpl.h:489:21: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   489 |     hist.pid = hist.id;
#       |                     ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/ner.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/ner.cc:17:
# src/include/tagger/_baseimpl.h:490:15: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   490 |     hist.id = max_tag;
#       |               ^~~~~~~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/ner.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# src/lib/tagger/ner.cc: In member function ‘void NLP::Taggers::NER::Impl::add_special(const RawWord&, NLP::PDF&) const’:
# src/lib/tagger/ner.cc:206:17: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   206 |         case 1: if(types.use_one_digit())
#       |                 ^~
# src/lib/tagger/ner.cc:208:19: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   208 |                   break;
#       |                   ^~~~~
# src/lib/tagger/ner.cc:209:17: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   209 |         case 2: if(types.use_two_digits())
#       |                 ^~
# src/lib/tagger/ner.cc:211:19: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   211 |                   break;
#       |                   ^~~~~
# src/lib/tagger/ner.cc:212:17: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   212 |         case 3: if(types.use_three_digits())
#       |                 ^~
# src/lib/tagger/ner.cc:214:19: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   214 |                   break;
#       |                   ^~~~~
# src/lib/tagger/ner.cc:215:17: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   215 |         case 4: if(types.use_four_digits())
#       |                 ^~
# src/lib/tagger/ner.cc:217:19: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   217 |                   break;
#       |                   ^~~~~
# src/lib/tagger/ner.cc:218:18: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   218 |         default: if(types.use_digits())
#       |                  ^~
# src/lib/tagger/ner.cc:220:19: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   220 |                   break;
#       |                   ^~~~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/ner.o src/main/ner.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/ner.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/ner.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/ner src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/ner.o src/main/ner.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/mner.o src/main/mner.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/mner.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/mner.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/mner src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/ner.o src/main/mner.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/super.o src/lib/tagger/super.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/super.cc:11:
# ...
#                  from src/main/candc.cc:13:
# src/include/parser/category.h:239:23: warning: implicitly-declared ‘NLP::CCG::VarID& NLP::CCG::VarID::operator=(const NLP::CCG::VarID&)’ is deprecated [-Wdeprecated-copy]
#   239 |         var = seen[var];
#       |                       ^
# In file included from src/include/parser/parser.h:15,
#                  from src/include/candc.h:39,
#                  from src/main/candc.cc:13:
# src/include/parser/varid.h:42:7: note: because ‘NLP::CCG::VarID’ has user-provided ‘NLP::CCG::VarID::VarID(const NLP::CCG::VarID&)’
#    42 |       VarID(const VarID &other): Fixed(other) {}
#       |       ^~~~~
# In file included from src/include/parser/parser.h:16,
#                  from src/include/candc.h:39,
#                  from src/main/candc.cc:13:
# src/include/parser/category.h: In member function ‘void NLP::CCG::Cat::order(NLP::CCG::VarID*, NLP::CCG::VarID*, NLP::CCG::VarID&) const’:
# src/include/parser/category.h:245:34: warning: implicitly-declared ‘NLP::CCG::VarID& NLP::CCG::VarID::operator=(const NLP::CCG::VarID&)’ is deprecated [-Wdeprecated-copy]
#   245 |             seen[trans[var]] = ++order;
#       |                                  ^~~~~
# In file included from src/include/parser/parser.h:15,
#                  from src/include/candc.h:39,
#                  from src/main/candc.cc:13:
# src/include/parser/varid.h:42:7: note: because ‘NLP::CCG::VarID’ has user-provided ‘NLP::CCG::VarID::VarID(const NLP::CCG::VarID&)’
#    42 |       VarID(const VarID &other): Fixed(other) {}
#       |       ^~~~~
# In file included from src/include/parser/parser.h:16,
#                  from src/include/candc.h:39,
#                  from src/main/candc.cc:13:
# src/include/parser/category.h:250:34: warning: implicitly-declared ‘NLP::CCG::VarID& NLP::CCG::VarID::operator=(const NLP::CCG::VarID&)’ is deprecated [-Wdeprecated-copy]
#   250 |             seen[trans[var]] = ++order;
#       |                                  ^~~~~
# In file included from src/include/parser/parser.h:15,
#                  from src/include/candc.h:39,
#                  from src/main/candc.cc:13:
# src/include/parser/varid.h:42:7: note: because ‘NLP::CCG::VarID’ has user-provided ‘NLP::CCG::VarID::VarID(const NLP::CCG::VarID&)’
#    42 |       VarID(const VarID &other): Fixed(other) {}
#       |       ^~~~~
# gcc -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include -w -c -o src/lib/relations/morpha.o src/lib/relations/morpha.c
# g++ -fPIC -o bin/candc src/lib/candc.o src/main/candc.o src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/parser/atom.o src/lib/parser/feature.o src/lib/parser/varid.o src/lib/parser/category.o src/lib/parser/markedup.o src/lib/parser/categories.o src/lib/parser/gr.o src/lib/parser/gr_constraints.o src/lib/parser/relations.o src/lib/parser/supercat.o src/lib/parser/equiv.o src/lib/parser/chart.o src/lib/parser/unify.o src/lib/parser/treebank.o src/lib/parser/variable.o src/lib/parser/rule.o src/lib/tree/catvalue.o src/lib/tree/dependency.o src/lib/tree/distance.o src/lib/tree/rule.o src/lib/tree/depdist.o src/lib/tree/genrule.o src/lib/parser/rule_instances.o src/lib/parser/parser.o src/lib/parser/depscore.o src/lib/parser/canonical.o src/lib/parser/generator.o src/lib/parser/constraint.o src/lib/parser/print_deps.o src/lib/parser/print_prolog.o src/lib/parser/print_boxer.o src/lib/parser/print_ccgbank.o src/lib/parser/print_grs.o src/lib/parser/print_xml.o src/lib/parser/print_debug.o src/lib/parser/print_js.o src/lib/parser/print_latex.o src/lib/parser/print_factory.o src/lib/parser/decoder.o src/lib/parser/decoder_derivs.o src/lib/parser/decoder_derivs_random.o src/lib/parser/decoder_deps_recall.o src/lib/parser/decoder_factory.o src/lib/parser/beam.o src/lib/parser/count_rules.o src/lib/parser/print_forest.o src/lib/parser/inside_outside.o src/lib/parser/feature_root.o src/lib/parser/feature_rule.o src/lib/parser/feature_rule_head.o src/lib/parser/feature_dep.o src/lib/parser/feature_dep_dist.o src/lib/parser/feature_rule_dep.o src/lib/parser/feature_rule_dep_dist.o src/lib/parser/feature_genrule.o src/lib/parser/integration.o src/lib/tagger/pos.o src/lib/tagger/chunk.o src/lib/tagger/ner.o src/lib/tagger/super.o src/lib/relations/morpha.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/reestimate.o src/main/reestimate.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/main/reestimate.cc:18:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/main/reestimate.cc:20:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/reestimate src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/maxent/gis.o src/lib/maxent/bfgs.o src/lib/maxent/perceptron.o src/lib/extract/_baseimpl.o src/lib/extract/attributes.o src/lib/extract/contexts.o src/main/reestimate.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# make: *** No rule to make target 'ext/bin/soapcpp2', needed by 'soap'.  Stop.
# bin/swipl -g "['src/prolog/nutcracker/ntokkie'], qsave_program('bin/t',[goal=start,stand_alone=true]), halt."
# %   library(error) compiled into error 0.00 sec, 81 clauses
# %   library(pairs) compiled into pairs 0.00 sec, 22 clauses
# %  library(lists) compiled into lists 0.01 sec, 206 clauses
# %   library(shlib) compiled into shlib 0.00 sec, 39 clauses
# %   library(option) compiled into swi_option 0.00 sec, 32 clauses
# %  library(readutil) compiled into read_util 0.01 sec, 112 clauses
# %  semlib(abbreviations) compiled into abbreviations 0.00 sec, 46 clauses
# %   semlib(options) compiled into options 0.00 sec, 112 clauses
# %  semlib(errors) compiled into errors 0.00 sec, 123 clauses
# % src/prolog/nutcracker/ntokkie compiled 0.02 sec, 635 clauses
# % autoloading prolog_codewalk:must_be/2 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/error
# % autoloading prolog_debug:backtrace/1 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_stack
# % autoloading oset:reverse/2 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/lists
# % autoloading record:member/2 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/lists
# % autoloading error:assertion/1 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/debug
# % autoloading qsave:current_foreign_library/2 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/shlib
# % autoloading prolog_codewalk:portray_clause/1 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/listing
# % autoloading prolog_codewalk:clause_info/4 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % autoloading prolog_codewalk:initialization_layout/4 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % autoloading prolog_codewalk:clause_name/2 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % Autoloader: iteration 1 resolved 9 predicates and loaded 10 files in 0.060 seconds.  Restarting ...
# % Autoloader: loaded 9 files in 2 iterations in 0.084 seconds
# src/scripts/version unix
# src/scripts/version: line 53: svnversion: command not found
# Usage: grep [OPTION]... PATTERNS [FILE]...
# Try 'grep --help' for more information.
# bin/swipl -g "['src/prolog/boxer/boxer'], qsave_program('bin/boxer',[global=128000,local=128000,goal=start,stand_alone=true]), halt."
# %   library(error) compiled into error 0.00 sec, 81 clauses
# %   library(pairs) compiled into pairs 0.00 sec, 22 clauses
# %  library(lists) compiled into lists 0.01 sec, 206 clauses
# %   boxer(slashes) compiled into slashes 0.00 sec, 5 clauses
# %      semlib(options) compiled into options 0.00 sec, 112 clauses
# %     semlib(errors) compiled into errors 0.00 sec, 123 clauses
# %    boxer(alphaConversionDRT) compiled into alphaConversionDRT 0.00 sec, 166 clauses
# %     boxer(noncomp) compiled into noncomp 0.00 sec, 17 clauses
# %    boxer(mergeDRT) compiled into mergeDRT 0.00 sec, 89 clauses
# %   boxer(betaConversionDRT) compiled into betaConversionDRT 0.01 sec, 293 clauses
# %    boxer(bindingViolation) compiled into bindingViolation 0.00 sec, 33 clauses
# %    boxer(freeVarCheck) compiled into freeVarCheck 0.00 sec, 57 clauses
# %     lex(verbnet) compiled into verbnet 0.48 sec, 30,594 clauses
# %    boxer(categories) compiled into categories 0.48 sec, 30,662 clauses
# %    knowledge(antecedent) compiled into antecedent 0.01 sec, 825 clauses
# %   boxer(resolveDRT) compiled into resolveDRT 0.50 sec, 31,717 clauses
# %    boxer(morpha) compiled into morpha 0.00 sec, 62 clauses
# %   boxer(transform) compiled into transform 0.01 sec, 164 clauses
# %    knowledge(relations) compiled into relations 0.08 sec, 9,437 clauses
# %   boxer(relation) compiled into relation 0.08 sec, 9,460 clauses
# %     boxer(string2digit) compiled into string2digit 0.00 sec, 42 clauses
# %     knowledge(ne) compiled into ne 0.00 sec, 32 clauses
# %     knowledge(dates) compiled into dates 0.00 sec, 155 clauses
# %     knowledge(punctuation) compiled into punctuation 0.00 sec, 13 clauses
# %     lex(determiners) compiled into determiners 0.00 sec, 33 clauses
# %      lex(tense) compiled into tense 0.00 sec, 18 clauses
# %     lex(verbs) compiled into verbs 0.01 sec, 110 clauses
# %     boxer(coordination) compiled into coordination 0.00 sec, 11 clauses
# %     (lex/pp) compiled into lexicon 0.00 sec, 27 clauses
# %     (lex/n) compiled into lexicon 0.01 sec, 93 clauses
# %    boxer(lexicon) compiled into lexicon 0.05 sec, 844 clauses
# %   boxer(closure) compiled into closure 0.05 sec, 881 clauses
# %   boxer(typechange) compiled into typechange 0.00 sec, 26 clauses
# %   boxer(evaluation) compiled into evaluation 0.00 sec, 6 clauses
# %   boxer(input) compiled into input 0.00 sec, 23 clauses
# %   boxer(sdrt) compiled into sdrt 0.00 sec, 27 clauses
# %   boxer(drs2fdrs) compiled into drs2fdrs 0.00 sec, 76 clauses
# %    semlib(drs2tacitus) compiled into drs2tacitus 0.00 sec, 104 clauses
# %   boxer(tuples) compiled into tuples 0.01 sec, 235 clauses
# %    knowledge(amrmfs) compiled into amrmfs 0.00 sec, 244 clauses
# %    knowledge(verbalization-list-v1.01) compiled into verbalization 0.00 sec, 475 clauses
# %    knowledge(role91) compiled into role91 0.00 sec, 121 clauses
# %    knowledge(negprefix) compiled into negprefix 0.02 sec, 1,597 clauses
# %    knowledge(negsuffix) compiled into negsuffix 0.01 sec, 472 clauses
# %    knowledge(nationality) compiled into nationality 0.01 sec, 305 clauses
# %    knowledge(wiki) compiled into wiki 0.05 sec, 3,158 clauses
# %   semlib(drs2amr) compiled into drs2amr 0.11 sec, 6,840 clauses
# %   semlib(pdrs2drs) compiled into pdrs2drs 0.00 sec, 35 clauses
# %   semlib(drs2fol) compiled into drs2fol 0.01 sec, 126 clauses
# %  boxer(ccg2drs) compiled into ccg2drs 0.79 sec, 50,070 clauses
# %  boxer(version) compiled into version 0.00 sec, 2 clauses
# %  boxer(printCCG) compiled into printCCG 0.00 sec, 53 clauses
# %   boxer(xdrs2xml) compiled into xdrs2xml 0.01 sec, 127 clauses
# %   boxer(printDrs) compiled into printDrs 0.00 sec, 106 clauses
# %   semlib(drs2tex) compiled into drs2tex 0.00 sec, 32 clauses
# %  boxer(output) compiled into output 0.02 sec, 338 clauses
# % src/prolog/boxer/boxer compiled 0.81 sec, 50,723 clauses
# % autoloading prolog_codewalk:(must_be/2) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/error
# % autoloading prolog_debug:(backtrace/1) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_stack
# % autoloading oset:(reverse/2) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/lists
# % autoloading record:(member/2) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/lists
# % autoloading error:(assertion/1) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/debug
# % autoloading qsave:(current_foreign_library/2) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/shlib
# % autoloading prolog_codewalk:(portray_clause/1) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/listing
# % autoloading prolog_codewalk:(clause_info/4) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % autoloading prolog_codewalk:(initialization_layout/4) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % autoloading prolog_codewalk:(clause_name/2) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % Autoloader: iteration 1 resolved 10 predicates and loaded 10 files in 0.103 seconds.  Restarting ...
# % Autoloader: loaded 10 files in 2 iterations in 0.173 seconds
# models/
# models/config
# models/pos
# models/super
# models/parser/
# models/parser/log
# models/parser/cats/
# models/parser/cats/markedup
# models/parser/cats/trAP
# models/parser/cats/trNP
# models/parser/cats/trPP
# models/parser/cats/trPP_qus
# models/parser/cats/trVP_to
# models/parser/features
# models/parser/lexicon
# models/parser/rules
# models/parser/model.config
# models/parser/info
# models/parser/weights
# models/parser/stats
# models/parser/config
# models/pos_quotes/
# models/pos_quotes/log
# models/pos_quotes/classes
# models/pos_quotes/lexicon
# models/pos_quotes/tagdict
# models/pos_quotes/attributes
# models/pos_quotes/unknowns
# models/pos_quotes/number_unknowns
# models/pos_quotes/info
# models/pos_quotes/config
# models/pos_quotes/weights

# %%
# # Gera boxer em xml
# command = "./install_candc.sh"
# subprocess.run(command, shell=True, check=True, capture_output=True)

# %%
# Import das bibliotecas.
import sys # Biblioteca para acessar módulos do sistema

# Se estiver executando no Google Colaboratory
# Retorna true ou false se estiver no Google Colaboratory
IN_COLAB = "google.colab" in sys.modules

# %%
# Importando as bibliotecas.
import os

# Cria o diretório para receber os arquivos Originais e Permutados
# Diretório a ser criado
dirbase = DIRETORIO_LOCAL[:-1]

if not os.path.exists(dirbase):
    # Cria o diretório
    os.makedirs(dirbase)
    logging.info("Diretório criado: {}".format(dirbase))
else:
    logging.info("Diretório já existe: {}".format(dirbase))

# %% [markdown]
# ## Verifica se arquivos estão corretos

# %%
os.chdir('/content/learningbyreading/ext/candc')
# !ls

# %%
#!chmod +x bin/candc
# !bin/candc --version
# !bin/boxer --version

# %% [markdown]
# Roda teste

# %% [markdown]
# #Importa word2vec

# %%
import re
import numpy as np

# %%
from nltk.corpus import wordnet as wn
from scipy.spatial.distance import cosine
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# #Carrega word2vec

# %%
# from gensim.models import KeyedVectors
# import gensim.downloader as api

# # Carregar o modelo Word2Vec
# word2vec_model = api.load('glove-wiki-gigaword-300')

# %%
# word2vec_model.init_sims(replace=True)

# %% [markdown]
# #Carrega bert

# %%
from transformers import BertTokenizer, BertModel
import torch

# Inicializa o tokenizer e o modelo
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased',
                                          do_lower_case=False)
model = BertModel.from_pretrained('bert-base-multilingual-cased',
                                  output_attentions=False,
                                  output_hidden_states=True)

# Função para obter embeddings do BERT
def get_bert_embeddings(text):
    # Tokeniza a entrada e converte para tensor
    inputs = tokenizer(text, return_tensors="pt")

    # Obtém os embeddings
    with torch.no_grad():
        outputs = model(**inputs)

    # Retorna os embeddings da última camada
    return outputs.last_hidden_state

# %%
# from transformers import BertTokenizer, BertModel
# import torch

# # Initialize the tokenizer and the model
# tokenizer = BertTokenizer.from_pretrained('bert-large-cased')
# model = BertModel.from_pretrained('bert-large-cased')

# # Set the model to evaluation mode
# model.eval()

# # Function to obtain BERT embeddings
# def get_bert_embeddings(text_list):
#     # Ensure text_list is not empty
#     if not text_list:
#         return None

#     # Tokenize the input batch and convert to tensors
#     inputs = tokenizer(text_list, return_tensors="pt", padding=True, truncation=True)

#     # Obtain the embeddings
#     with torch.no_grad():
#         outputs = model(**inputs)

#     # Return the embeddings from the last layer
#     return outputs.last_hidden_state

# # Example usage
# text_list = ["This is an example sentence.", "Another sentence for illustration."]
# embeddings = get_bert_embeddings(text_list)
# print(embeddings.shape)  # Print the shape of the embeddings tensor

# %%
# Exemplo de uso
embeddings = get_bert_embeddings("Hello, world!")
print(embeddings)

# %% [markdown]
# # Importa Paragram300

# %%
# from gensim.models import KeyedVectors

# # Path to the downloaded model files
# model_path = DIRETORIO_DRIVE + 'paragram-300-sl999.model'

# # # Carregar o modelo Word2Vec
# word2vec_model = KeyedVectors.load(model_path)

# %%
# word2vec_model.init_sims(replace=True)

# %% [markdown]
# #Define função do grafo

# %%
class Graph:
    def __init__(self, sentence: str, debug: bool = False):
        self.words = sentence.split(" ")
        self.count = len([word for word in self.words if len(word) > 0])
        self.gLen = self.count
        self.nodes = [None] * (self.count * 2)  # Armazenamento para conceitos
        self.edges = [None] * (self.count * 2)  # Armazenamento para arestas
        self.conceptCount = 0  # Contador para conceitos
        self.edgeCount = 0  # Contador para arestas
        self.repeated = 0
        self.autoInc = 0  # Variável para auto-incremento
        self.debug = debug  # Variável para debug

        if debug:
            print(sentence)

    def get_vector(self, word):
        return word2vec_model[word] if word in word2vec_model else np.zeros(word2vec_model.vector_size)

    def get_vector_bert(self, dic, word):
      # Sua lógica para obter o vetor BERT
      return dic[word] if word in dic else np.zeros(len(next(iter(dic.values()))))

    def getCode(self):
        # Implementação do método getCode
        code = f"ma{self.autoInc}"
        self.autoInc += 1
        return code

    def addConcept(self, name: str, code: str, pos: str):
        # Verifica se o conceito já existe e adiciona uma nova instância se necessário
        for i in range(self.conceptCount):
            if self.nodes[i]['code'] == code:
                nCode = self.getCode()
                self.addConcept(name, nCode, pos)
                rName = self.getCode()
                self.addRelationIn("equality", rName, code)
                self.addRelationEx("equality", rName, nCode)
                return

        # Expandir a lista se necessário
        if self.conceptCount >= len(self.nodes):
            self.nodes.append(None)

        # Adicionar o novo conceito
        self.nodes[self.conceptCount] = {'lemma': name, 'code': code, 'pos': pos}
        self.conceptCount += 1

    def addRelationIn(self, name: str, code: str, in_relation: str):
        found = False
        for i in range(self.edgeCount):
            if self.edges[i]['code'] == code:
                found = True
                self.edges[i]['in'] = in_relation
                break
        if not found:
            if self.edgeCount >= len(self.edges):
                self.edges.append(None)  # Expande a lista
            self.edges[self.edgeCount] = {'code': code, 'name': name, 'in': in_relation}
            self.edgeCount += 1

    def addRelationEx(self, name: str, code: str, ex: str):
        found = False
        for i in range(self.edgeCount):
            if self.edges[i]['code'] == code:
                found = True
                self.edges[i]['ex'] = ex
                break
        if not found:
            if self.edgeCount >= len(self.edges):
                self.edges.append(None)  # Expande a lista
            self.edges[self.edgeCount] = {'code': code, 'name': name, 'ex': ex}
            self.edgeCount += 1

    def addIsRelation(self, name: str, code: str):
        found = False
        for i in range(self.edgeCount):
            if self.edges[i]['code'] == code:
                self.edges[i]['name'] = name
                return
        self.edges[self.edgeCount] = {'code': code, 'name': name}
        self.edgeCount += 1

    def getWeight(self, relation: str) -> int:
        if relation == "equality":
            return 1
        elif relation == "is":
            return 4
        elif relation == "rep":
            return 1
        elif relation == "for":
            return 1
        elif relation == "on":
            return 1
        elif relation == "of":
            return 1
        elif relation == "in":
            return 3
        elif relation == "experiencer":
            return 6
        elif relation == "agent":
            return 8
        elif relation == "theme":
            return 8
        else:
            return 1

    def printNodes(self):
        for i in range(self.conceptCount):
            node = self.nodes[i]
            print(f"{node['code']}   {node['lemma']}   {node['pos']}")

    def printEdges(self):
        for i in range(self.edgeCount):
            edge = self.edges[i]
            print(f"{edge['name']}\t{edge.get('in', '')}\t{edge.get('ex', '')}")

    def getNode(self, code: str):
        for i in range(self.conceptCount):
            if self.nodes[i] and self.nodes[i]['code'] == code:
                return self.nodes[i]

        for i in range(self.edgeCount):
            edge = self.edges[i]
            if edge:
                if 'name' in edge and edge['name'] == "equality":
                    if 'ex' in edge and edge['ex'] == code:
                        in_code = edge.get('in')  # Use .get() to avoid KeyError
                        if in_code:
                            return self.getNode(in_code)
        return None  # Return None or a default value if no node is found

    def finalize(self):
        for i in range(self.edgeCount):
            if self.edges[i]['name'] == "is":
                for j in range(self.edgeCount):
                    if self.edges[i]['code'] == self.edges[j]['code']:
                        self.edges[i]['ex'] = self.edges[j]['ex']
                        self.edges[i]['in'] = self.edges[j]['in']
                        print("found")
                        break

    def checkGraph(self) -> bool:
            if self.debug:
                for i in range(self.conceptCount):
                    node = self.nodes[i]
                    if node:
                        print(f"{node['code']}   {node['lemma']}")

            for i in range(self.edgeCount):
                print(i)
                edge = self.edges[i]
                print(edge)
                if edge:
                    in_node_obj = self.getNode(edge.get('in'))
                    ex_node_obj = self.getNode(edge.get('ex'))

                    in_node = in_node_obj['lemma'] if in_node_obj is not None else None
                    ex_node = ex_node_obj['lemma'] if ex_node_obj is not None else None

                    print(f"{in_node}  {edge['name']}   {ex_node}")

                    if edge['name'] == "equality" and in_node == ex_node:
                        self.repeated += 1

                    for j in range(self.edgeCount):
                        other_edge = self.edges[j]
                        if other_edge and edge['name'] == other_edge['name']:
                            in_node_other_obj = self.getNode(other_edge.get('in'))
                            ex_node_other_obj = self.getNode(other_edge.get('ex'))
                            in_node_other = in_node_other_obj['lemma'] if in_node_other_obj is not None else None
                            ex_node_other = ex_node_other_obj['lemma'] if ex_node_other_obj is not None else None

                            if in_node == in_node_other and ex_node == ex_node_other:
                                other_edge['name'] = "rep"
                                self.repeated += 1

            return True if self.repeated > 0 else False

    def matchRelationNameSTS(self, r1, r2):
        print(f"{r1}    {r2}")
        if r1 == "rep" or r2 == "rep":
            return 0.5
        if r1 == "topic" or r2 == "topic":
            return 0.3
        if r1 == "is" and r2 == "is":
            return 0.7
        if r1 == "equality" and r2 == "equality":
            return 0.7
        if r1 == "rep":
            return 0.0
        if r1 == r2:
            return 1
        if (r1 == "experiencer" and r2 == "of") or (r1 == "of" and r2 == "experiencer"):
            return 0.8
        if (r1 == "theme" and r2 == "agent") or (r1 == "agent" and r2 == "theme"):
            return 0.6
        else:
            return 0.79 - 0.01 * (self.getWeight(r1) + self.getWeight(r2))

    # Convertendo a função matchRelationName para Python
    def matchRelationName(self, r1: str, r2: str) -> float:
        if r1 == "is" and r2 == "is":
            return 0.7
        if r1 == "equality" and r2 == "equality":
            return 0.7
        if r1 == "rep":
            return 0.0
        if r1 == r2:
            return 1.0
        else:
            return 0.73


    # Corrigindo a função stringSim uma última vez
    def stringSim(self, s1: str, s2: str) -> float:
        m, n = len(s1), len(s2)

        if m == 0 and n == 0: return 1.0
        if m == 0 or n == 0: return 0.0

        costs = [0] * (n + 1)

        # Initialize the array
        for k in range(n + 1):
            costs[k] = k

        for i, c1 in enumerate(s1):
            costs[0] = i + 1
            corner = i

            for j, c2 in enumerate(s2):
                upper = costs[j + 1]
                if c1 == c2:
                    costs[j + 1] = corner
                else:
                    t = min(upper, corner)
                    costs[j + 1] = min(costs[j], t) + 1
                corner = upper

        result = costs[n]
        return 1 - float(result) / max(m, n)

    def expand(self, word):
      ewords = [word]
      for edge in self.edges:
          if edge and edge['name'] in ["equality", "is", "of"]:
              node_ex = self.getNode(edge['ex'])
              node_in = self.getNode(edge['in'])

              if node_ex and node_ex['lemma'] == word:
                  ewords.append(node_in['lemma']) if node_in else None
              elif node_in and node_in['lemma'] == word:
                  ewords.append(node_ex['lemma']) if node_ex else None

      return ewords

# %% [markdown]
# #GraphSTSBert

# %%
class GraphSTSBert(Graph):
    def __init__(self, sentence: str, debug: bool = False):
        super().__init__(sentence, debug)

    def matchConceptBert(self, dic1, dic2, c1, c2):
        vec1 = self.get_vector_bert(dic1, c1)
        vec2 = self.get_vector_bert(dic2, c2)
        # Similaridade do cosseno
        return 1 - cosine(vec1, vec2) if np.any(vec1) and np.any(vec2) else 0

    def matchConceptWithExpansionBert(self, dic1, dic2, g1, c1, g2, c2):
        all1 = g1.expand(c1)
        all2 = g2.expand(c2)
        print("expansions:", all1, all2)
        max_similarity = 0

        for word1 in all1:
            for word2 in all2:
                similarity = self.matchConceptBert(dic1, dic2, word1, word2)
                if similarity > max_similarity:
                    max_similarity = similarity

        return max_similarity

    def matchRelationBert(self, dic1, dic2, g1, r1, g2, r2):
        node_g1_in = g1.getNode(r1['in'])
        node_g1_ex = g1.getNode(r1['ex'])
        node_g2_in = g2.getNode(r2['in'])
        node_g2_ex = g2.getNode(r2['ex'])

        # Verifica se algum dos nós é None e retorna 0 em tal caso
        if not all([node_g1_in, node_g1_ex, node_g2_in, node_g2_ex]):
            return 0

        node_in_g1 = node_g1_in['lemma']
        node_ex_g1 = node_g1_ex['lemma']
        node_in_g2 = node_g2_in['lemma']
        node_ex_g2 = node_g2_ex['lemma']

        # d1 = self.matchConceptWithExpansionBert(dic1, dic2, g1, node_in_g1, g2, node_in_g2)
        # d2 = self.matchConceptWithExpansionBert(dic2, dic2, g1, node_ex_g1, g2, node_ex_g2)
        d1 = self.matchConceptBert(dic1, dic2, node_in_g1, node_in_g2)
        d2 = self.matchConceptBert(dic1, dic2, node_ex_g1, node_ex_g2)
        d3 = self.matchRelationNameSTS(r1['name'], r2['name'])

        return ((d2 + d1) / 2.0) * d3

    def matchGraphBert(self, dic1, dic2, g):
        matrix = np.zeros((self.edgeCount, g.edgeCount))

        for i in range(self.edgeCount):
            for j in range(g.edgeCount):
                similarity = self.matchRelationBert(dic1, dic2, self, self.edges[i], g, g.edges[j])
                matrix[i, j] = similarity

        sum_d1, sum_d2, weight_sum_d1, weight_sum_d2 = 0, 0, 0, 0
        nan_count_d1, nan_count_d2 = 0, 0

        for i in range(self.edgeCount):
            max_val = np.max(matrix[i, :])
            if max_val == 0:
                nan_count_d1 += 1
            else:
                rel = g.edges[np.argmax(matrix[i, :])]['name']
                weight = self.getWeight(rel)
                sum_d1 += max_val * weight
                weight_sum_d1 += weight

        for j in range(g.edgeCount):
            max_val = np.max(matrix[:, j])
            if max_val == 0:
                nan_count_d2 += 1
            else:
                rel = self.edges[np.argmax(matrix[:, j])]['name']
                weight = self.getWeight(rel)
                sum_d2 += max_val * weight
                weight_sum_d2 += weight

        d1 = sum_d1 / weight_sum_d1 if weight_sum_d1 > 0 else 0
        d2 = sum_d2 / weight_sum_d2 if weight_sum_d2 > 0 else 0

        g1.printRelationMatrix(matrix, g1, g2, export_csv=True, filename="relation_matrix.csv")

        return (d1 + d2) / 2 if self.edgeCount - nan_count_d1 > 0 and g.edgeCount - nan_count_d2 > 0 else 0


    def getNodeLemma(self, code):
        node = self.getNode(code)
        return node['lemma'] if node else 'N/A'

    def printRelationMatrix(self, matrix, g1, g2, export_csv=False, filename="relation_matrix.csv"):
        print("Matriz de Relações:")
        header = [""] + [f"{g2.edges[j]['name']} ({self.getNodeLemma(g2.edges[j]['in'])} - {self.getNodeLemma(g2.edges[j]['ex'])})" for j in range(g2.edgeCount)]
        print("     ".join(header))

        rows = []
        for i in range(self.edgeCount):
            row = [f"{g1.edges[i]['name']} ({self.getNodeLemma(g1.edges[i]['in'])} - {self.getNodeLemma(g1.edges[i]['ex'])})"]
            for j in range(g2.edgeCount):
                cell_value = f"{matrix[i, j]:.4f} ({self.getNodeLemma(g1.edges[i]['in'])} - {self.getNodeLemma(g1.edges[i]['ex'])}, {self.getNodeLemma(g2.edges[j]['in'])} - {self.getNodeLemma(g2.edges[j]['ex'])})"
                row.append(cell_value)
            rows.append(row)

        # Imprimir a matriz de relações
        for row in rows:
            print("     ".join(row))

        # Exportar para CSV se necessário
        if export_csv:
            with open(filename, 'w', newline='') as csvfile:
                csvwriter = csv.writer(csvfile)
                csvwriter.writerow(header)
                csvwriter.writerows(rows)
            print(f"Matriz exportada para {filename}")


    def calculateGraph(self):
        matrix = np.zeros((self.edgeCount, g.edgeCount))
        for j in range(self.edgeCount):
            max_val = np.max(matrix[:, j])
            if max_val == 0:
                nan_count_d2 += 1
            else:
                rel = self.edges[np.argmax(matrix[:, j])]['name']
                weight = self.getWeight(rel)
                sum_d2 += max_val * weight
                weight_sum_d2 += weight

# %% [markdown]
# #Define função similaridade dos grafos

# %%
class GraphSTS(Graph):
    def __init__(self, sentence: str, debug: bool = False):
        super().__init__(sentence, debug)

    def matchConcept(self, c1, c2):
        vec1 = self.get_vector(c1)
        vec2 = self.get_vector(c2)
        # Similaridade do cosseno
        return 1 - cosine(vec1, vec2) if np.any(vec1) and np.any(vec2) else 0

    def matchConceptWithExpansion(self, g1, c1, g2, c2):
        all1 = g1.expand(c1)
        all2 = g2.expand(c2)
        print("expansions:", all1, all2)
        max_similarity = 0

        for word1 in all1:
            for word2 in all2:
                similarity = self.matchConcept(word1, word2)
                if similarity > max_similarity:
                    max_similarity = similarity

        return max_similarity

    def matchRelation(self, g1, r1, g2, r2):
        node_g1_in = g1.getNode(r1['in'])
        node_g1_ex = g1.getNode(r1['ex'])
        node_g2_in = g2.getNode(r2['in'])
        node_g2_ex = g2.getNode(r2['ex'])

        # Verifica se algum dos nós é None e retorna 0 em tal caso
        if not all([node_g1_in, node_g1_ex, node_g2_in, node_g2_ex]):
            return 0

        node_in_g1 = node_g1_in['lemma']
        node_ex_g1 = node_g1_ex['lemma']
        node_in_g2 = node_g2_in['lemma']
        node_ex_g2 = node_g2_ex['lemma']

        # d1 = self.matchConceptWithExpansion(g1, node_in_g1, g2, node_in_g2)
        # d2 = self.matchConceptWithExpansion(g1, node_ex_g1, g2, node_ex_g2)
        d1 = self.matchConcept(node_in_g1, node_in_g2)
        d2 = self.matchConcept(node_ex_g1, node_ex_g2)
        d3 = self.matchRelationNameSTS(r1['name'], r2['name'])

        return ((d2 + d1) / 2.0) * d3

    def calculateGraph(self):
        matrix = np.zeros((self.edgeCount, g.edgeCount))
        for j in range(self.edgeCount):
            max_val = np.max(matrix[:, j])
            if max_val == 0:
                nan_count_d2 += 1
            else:
                rel = self.edges[np.argmax(matrix[:, j])]['name']
                weight = self.getWeight(rel)
                sum_d2 += max_val * weight
                weight_sum_d2 += weight

    def printRelationMatrix(self, matrix, g, export_csv=False, filename="relation_matrix.csv"):
        print("Matriz de Relações:")
        print("     ", end="")
        header = [""] + [g.edges[j]['name'] for j in range(g.edgeCount)]
        print("     ".join(header))

        rows = []
        for i in range(self.edgeCount):
            row = [self.edges[i]['name']]
            print(f"{self.edges[i]['name']:>12}", end="     ")
            for j in range(g.edgeCount):
                print(f"{matrix[i, j]:>12.4f}", end="     ")
                row.append(matrix[i, j])
            rows.append(row)
            print()

        if export_csv:
            with open(filename, 'w', newline='') as csvfile:
                csvwriter = csv.writer(csvfile)
                csvwriter.writerow(header)
                csvwriter.writerows(rows)
            print(f"Matriz exportada para {filename}")

    def matchGraph(self, g):
        matrix = np.zeros((self.edgeCount, g.edgeCount))

        for i in range(self.edgeCount):
            for j in range(g.edgeCount):
                similarity = self.matchRelation(self, self.edges[i], g, g.edges[j])
                matrix[i, j] = similarity

        sum_d1, sum_d2, weight_sum_d1, weight_sum_d2 = 0, 0, 0, 0
        nan_count_d1, nan_count_d2 = 0, 0

        for i in range(self.edgeCount):
            max_val = np.max(matrix[i, :])
            if max_val == 0:
                nan_count_d1 += 1
            else:
                rel = g.edges[np.argmax(matrix[i, :])]['name']
                weight = self.getWeight(rel)
                sum_d1 += max_val * weight
                weight_sum_d1 += weight

        for j in range(g.edgeCount):
            max_val = np.max(matrix[:, j])
            if max_val == 0:
                nan_count_d2 += 1
            else:
                rel = self.edges[np.argmax(matrix[:, j])]['name']
                weight = self.getWeight(rel)
                sum_d2 += max_val * weight
                weight_sum_d2 += weight

        d1 = sum_d1 / weight_sum_d1 if weight_sum_d1 > 0 else 0
        d2 = sum_d2 / weight_sum_d2 if weight_sum_d2 > 0 else 0

        self.printRelationMatrix(matrix, g)

        return (d1 + d2) / 2 if self.edgeCount - nan_count_d1 > 0 and g.edgeCount - nan_count_d2 > 0 else 0

# %%
# # Exemplo de uso
# graph = GraphSTS("A cock is an adult male chicken")
# idf_value = graph.get_idf("is")
# print(f"Valor IDF para 'cock': {idf_value}")

# %% [markdown]
# #Gera os grafos a partir da classe

# %%
def generate_graphs(fres):
    # Regular expressions
    conceptReg = re.compile(r"c\d+:(.+?):.+instance (.+?) ")
    argReg = re.compile(r"c\d+:(.+?):.+arg (.+?) ")
    inRelReg = re.compile(r"(.*?):(.*?):.* int (.*?) ")
    exRelReg = re.compile(r"(.*?):(.*?):.* ext (.*?) ")
    inEqRelReg = re.compile(r"(.*?):equality int (.*?) ")
    exEqRelReg = re.compile(r"(.*?):equality ext (.*?) ")
    isReg = re.compile(r".* (.*?):equality \d+ . is ")
    refReg = re.compile(r".+referent (.+?) .* (.+?) ")

    for i in range(3):
      sentence = fres.readline()

    sentence = sentence.replace("%%% ", "")
    g1 = GraphSTSBert(sentence, True)
    # g1 = GraphSTS(sentence, True)

    # print(g1.words)
    for line in fres:
        # Initialize your GraphSTS object here (Placeholder)
        if line and line[0] == '%':
            continue
        else:
            match = conceptReg.search(line)
        if match:
            g1.addConcept(match.group(1), match.group(2), "")
            pass
        elif (match := argReg.search(line)):
            g1.addConcept(match.group(1), match.group(2), "jj")
            pass
        elif (match := inRelReg.search(line)):
            g1.addRelationIn(match.group(2), match.group(1), match.group(3))
            pass
        elif (match := exRelReg.search(line)):
            g1.addRelationEx(match.group(2), match.group(1), match.group(3))
            pass
        elif (match := inEqRelReg.search(line)):
            g1.addRelationIn("equality", match.group(1), match.group(2))
            pass
        elif (match := exEqRelReg.search(line)):
            g1.addRelationEx("equality", match.group(1), match.group(2))
            pass
        elif (match := isReg.search(line)):
            g1.addIsRelation("is", match.group(1))
            pass
        elif (match := refReg.search(line)):
            temp = match.group(2)
            if len(temp) > 3:
                g1.addConcept(match.group(2), match.group(1), "ref")
                pass

    return g1

# %% [markdown]
# # Processa usando BERT

# %%
# Função para obter embeddings de uma sentença
def get_sentence_embeddings(sentence):
  # Tokeniza a sentença
  inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=512)

  # Obtém os embeddings
  with torch.no_grad():
      outputs = model(**inputs)

  # Mapeia tokens para palavras
  token_embeddings = outputs.last_hidden_state.squeeze().numpy()
  tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"][0])

  # Cria um dicionário para mapear palavras aos seus embeddings
  word_embeddings = {}
  current_word = ""
  word_embedding = None

  for i, token in enumerate(tokens):
      # Se é o primeiro subtoken de uma nova palavra
      if token.startswith("##"):
          token = token[2:]  # Remove o prefixo '##'
          current_word += token
          word_embedding += token_embeddings[i]
      else:
          if current_word:
              # Adiciona a palavra anterior ao dicionário
              word_embeddings[current_word] = word_embedding / len(current_word.split("##"))
          current_word = token
          word_embedding = token_embeddings[i]

  # Adiciona a última palavra
  if current_word:
      word_embeddings[current_word] = word_embedding / len(current_word.split("##"))

  return word_embeddings

# %% [markdown]
# #Importa dataset

# %%
NOME_ARQUIVO_ORIGINAL_COMPACTADO = "MSRP/msrp_test.csv"

# %%
# Se estiver executando no Google Colaboratory
if IN_COLAB:

  # !cp "$DIRETORIO_DRIVE$NOME_ARQUIVO_ORIGINAL_COMPACTADO" "$DIRETORIO_LOCAL"

  logging.info("Terminei a cópia.")

# %% [markdown]
# #Processa dataset

# %%
import pandas as pd
import os
import subprocess

# Função para processar sentenças e gerar os grafos
def process_sentence(sentence, file_name):
    # Grava a sentença em um arquivo temporário
    with open(file_name, 'w') as file:
        file.write(sentence)

    # Chama o CandC e o Boxer
    subprocess.run(f'echo "{sentence}" | bin/candc --models models/boxer --candc-printer boxer --output /content/CANDC/{file_name}_candc', shell=True)
    subprocess.run(f'bin/boxer --input /content/CANDC/{file_name}_candc --output /content/CANDC/{file_name}_drg --semantics drg', shell=True)

# %%
# Lê o arquivo CSV
df = pd.read_csv('/content/CANDC/msrp_test.csv')
# df = pd.read_excel('/content/CANDC/msrp_test.csv')
df = df[:100]
df

# %% [markdown]
# ##Processa usando word2vec

# %%
import re

# Nova função para converter similaridade em binário
def convert_to_binary(similarity, threshold=0.5):
    return 1 if similarity >= threshold else 0

# Função para limpar a sentença removendo pontos e vírgulas
def clean_sentence(sentence):
    return re.sub(r'[.,]', '', sentence)

# Lista para armazenar os resultados de similaridade
similarities = []
binary_predictions = []

for index, row in df.iterrows():
    # Limpa e processa as duas sentenças
    sentence1_clean = clean_sentence(row['#1 String'])
    process_sentence(sentence1_clean, 'sentence1')
    print(sentence1_clean)
    dict1 = get_sentence_embeddings(sentence1_clean)
    sentence2_clean = clean_sentence(row['#2 String'])
    process_sentence(sentence2_clean, 'sentence2')
    print(sentence2_clean)
    dict2 = get_sentence_embeddings(sentence2_clean)

    # Abre os arquivos processados
    with open("/content/CANDC/sentence1_drg", "r") as fres, open("/content/CANDC/sentence2_drg", "r") as fres2:
        # Gera os grafos
        g1 = generate_graphs(fres)
        g2 = generate_graphs(fres2)

        # Calcula e armazena a similaridade
        similarity = g1.matchGraphBert(dict1, dict2, g2)
        # similarity = g1.matchGraph(g2)
        similarities.append(similarity)
        binary_predictions.append(convert_to_binary(similarity))

# Adiciona a coluna de similaridade ao DataFrame
df['Similarity'] = similarities

# Salva o DataFrame modificado como CSV
# df.to_csv('/content/CANDC/results.csv', index=False)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# equality    Theme
# equality    equality
# equality    to
# equality    equality
# equality    equality
# equality    at
# equality    in
# equality    about
# equality    equality
# equality    from
# equality    Actor
# equality    equality
# equality    Time
# equality    equality
# equality    equality
# equality    equality
# equality    equality
# equality    equality
# equality    equality
# equality    Theme
# equality    equality
# equality    to
# equality    equality
# equality    equality
# equality    at
# equality    in
# equality    about
# equality    equality
# equality    from
# Theme    Actor
# Theme    equality
# Theme    Time
# Theme    equality
# Theme    equality
# Theme    equality
# Theme    equality
# Theme    equality
# Theme    equality
# Theme    Theme
# Theme    equality
# Theme    to
# Theme    equality
# Theme    equality
# Theme    at
# Theme    in
# Theme    about
# Theme    equality
# Theme    from
# equality    Actor
# equality    equality
# equality    Time
# equality    equality
# equality    equality
# equality    equality
# equality    equality
# equality    equality
# equality    equality
# equality    Theme
# equality    equality
# equality    to
# equality    equality
# equality    equality
# equality    at
# equality    in
# equality    about
# equality    equality
# equality    from
# to    Actor
# to    equality
# to    Time
# to    equality
# to    equality
# to    equality
# to    equality
# to    equality
# to    equality
# to    Theme
# to    equality
# to    to
# to    equality
# to    equality
# to    at
# to    in
# to    about
# to    equality
# to    from
# equality    Actor
# equality    equality
# equality    Time
# equality    equality
# equality    equality
# equality    equality
# equality    equality
# equality    equality
# equality    equality
# equality    Theme
# equality    equality
# equality    to
# equality    equality
# equality    equality
# equality    at
# equality    in
# equality    about
# equality    equality
# equality    from
# equality    Actor
# equality    equality
# equality    Time
# equality    equality
# equality    equality
# equality    equality
# equality    equality
# equality    equality
# equality    equality
# equality    Theme
# equality    equality
# equality    to
# equality    equality
# equality    equality
# equality    at
# equality    in
# equality    about
# equality    equality
# equality    from
# equality    Actor
# equality    equality
# equality    Time
# equality    equality
# equality    equality
# equality    equality
# equality    equality
# equality    equality
# equality    equality
# equality    Theme
# equality    equality
# equality    to
# equality    equality
# equality    equality
# equality    at
# equality    in
# equality    about
# equality    equality
# equality    from
# at    Actor
# at    equality
# at    Time
# at    equality
# at    equality
# at    equality
# at    equality
# at    equality
# at    equality
# at    Theme
# at    equality
# at    to
# at    equality
# at    equality
# at    at
# at    in
# at    about
# at    equality
# at    from
# in    Actor
# in    equality
# in    Time
# in    equality
# in    equality
# in    equality
# in    equality
# in    equality
# in    equality
# in    Theme
# in    equality
# in    to
# in    equality
# in    equality
# in    at
# in    in
# in    about
# in    equality
# in    from
# about    Actor
# about    equality
# about    Time
# about    equality
# about    equality
# about    equality
# about    equality
# about    equality
# about    equality
# about    Theme
# about    equality
# about    to
# about    equality
# about    equality
# about    at
# about    in
# about    about
# about    equality
# about    from
# from    Actor
# from    equality
# from    Time
# from    equality
# from    equality
# from    equality
# from    equality
# from    equality
# from    equality
# from    Theme
# from    equality
# from    to
# from    equality
# from    equality
# from    at
# from    in
# from    about
# from    equality
# from    from
# Matriz de Relações:
#      Actor (N/A - N/A)     equality (N/A - lat)     Time (N/A - N/A)     equality (N/A - 11)     equality (N/A - 11)     equality (N/A - N/A)     equality (N/A - N/A)     equality (N/A - N/A)     equality (N/A - N/A)     Theme (N/A - N/A)     equality (N/A - shooting)     to (N/A - N/A)     equality (N/A - N/A)     equality (N/A - N/A)     at (N/A - N/A)     in (N/A - N/A)     about (N/A - N/A)     equality (N/A - N/A)     from (N/A - N/A)
# Theme (shooting - most)     0.0000 (shooting - most, N/A - N/A)     0.0000 (shooting - most, N/A - lat)     0.0000 (shooting - most, N/A - N/A)     0.0000 (shooting - most, N/A - 11)     0.0000 (shooting - most, N/A - 11)     0.0000 (shooting - most, N/A - N/A)     0.1895 (shooting - most, N/A - N/A)     0.0000 (shooting - most, N/A - N/A)     0.1895 (shooting - most, N/A - N/A)     0.2461 (shooting - most, N/A - N/A)     0.1895 (shooting - most, N/A - shooting)     0.0000 (shooting - most, N/A - N/A)     0.0000 (shooting - most, N/A - N/A)     0.0000 (shooting - most, N/A - N/A)     0.0000 (shooting - most, N/A - N/A)     0.0000 (shooting - most, N/A - N/A)     0.0000 (shooting - most, N/A - N/A)     0.0000 (shooting - most, N/A - N/A)     0.0000 (shooting - most, N/A - N/A)
# equality (school - hamilton)     0.0000 (school - hamilton, N/A - N/A)     0.0000 (school - hamilton, N/A - lat)     0.0000 (school - hamilton, N/A - N/A)     0.0000 (school - hamilton, N/A - 11)     0.0000 (school - hamilton, N/A - 11)     0.0000 (school - hamilton, N/A - N/A)     0.0000 (school - hamilton, N/A - N/A)     0.0000 (school - hamilton, N/A - N/A)     0.0000 (school - hamilton, N/A - N/A)     0.0000 (school - hamilton, N/A - N/A)     0.0000 (school - hamilton, N/A - shooting)     0.0000 (school - hamilton, N/A - N/A)     0.0000 (school - hamilton, N/A - N/A)     0.0000 (school - hamilton, N/A - N/A)     0.0000 (school - hamilton, N/A - N/A)     0.0000 (school - hamilton, N/A - N/A)     0.0000 (school - hamilton, N/A - N/A)     0.0000 (school - hamilton, N/A - N/A)     0.0000 (school - hamilton, N/A - N/A)
# equality (school - central)     0.0000 (school - central, N/A - N/A)     0.0000 (school - central, N/A - lat)     0.0000 (school - central, N/A - N/A)     0.0000 (school - central, N/A - 11)     0.0000 (school - central, N/A - 11)     0.0000 (school - central, N/A - N/A)     0.0000 (school - central, N/A - N/A)     0.0000 (school - central, N/A - N/A)     0.0000 (school - central, N/A - N/A)     0.0000 (school - central, N/A - N/A)     0.0000 (school - central, N/A - shooting)     0.0000 (school - central, N/A - N/A)     0.0000 (school - central, N/A - N/A)     0.0000 (school - central, N/A - N/A)     0.0000 (school - central, N/A - N/A)     0.0000 (school - central, N/A - N/A)     0.0000 (school - central, N/A - N/A)     0.0000 (school - central, N/A - N/A)     0.0000 (school - central, N/A - N/A)
# equality (school - elementary)     0.0000 (school - elementary, N/A - N/A)     0.0000 (school - elementary, N/A - lat)     0.0000 (school - elementary, N/A - N/A)     0.0000 (school - elementary, N/A - 11)     0.0000 (school - elementary, N/A - 11)     0.0000 (school - elementary, N/A - N/A)     0.0000 (school - elementary, N/A - N/A)     0.0000 (school - elementary, N/A - N/A)     0.0000 (school - elementary, N/A - N/A)     0.0000 (school - elementary, N/A - N/A)     0.0000 (school - elementary, N/A - shooting)     0.0000 (school - elementary, N/A - N/A)     0.0000 (school - elementary, N/A - N/A)     0.0000 (school - elementary, N/A - N/A)     0.0000 (school - elementary, N/A - N/A)     0.0000 (school - elementary, N/A - N/A)     0.0000 (school - elementary, N/A - N/A)     0.0000 (school - elementary, N/A - N/A)     0.0000 (school - elementary, N/A - N/A)
# equality (shooting - XXXX)     0.0000 (shooting - XXXX, N/A - N/A)     0.0000 (shooting - XXXX, N/A - lat)     0.0000 (shooting - XXXX, N/A - N/A)     0.0000 (shooting - XXXX, N/A - 11)     0.0000 (shooting - XXXX, N/A - 11)     0.0000 (shooting - XXXX, N/A - N/A)     0.1722 (shooting - XXXX, N/A - N/A)     0.0000 (shooting - XXXX, N/A - N/A)     0.1722 (shooting - XXXX, N/A - N/A)     0.1895 (shooting - XXXX, N/A - N/A)     0.1722 (shooting - XXXX, N/A - shooting)     0.0000 (shooting - XXXX, N/A - N/A)     0.0000 (shooting - XXXX, N/A - N/A)     0.0000 (shooting - XXXX, N/A - N/A)     0.0000 (shooting - XXXX, N/A - N/A)     0.0000 (shooting - XXXX, N/A - N/A)     0.0000 (shooting - XXXX, N/A - N/A)     0.0000 (shooting - XXXX, N/A
N/A - N/A)
# Matriz exportada para relation_matrix.csv
# Sanitation is poor there could be typhoid and cholera he said
# Sanitation is poor drinking water is generally left behind    there could be typhoid and cholera
# Sanitation is poor there could be typhoid cholera he said
#
# Sanitation is poor drinking water is generally left behind there could be typhoid and cholera
#
# Theme    equality
# Theme    equality
# Theme    Theme
# Theme    Manner
# Theme    of
# Theme    is
# Theme    Theme
# Theme    Actor
# Theme    Theme
# equality    equality
# equality    equality
# equality    Theme
# equality    Manner
# equality    of
# equality    is
# equality    Theme
# equality    Actor
# equality    Theme
# Actor    equality
# Actor    equality
# Actor    Theme
# Actor    Manner
# Actor    of
# Actor    is
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Theme    equality
# Theme    equality
# Theme    Theme
# Theme    Manner
# Theme    of
# Theme    is
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Actor    equality
# Actor    equality
# Actor    Theme
# Actor    Manner
# Actor    of
# Actor    is
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Matriz de Relações:
#      equality (male - N/A)     equality (N/A - N/A)     Topic (N/A - N/A)     superset_of (N/A - N/A)     superset_of (N/A - N/A)     Theme (N/A - N/A)     Manner (say - N/A)     of (N/A - N/A)     is (N/A - N/A)     Theme (say - male)     Actor (N/A - N/A)     Theme (N/A - N/A)     behind (say - N/A)
# Theme (cholera - typhoid)     0.0000 (cholera - typhoid, male - N/A)     0.4195 (cholera - typhoid, N/A - N/A)     0.0000 (cholera - typhoid, N/A - N/A)     0.0000 (cholera - typhoid, N/A - N/A)     0.0000 (cholera - typhoid, N/A - N/A)     0.4984 (cholera - typhoid, N/A - N/A)     0.0000 (cholera - typhoid, say - N/A)     0.4046 (cholera - typhoid, N/A - N/A)     0.1971 (cholera - typhoid, N/A - N/A)     0.0000 (cholera - typhoid, say - male)     0.3997 (cholera - typhoid, N/A - N/A)     0.7119 (cholera - typhoid, N/A - N/A)     0.0000 (cholera - typhoid, say - N/A)
# equality (there - cholera)     0.0000 (there - cholera, male - N/A)     0.4804 (there - cholera, N/A - N/A)     0.0000 (there - cholera, N/A - N/A)     0.0000 (there - cholera, N/A - N/A)     0.0000 (there - cholera, N/A - N/A)     0.4296 (there - cholera, N/A - N/A)     0.0000 (there - cholera, say - N/A)     0.4363 (there - cholera, N/A - N/A)     0.1994 (there - cholera, N/A - N/A)     0.0000 (there - cholera, say - male)     0.5034 (there - cholera, N/A - N/A)     0.6094 (there - cholera, N/A - N/A)     0.0000 (there - cholera, say - N/A)
# Actor (say - male)     0.0000 (say - male, male - N/A)     0.0000 (say - male, N/A - N/A)     0.0000 (say - male, N/A - N/A)     0.0000 (say - male, N/A - N/A)     0.0000 (say - male, N/A - N/A)     0.0000 (say - male, N/A - N/A)     0.0000 (say - male, say - N/A)     0.0000 (say - male, N/A - N/A)     0.0000 (say - male, N/A - N/A)     0.0000 (say - male, say - male)     0.0000 (say - male, N/A - N/A)     0.0000 (say - male, N/A - N/A)     0.0000 (say - male, say - N/A)
# Topic (say - N/A)     0.0000 (say - N/A, male - N/A)     0.0000 (say - N/A, N/A - N/A)     0.0000 (say - N/A, N/A - N/A)     0.0000 (say - N/A, N/A - N/A)     0.0000 (say - N/A, N/A - N/A)     0.0000 (say - N/A, N/A - N/A)     0.0000 (say - N/A, say - N/A)     0.0000 (say - N/A, N/A - N/A)     0.0000 (say - N/A, N/A - N/A)     0.0000 (say - N/A, say - male)     0.0000 (say - N/A, N/A - N/A)     0.0000 (say - N/A, N/A - N/A)     0.0000 (say - N/A, say - N/A)
# Theme (poor - sanitation)     0.0000 (poor - sanitation, male - N/A)     0.2071 (poor - sanitation, N/A - N/A)     0.0000 (poor - sanitation, N/A - N/A)     0.0000 (poor - sanitation, N/A - N/A)     0.0000 (poor - sanitation, N/A - N/A)     0.2919 (poor - sanitation, N/A - N/A)     0.0000 (poor - sanitation, say - N/A)     0.2248 (poor - sanitation, N/A - N/A)     0.0000 (poor - sanitation, N/A - N/A)     0.0000 (poor - sanitation, say - male)     0.2071 (poor - sanitation, N/A - N/A)     0.2690 (poor - sanitation, N/A - N/A)     0.0000 (poor - sanitation, say - N/A)
# Actor (could - there)     0.0000 (could - there, male - N/A)     0.6023 (could - there, N/A - N/A)     0.0000 (could - there, N/A - N/A)     0.0000 (could - there, N/A - N/A)     0.0000 (could - there, N/A - N/A)     0.4158 (could - there, N/A - N/A)     0.0000 (could - there, say - N/A)     0.4305 (could - there, N/A - N/A)     0.2266 (could - there, N/A - N/A)     0.0000 (could - there, say - male)     0.6785 (could - there, N/A - N/A)     0.4999 (could - there, N/A - N/A)     0.0000 (could - there, say - N/A)
# Topic (could - N/A)     0.0000 (could - N/A, male - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, say - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, say - male)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, say - N/A)
# Matriz exportada para relation_matrix.csv
# The Dow Jones Industrial Average ended down 128 points or 14% at 9073 while the Nasdaq fell 34 points or 21% to 1610
# In early trading the Dow Jones industrial average was up 390 or 004 percent at 911375 having gained 3690 on Tuesday
# The Dow Jones Industrial Average ended down 128 points or 14% at 9073 while the Nasdaq fell 34 points or 21% to 1610
#
# In early trading the Dow Jones industrial average was up 390 or 004 percent at 911375 having gained 3690 on Tuesday
#
# equality    equality
# equality    Actor
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    equality
# equality    for
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    for
# equality    Actor
# equality    in
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    at
# equality    equality
# equality    equality
# equality    equality
# equality    on
# equality    on
# Actor    equality
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    equality
# Actor    for
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    for
# Actor    Actor
# Actor    in
# Actor    in
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    at
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    on
# Actor    on
# Theme    equality
# Theme    Actor
# Theme    Theme
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    equality
# Theme    for
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Theme
# Theme    for
# Theme    Actor
# Theme    in
# Theme    in
# Theme    equality
# Theme    equality
# Theme    equality
# Theme    at
# Theme    equality
# Theme    equality
# Theme    equality
# Theme    on
# Theme    on
# Actor    equality
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    equality
# Actor    for
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    for
# Actor    Actor
# Actor    in
# Actor    in
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    at
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    on
# Actor    on
# Time    equality
# Time    Actor
# Time    Theme
# Time    Theme
# Time    Actor
# Time    Theme
# Time    equality
# Time    for
# Time    Theme
# Time    Actor
# Time    Theme
# Time    Theme
# Time    for
# Time    Actor
# Time    in
# Time    in
# Time    equality
# Time    equality
# Time    equality
# Time    at
# Time    equality
# Time    equality
# Time    equality
# Time    on
# Time    on
# Time    equality
# Time    Actor
# Time    Theme
# Time    Theme
# Time    Actor
# Time    Theme
# Time    equality
# Time    for
# Time    Theme
# Time    Actor
# Time    Theme
# Time    Theme
# Time    for
# Time    Actor
# Time    in
# Time    in
# Time    equality
# Time    equality
# Time    equality
# Time    at
# Time    equality
# Time    equality
# Time    equality
# Time    on
# Time    on
# equality    equality
# equality    Actor
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    equality
# equality    for
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    for
# equality    Actor
# equality    in
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    at
# equality    equality
# equality    equality
# equality    equality
# equality    on
# equality    on
# equality    equality
# equality    Actor
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    equality
# equality    for
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    for
# equality    Actor
# equality    in
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    at
# equality    equality
# equality    equality
# equality    equality
# equality    on
# equality    on
# Actor    equality
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    equality
# Actor    for
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    for
# Actor    Actor
# Actor    in
# Actor    in
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    at
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    on
# Actor    on
# Manner    equality
# Manner    Actor
# Manner    Theme
# Manner    Theme
# Manner    Actor
# Manner    Theme
# Manner    equality
# Manner    for
# Manner    Theme
# Manner    Actor
# Manner    Theme
# Manner    Theme
# Manner    for
# Manner    Actor
# Manner    in
# Manner    in
# Manner    equality
# Manner    equality
# Manner    equality
# Manner    at
# Manner    equality
# Manner    equality
# Manner    equality
# Manner    on
# Manner    on
# equality    equality
# equality    Actor
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    equality
# equality    for
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    for
# equality    Actor
# equality    in
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    at
# equality    equality
# equality    equality
# equality    equality
# equality    on
# equality    on
# equality    equality
# equality    Actor
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    equality
# equality    for
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    for
# equality    Actor
# equality    in
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    at
# equality    equality
# equality    equality
# equality    equality
# equality    on
# equality    on
# Actor    equality
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    equality
# Actor    for
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    for
# Actor    Actor
# Actor    in
# Actor    in
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    at
# Actor    equality
# Actor    equality
# Actor    equality
# Actor    on
# Actor    on
# equality    equality
# equality    Actor
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    equality
# equality    for
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    for
# equality    Actor
# equality    in
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    at
# equality    equality
# equality    equality
# equality    equality
# equality    on
# equality    on
# equality    equality
# equality    Actor
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    equality
# equality    for
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    for
# equality    Actor
# equality    in
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    at
# equality    equality
# equality    equality
# equality    equality
# equality    on
# equality    on
# at    equality
# at    Actor
# at    Theme
# at    Theme
# at    Actor
# at    Theme
# at    equality
# at    for
# at    Theme
# at    Actor
# at    Theme
# at    Theme
# at    for
# at    Actor
# at    in
# at    in
# at    equality
# at    equality
# at    equality
# at    at
# at    equality
# at    equality
# at    equality
# at    on
# at    on
# equality    equality
# equality    Actor
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    equality
# equality    for
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    for
# equality    Actor
# equality    in
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    at
# equality    equality
# equality    equality
# equality    equality
# equality    on
# equality    on
# to    equality
# to    Actor
# to    Theme
# to    Theme
# to    Actor
# to    Theme
# to    equality
# to    for
# to    Theme
# to    Actor
# to    Theme
# to    Theme
# to    for
# to    Actor
# to    in
# to    in
# to    equality
# to    equality
# to    equality
# to    at
# to    equality
# to    equality
# to    equality
# to    on
# to    on
# to    equality
# to    Actor
# to    Theme
# to    Theme
# to    Actor
# to    Theme
# to    equality
# to    for
# to    Theme
# to    Actor
# to    Theme
# to    Theme
# to    for
# to    Actor
# to    in
# to    in
# to    equality
# to    equality
# to    equality
# to    at
# to    equality
# to    equality
# to    equality
# to    on
# to    on
# equality    equality
# equality    Actor
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    equality
# equality    for
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    for
# equality    Actor
# equality    in
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    at
# equality    equality
# equality    equality
# equality    equality
# equality    on
# equality    on
# equality    equality
# equality    Actor
# equality    Theme
# equality    Theme
# equality    Actor
# equality    Theme
# equality    equality
# equality    for
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    for
# equality    Actor
# equality    in
# equality    in
# equality    equality
# equality    equality
# equality    equality
# equality    at
# equality    equality
# equality    equality
# equality    equality
# equality    on
# equality    on
# Matriz de Relações:
#      equality (average - dow)     Actor (N/A - end)     Theme (N/A - thing)     Theme (N/A - N/A)     Actor (N/A - average)     Theme (N/A - N/A)     equality (average - jones)     for (N/A - N/A)     Theme (N/A - N/A)     Actor (N/A - average)     Theme (average - N/A)     Theme (N/A - N/A)     for (end - N/A)     Actor (end - average)     in (N/A - N/A)     in (end - N/A)     equality (thing - XX)     equality (thing - XX)     equality (thing - point)     at (end - industrial)     equality (industrial - 14%)     equality (N/A - 9073)     equality (N/A - 1610)     on (N/A - N/A)     on (N/A - N/A)
# equality (average - dow)     0.0000 (average - dow, average - dow)     0.0000 (average - dow, N/A - end)     0.0000 (average - dow, N/A - thing)     0.0000 (average - dow, N/A - N/A)     0.0000 (average - dow, N/A - average)     0.0000 (average - dow, N/A - N/A)     0.0000 (average - dow, average - jones)     0.0000 (average - dow, N/A - N/A)     0.0000 (average - dow, N/A - N/A)     0.0000 (average - dow, N/A - average)     0.0000 (average - dow, average - N/A)     0.0000 (average - dow, N/A - N/A)     0.0000 (average - dow, end - N/A)     0.0000 (average - dow, end - average)     0.0000 (average - dow, N/A - N/A)     0.0000 (average - dow, end - N/A)     0.0000 (average - dow, thing - XX)     0.0000 (average - dow, thing - XX)     0.0000 (average - dow, thing - point)     0.0000 (average - dow, end - industrial)     0.0000 (average - dow, industrial - 14%)     0.0000 (average - dow, N/A - 9073)     0.0000 (average - dow, N/A - 1610)     0.0000 (average - dow, N/A - N/A)     0.0000 (average - dow, N/A - N/A)
# Actor (down - average)     0.1177 (down - average, average - dow)     0.3156 (down - average, N/A - end)     0.2430 (down - average, N/A - thing)     0.1100 (down - average, N/A - N/A)     0.0000 (down - average, N/A - average)     0.0000 (down - average, N/A - N/A)     0.1177 (down - average, average - jones)     0.2430 (down - average, N/A - N/A)     0.1100 (down - average, N/A - N/A)     0.0000 (down - average, N/A - average)     0.1177 (down - average, average - N/A)     0.0000 (down - average, N/A - N/A)     0.0000 (down - average, end - N/A)     0.0000 (down - average, end - average)     0.2367 (down - average, N/A - N/A)     0.0000 (down - average, end - N/A)     0.0000 (down - average, thing - XX)     0.0000 (down - average, thing - XX)     0.0000 (down - average, thing - point)     0.0000 (down - average, end - industrial)     0.0000 (down - average, industrial - 14%)     0.0000 (down - average, N/A - 9073)     0.0000 (down - average, N/A - 1610)     0.0000 (down - average, N/A - N/A)     0.0000 (down - average, N/A - N/A)
# at (end - thing)     0.0000 (end - thing, average - dow)     0.0000 (end - thing, N/A - end)     0.0000 (end - thing, N/A - thing)     0.0000 (end - thing, N/A - N/A)     0.0000 (end - thing, N/A - average)     0.0000 (end - thing, N/A - N/A)     0.0000 (end - thing, average - jones)     0.0000 (end - thing, N/A - N/A)     0.0000 (end - thing, N/A - N/A)     0.0000 (end - thing, N/A - average)     0.0000 (end - thing, average - N/A)     0.0000 (end - thing, N/A - N/A)     0.0000 (end - thing, end - N/A)     0.0000 (end - thing, end - average)     0.0000 (end - thing, N/A - N/A)     0.0000 (end - thing, end - N/A)     0.0000 (end - thing, thing - XX)     0.0000 (end - thing, thing - XX)     0.0000 (end - thing, thing - point)     0.0000 (end - thing, end - industrial)     0.0000 (end - thing, industrial - 14%)     0.0000 (end - thing, N/A - 9073)     0.0000 (end - thing, N/A - 1610)     0.0000 (end - thing, N/A - N/A)     0.0000 (end - thing, N/A - N/A)
# ...
# Actor (could - attack)     0.0000 (could - attack, N/A - N/A)     0.3412 (could - attack, N/A - N/A)     0.1260 (could - attack, N/A - N/A)     0.3155 (could - attack, N/A - N/A)     0.0000 (could - attack, N/A - N/A)     0.1710 (could - attack, N/A - N/A)     0.8886 (could - attack, N/A - N/A)     0.0000 (could - attack, N/A - N/A)     0.7309 (could - attack, N/A - N/A)     0.4928 (could - attack, N/A - N/A)     0.2528 (could - attack, N/A - N/A)     0.4191 (could - attack, N/A - N/A)
# Topic (say - that)     0.0000 (say - that, N/A - N/A)     0.0000 (say - that, N/A - N/A)     0.0000 (say - that, N/A - N/A)     0.1512 (say - that, N/A - N/A)     0.0000 (say - that, N/A - N/A)     0.4319 (say - that, N/A - N/A)     0.1737 (say - that, N/A - N/A)     0.0000 (say - that, N/A - N/A)     0.1737 (say - that, N/A - N/A)     0.1059 (say - that, N/A - N/A)     0.1115 (say - that, N/A - N/A)     0.1631 (say - that, N/A - N/A)
# Topic (could - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, N/A - N/A)     0.0000 (could - N/A, N/A - N/A)
# Actor (widen - attack)     0.0000 (widen - attack, N/A - N/A)     0.2025 (widen - attack, N/A - N/A)     0.1242 (widen - attack, N/A - N/A)     0.3137 (widen - attack, N/A - N/A)     0.0000 (widen - attack, N/A - N/A)     0.1710 (widen - attack, N/A - N/A)     0.7085 (widen - attack, N/A - N/A)     0.0000 (widen - attack, N/A - N/A)     0.8701 (widen - attack, N/A - N/A)     0.3542 (widen - attack, N/A - N/A)     0.2510 (widen - attack, N/A - N/A)     0.5264 (widen - attack, N/A - N/A)
# Theme (widen - conflict)     0.0000 (widen - conflict, N/A - N/A)     0.2025 (widen - conflict, N/A - N/A)     0.1613 (widen - conflict, N/A - N/A)     0.2739 (widen - conflict, N/A - N/A)     0.0000 (widen - conflict, N/A - N/A)     0.1298 (widen - conflict, N/A - N/A)     0.3695 (widen - conflict, N/A - N/A)     0.0000 (widen - conflict, N/A - N/A)     0.4940 (widen - conflict, N/A - N/A)     0.3277 (widen - conflict, N/A - N/A)     0.2644 (widen - conflict, N/A - N/A)     0.5315 (widen - conflict, N/A - N/A)
# Actor (plan - “in)     0.0000 (plan - “in, N/A - N/A)     0.1329 (plan - “in, N/A - N/A)     0.2553 (plan - “in, N/A - N/A)     0.2553 (plan - “in, N/A - N/A)     0.0000 (plan - “in, N/A - N/A)     0.0000 (plan - “in, N/A - N/A)     0.1726 (plan - “in, N/A - N/A)     0.0000 (plan - “in, N/A - N/A)     0.2056 (plan - “in, N/A - N/A)     0.1329 (plan - “in, N/A - N/A)     0.2486 (plan - “in, N/A - N/A)     0.1583 (plan - “in, N/A - N/A)
# with (could - plan)     0.0000 (could - plan, N/A - N/A)     0.3412 (could - plan, N/A - N/A)     0.1260 (could - plan, N/A - N/A)     0.3403 (could - plan, N/A - N/A)     0.0000 (could - plan, N/A - N/A)     0.1363 (could - plan, N/A - N/A)     0.5115 (could - plan, N/A - N/A)     0.0000 (could - plan, N/A - N/A)     0.3901 (could - plan, N/A - N/A)     0.7746 (could - plan, N/A - N/A)     0.2866 (could - plan, N/A - N/A)     0.3964 (could - plan, N/A - N/A)
# equality (plan - map)     0.0000 (plan - map, N/A - N/A)     0.1329 (plan - map, N/A - N/A)     0.2553 (plan - map, N/A - N/A)     0.4814 (plan - map, N/A - N/A)     0.0000 (plan - map, N/A - N/A)     0.1171 (plan - map, N/A - N/A)     0.2890 (plan - map, N/A - N/A)     0.0000 (plan - map, N/A - N/A)     0.3144 (plan - map, N/A - N/A)     0.4592 (plan - map, N/A - N/A)     0.4129 (plan - map, N/A - N/A)     0.3244 (plan - map, N/A - N/A)
# through (widen - region)     0.0000 (widen - region, N/A - N/A)     0.2025 (widen - region, N/A - N/A)     0.1242 (widen - region, N/A - N/A)     0.3073 (widen - region, N/A - N/A)     0.0000 (widen - region, N/A - N/A)     0.1528 (widen - region, N/A - N/A)     0.3937 (widen - region, N/A - N/A)     0.0000 (widen - region, N/A - N/A)     0.5181 (widen - region, N/A - N/A)     0.3497 (widen - region, N/A - N/A)     0.2701 (widen - region, N/A - N/A)     0.8740 (widen - region, N/A - N/A)
# Matriz exportada para relation_matrix.csv
# A successful attack could be launched within any type of document that supports VBA including Microsoft Word Excel or PowerPoint
# But this could happen with any document format that supports VBA including Word Excel or PowerPoint
# A successful attack could be launched within any type of document that supports VBA including Microsoft Word Excel or PowerPoint
#
# But this could happen with any document format that supports VBA including Word Excel or PowerPoint
#
# Theme    equality
# Theme    Theme
# Theme    equality
# Theme    Actor
# Theme    Actor
# Theme    of
# Theme    Actor
# Theme    equality
# Theme    with
# Theme    with
# Theme    include
# Theme    include
# equality    equality
# equality    Theme
# equality    equality
# equality    Actor
# equality    Actor
# equality    of
# equality    Actor
# equality    equality
# equality    with
# equality    with
# equality    include
# equality    include
# Theme    equality
# Theme    Theme
# Theme    equality
# Theme    Actor
# Theme    Actor
# Theme    of
# Theme    Actor
# Theme    equality
# Theme    with
# Theme    with
# Theme    include
# Theme    include
# equality    equality
# equality    Theme
# equality    equality
# equality    Actor
# equality    Actor
# equality    of
# equality    Actor
# equality    equality
# equality    with
# equality    with
# equality    include
# equality    include
# equality    equality
# equality    Theme
# equality    equality
# equality    Actor
# equality    Actor
# equality    of
# equality    Actor
# equality    equality
# equality    with
# equality    with
# equality    include
# equality    include
# Actor    equality
# Actor    Theme
# Actor    equality
# Actor    Actor
# Actor    Actor
# Actor    of
# Actor    Actor
# Actor    equality
# Actor    with
# Actor    with
# Actor    include
# Actor    include
# Theme    equality
# Theme    Theme
# Theme    equality
# Theme    Actor
# Theme    Actor
# Theme    of
# Theme    Actor
# Theme    equality
# Theme    with
# Theme    with
# Theme    include
# Theme    include
# Actor    equality
# Actor    Theme
# Actor    equality
# Actor    Actor
# Actor    Actor
# Actor    of
# Actor    Actor
# Actor    equality
# Actor    with
# Actor    with
# Actor    include
# Actor    include
# within    equality
# within    Theme
# within    equality
# within    Actor
# within    Actor
# within    of
# within    Actor
# within    equality
# within    with
# within    with
# within    include
# within    include
# within    equality
# within    Theme
# within    equality
# within    Actor
# within    Actor
# within    of
# within    Actor
# within    equality
# within    with
# within    with
# within    include
# within    include
# of    equality
# of    Theme
# of    equality
# of    Actor
# of    Actor
# of    of
# of    Actor
# of    equality
# of    with
# of    with
# of    include
# of    include
# include    equality
# include    Theme
# include    equality
# include    Actor
# include    Actor
# include    of
# include    Actor
# include    equality
# include    with
# include    with
# include    include
# include    include
# include    equality
# include    Theme
# include    equality
# include    Actor
# include    Actor
# include    of
# include    Actor
# include    equality
# include    with
# include    with
# include    include
# include    include
# Matriz de Relações:
#      equality (type - that)     Theme (support - vba)     equality (excel - microsoft)     Actor (could - attack)     Topic (could - N/A)     Actor (launch - attack)     of (type - N/A)     Actor (that - support)     equality (could - N/A)     with (launch - type)     with (launch - type)     include (type - excel)     include (type - N/A)
# Theme (attack - successful)     0.3113 (attack - successful, type - that)     0.0000 (attack - successful, support - vba)     0.0000 (attack - successful, excel - microsoft)     0.0000 (attack - successful, could - attack)     0.0000 (attack - successful, could - N/A)     0.1531 (attack - successful, launch - attack)     0.3029 (attack - successful, type - N/A)     0.1580 (attack - successful, that - support)     0.1572 (attack - successful, could - N/A)     0.2913 (attack - successful, launch - type)     0.2913 (attack - successful, launch - type)     0.1646 (attack - successful, type - excel)     0.1646 (attack - successful, type - N/A)
# equality (type - that)     0.5461 (type - that, type - that)     0.0000 (type - that, support - vba)     0.0000 (type - that, excel - microsoft)     0.0000 (type - that, could - attack)     0.0000 (type - that, could - N/A)     0.1677 (type - that, launch - attack)     0.4433 (type - that, type - N/A)     0.2332 (type - that, that - support)     0.1922 (type - that, could - N/A)     0.4314 (type - that, launch - type)     0.4314 (type - that, launch - type)     0.2399 (type - that, type - excel)     0.2399 (type - that, type - N/A)
# Theme (support - vba)     0.0000 (support - vba, type - that)     0.0000 (support - vba, support - vba)     0.0000 (support - vba, excel - microsoft)     0.0000 (support - vba, could - attack)     0.0000 (support - vba, could - N/A)     0.0000 (support - vba, launch - attack)     0.0000 (support - vba, type - N/A)     0.0000 (support - vba, that - support)     0.0000 (support - vba, could - N/A)     0.0000 (support - vba, launch - type)     0.0000 (support - vba, launch - type)     0.0000 (support - vba, type - excel)     0.0000 (support - vba, type - N/A)
# equality (excel - microsoft)     0.0000 (excel - microsoft, type - that)     0.0000 (excel - microsoft, support - vba)     0.0000 (excel - microsoft, excel - microsoft)     0.0000 (excel - microsoft, could - attack)     0.0000 (excel - microsoft, could - N/A)     0.0000 (excel - microsoft, launch - attack)     0.0000 (excel - microsoft, type - N/A)     0.0000 (excel - microsoft, that - support)     0.0000 (excel - microsoft, could - N/A)     0.0000 (excel - microsoft, launch - type)     0.0000 (excel - microsoft, launch - type)     0.0000 (excel - microsoft, type - excel)     0.0000 (excel - microsoft, type - N/A)
# equality (excel - word)     0.0000 (excel - word, type - that)     0.0000 (excel - word, support - vba)     0.0000 (excel - word, excel - microsoft)     0.0000 (excel - word, could - attack)     0.0000 (excel - word, could - N/A)     0.0000 (excel - word, launch - attack)     0.0000 (excel - word, type - N/A)     0.0000 (excel - word, that - support)     0.0000 (excel - word, could - N/A)     0.0000 (excel - word, launch - type)     0.0000 (excel - word, launch - type)     0.0000 (excel - word, type - excel)     0.0000 (excel - word, type - N/A)
# Actor (could - attack)     0.3567 (could - attack, type - that)     0.0000 (could - attack, support - vba)     0.0000 (could - attack, excel - microsoft)     0.0000 (could - attack, could - attack)     0.0000 (could - attack, could - N/A)     0.2583 (could - attack, launch - attack)     0.3416 (could - attack, type - N/A)     0.2805 (could - attack, that - support)     0.1651 (could - attack, could - N/A)     0.3635 (could - attack, launch - type)     0.3635 (could - attack, launch - type)     0.1987 (could - attack, type - excel)     0.1987 (could - attack, type - N/A)
# Topic (could - N/A)     0.0000 (could - N/A, type - that)     0.0000 (could - N/A, support - vba)     0.0000 (could - N/A, excel - microsoft)     0.0000 (could - N/A, could - attack)     0.0000 (could - N/A, could - N/A)     0.0000 (could - N/A, launch - attack)     0.0000 (could - N/A, type - N/A)     0.0000 (could - N/A, that - support)     0.0000 (could - N/A, could - N/A)     0.0000 (could - N/A, launch - type)     0.0000 (could - N/A, launch - type)     0.0000 (could - N/A, type - excel)     0.0000 (could - N/A, type - N/A)
# Theme (launch - attack)     0.1580 (launch - attack, type - that)     0.0000 (launch - attack, support - vba)     0.0000 (launch - attack, excel - microsoft)     0.0000 (launch - attack, could - attack)     0.0000 (launch - attack, could - N/A)     0.0000 (launch - attack, launch - attack)     0.1429 (launch - attack, type - N/A)     0.0000 (launch - attack, that - support)     0.1651 (launch - attack, could - N/A)     0.1646 (launch - attack, launch - type)     0.1646 (launch - attack, launch - type)     0.0000 (launch - attack, type - excel)     0.0000 (launch - attack, type - N/A)
# Actor (that - support)     0.2638 (that - support, type - that)     0.0000 (that - support, support - vba)     0.0000 (that - support, excel - microsoft)     0.0000 (that - support, could - attack)     0.0000 (that - support, could - N/A)     0.2233 (that - support, launch - attack)     0.2638 (that - support, type - N/A)     0.4686 (that - support, that - support)     0.0000 (that - support, could - N/A)     0.1719 (that - support, launch - type)     0.1719 (that - support, launch - type)     0.2638 (that - support, type - excel)     0.2638 (that - support, type - N/A)
# within (launch - type)     0.2332 (launch - type, type - that)     0.0000 (launch - type, support - vba)     0.0000 (launch - type, excel - microsoft)     0.0000 (launch - type, could - attack)     0.0000 (launch - type, could - N/A)     0.0000 (launch - type, launch - attack)     0.2254 (launch - type, type - N/A)     0.0000 (launch - type, that - support)     0.1839 (launch - type, could - N/A)     0.2399 (launch - type, launch - type)     0.2399 (launch - type, launch - type)     0.0000 (launch - type, type - excel)     0.0000 (launch - type, type - N/A)
# within (launch - type)     0.2332 (launch - type, type - that)     0.0000 (launch - type, support - vba)     0.0000 (launch - type, excel - microsoft)     0.0000 (launch - type, could - attack)     0.0000 (launch - type, could - N/A)     0.0000 (launch - type, launch - attack)     0.2254 (launch - type, type - N/A)     0.0000 (launch - type, that - support)     0.1839 (launch - type, could - N/A)     0.2399 (launch - type, launch - type)     0.2399 (launch - type, launch - type)     0.0000 (launch - type, type - excel)     0.0000 (launch - type, type - N/A)
# of (type - document)     0.4710 (type - document, type - that)     0.0000 (type - document, support - vba)     0.0000 (type - document, excel - microsoft)     0.0000 (type - document, could - attack)     0.0000 (type - document, could - N/A)     0.1677 (type - document, launch - attack)     0.7223 (type - document, type - N/A)     0.2332 (type - document, that - support)     0.1755 (type - document, could - N/A)     0.4633 (type - document, launch - type)     0.4633 (type - document, launch - type)     0.2399 (type - document, type - excel)     0.2399 (type - document, type - N/A)
# include (type - excel)     0.2399 (type - excel, type - that)     0.0000 (type - excel, support - vba)     0.0000 (type - excel, excel - microsoft)     0.0000 (type - excel, could - attack)     0.0000 (type - excel, could - N/A)     0.1677 (type - excel, launch - attack)     0.2399 (type - excel, type - N/A)     0.2332 (type - excel, that - support)     0.0000 (type - excel, could - N/A)     0.1677 (type - excel, launch - type)     0.1677 (type - excel, launch - type)     0.3115 (type - excel, type - excel)     0.3115 (type - excel, type - N/A)
# include (type - powerpoint)     0.2399 (type - powerpoint, type - that)     0.0000 (type - powerpoint, support - vba)     0.0000 (type - powerpoint, excel - microsoft)     0.0000 (type - powerpoint, could - attack)     0.0000 (type - powerpoint, could - N/A)     0.1677 (type - powerpoint, launch - attack)     0.2399 (type - powerpoint, type - N/A)     0.2332 (type - powerpoint, that - support)     0.0000 (type - powerpoint, could - N/A)     0.1677 (type - powerpoint, launch - type)     0.1677 (type - powerpoint, launch - type)     0.3115 (type - powerpoint, type - excel)     0.3115 (type - powerpoint, type - N/A)
# Matriz exportada para relation_matrix.csv

# %%
similarities
# Out:
# [0.3920751485688889,
#  0.24168109360815113,
#  0.3655615643290906,
#  0.43464444687164644,
#  0.2371184737011372,
#  0.5678295342994409,
#  0.21177873739412562,
#  0.22973056236150358,
#  0.26709358323720056,
#  0.36233391055540115,
#  0.25661928090267905,
#  0.402510031628014,
#  0.40396037929387907,
#  0.7037833926068335,
#  0.5141708906165475,
#  0.43199046356822146,
#  0.3569728335834346,
#  0.45740258538598544,
#  0.26649430556390574,
#  0.5011708477857015,
#  0.37092959762093247,
#  0.2898493026430854,
#  0.650251419259062,
#  0.24889522555911126,
#  0.2618627788148239,
#  0.37979558043465445,
#  0.45865896035931697,
#  0.41737199801812597,
#  0,
#  0,
#  0.2093230407736913,
#  0.4802249365012553,
#  0.45773253228926336,
#  0.5026977337462417,
#  0.3631615045850585,
#  0.5321360217012999,
#  0.5636036776933413,
#  0,
#  0.57765716361756,
#  0.3196732616965549,
#  0.5271331697531743,
#  0.36474720137294,
#  0.4526283672948759,
#  0.6873372467213061,
#  0.3145585705760905,
#  0.29674905188811085,
#  0.5440077589050286,
#  0.2967707801755195,
#  0.3862122158150082,
#  0.44056080045405055,
#  0.6030727413685623,
#  0.313593764855725,
#  0.38354704466971645,
#  0.5387272000836791,
#  0.380134796138543,
#  0.17759635951099417,
#  0.29864435635244635,
#  0,
#  0.3114032176600888,
#  0,
#  0.42165850662692694,
#  0.5375381042806469,
#  0.3470093835604064,
#  0,
#  0.34965731064869837,
#  0.5864077223496053,
#  0,
#  0.5125213724588433,
#  0.2691925609019332,
#  0.4489912083554002,
#  0.3916913820124678,
#  0.4342399879737232,
#  0.6144463672978224,
#  0.4316994692910758,
#  0.4886108390782168,
#  0.1695090822017294,
#  0.3388069450446958,
#  0.5493044919320038,
#  0.21782564757016964,
#  0.4845013192793757,
#  0.42999741349698395,
#  0.5669454213669214,
#  0.567754423088053,
#  0,
#  0.18809850657678154,
#  0.4399610941769706,
#  0.1624541337098173,
#  0.45465744624245275,
#  0.36414649968220514,
#  0.39627770565145826,
#  0.29655370975185896,
#  0.30571697761369687,
#  0.27234401997297164,
#  0.501003193528406,
#  0.26041898645343275,
#  0.22840611662819812,
#  0.4491795490507453,
#  0.6214447310869156,
#  0.391579630362199]

# %%
from scipy import stats
from sklearn.metrics import accuracy_score, precision_score
# Função para converter para binário com arredondamento especial
def convert_to_binary_rounded(similarity):
    if similarity >= 0.45:  # Se for 0.45 ou maior, arredonda para 1
        return 1
    return 0

# Recalcula as predições binárias
binary_predictions_rounded = [convert_to_binary_rounded(sim) for sim in similarities]

# Adiciona as colunas ao DataFrame
df['Similarity'] = similarities
df['Prediction'] = binary_predictions_rounded  # Usa as novas predições

# Calcula as métricas com os novos valores
pearson_corr, _ = stats.pearsonr(similarities, df['Classification'])
spearman_corr, _ = stats.spearmanr(similarities, df['Classification'])
accuracy = accuracy_score(df['Classification'], binary_predictions_rounded)
precision = precision_score(df['Classification'], binary_predictions_rounded)

# Imprime os resultados
print("Resultados com arredondamento especial (>=0.45 -> 1):")
print(f"Correlação de Pearson: {pearson_corr:.4f}")
print(f"Correlação de Spearman: {spearman_corr:.4f}")
print(f"Acurácia: {accuracy:.4f}")
print(f"Precisão: {precision:.4f}")

# Imprime uma comparação das predições
print("\nComparação de algumas predições:")
comparison_df = pd.DataFrame({
    'Similarity': similarities,
    'Original_Binary': binary_predictions,
    'Rounded_Binary': binary_predictions_rounded,
    'Ground_Truth': df['Classification']
}).head(10)
print(comparison_df)

# Salva os resultados
df.to_csv('/content/CANDC/sick_evaluation_results_rounded.csv', index=False)
# Out:
# Resultados com arredondamento especial (>=0.45 -> 1):
# Correlação de Pearson: 0.2647
# Correlação de Spearman: 0.3332
# Acurácia: 0.5859
# Precisão: 0.8387
#
# Comparação de algumas predições:
#    Similarity  Original_Binary  Rounded_Binary  Ground_Truth
# 0    0.392075                0               0             1
# 1    0.241681                0               0             0
# 2    0.365562                0               0             1
# 3    0.434644                0               0             0
# 4    0.237118                0               0             1
# 5    0.567830                1               1             1
# 6    0.211779                0               0             0
# 7    0.229731                0               0             1
# 8    0.267094                0               0             0
# 9    0.362334                0               0             0
