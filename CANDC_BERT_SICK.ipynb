# %% [markdown]
# <a href="https://colab.research.google.com/github/ritaalamino/candc_master/blob/main/CANDC_BERT_SICK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## *CANDC*

# %% [markdown]
# Funções não suportadas
#
# *   --semantics
# *   --modal
# *   --elimeq não muda nada
# *   --vpe  não muda nada
# *   --robust  não muda nada
# *   --roles  não muda nada

# %% [markdown]
# ##Importa bibliotecas

# %%
# Import das bibliotecas.

# Biblioteca de logging
import logging
import subprocess
import os
import csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Instala as libraries necessárias

# %%
# Diretório do cohebert
DIRETORIO_CANDC = "CANDC"

# Diretório local para os arquivos pré-processados
DIRETORIO_LOCAL = "/content/" + DIRETORIO_CANDC + "/"

# Diretório no google drive com os arquivos pré-processados
DIRETORIO_DRIVE = "/content/drive/MyDrive/Colab Notebooks/Data/" + DIRETORIO_CANDC + "/"

# %%
# !git clone https://github.com/valeriobasile/learningbyreading.git
# Out:
# Cloning into 'learningbyreading'...
# remote: Enumerating objects: 1870, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 1870 (delta 30), reused 58 (delta 22), pack-reused 1797 (from 1)
# Receiving objects: 100% (1870/1870), 295.87 MiB | 14.33 MiB/s, done.
# Resolving deltas: 100% (722/722), done.
# Updating files: 100% (970/970), done.

# %%
os.chdir('./learningbyreading/ext')

# %%
# !./install_candc.sh
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/writer_multi_vert.o src/lib/io/writer_multi_vert.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/writer_format.o src/lib/io/writer_format.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/io/writer_factory.o src/lib/io/writer_factory.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/tagdict.o src/lib/tagger/tagdict.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/tagsetdict.o src/lib/tagger/tagsetdict.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/_baseimpl.o src/lib/tagger/_baseimpl.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/_baseimpl.cc:18:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/_baseimpl.h:42,
#                  from src/lib/tagger/_baseimpl.cc:18:
# src/include/tagger/lattice.h: In member function ‘void NLP::Taggers::Node::update(const NLP::Taggers::Node*, float)’:
# src/include/tagger/lattice.h:42:27: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    42 |         this->pid = prev->id;
#       |                           ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/_baseimpl.cc:18:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/_baseimpl.cc:18:
# src/include/tagger/_baseimpl.h: In member function ‘void NLP::Taggers::Tagger::Impl::_calc_greedy_probs(NLP::Taggers::State&, ulong, double) const’:
# src/include/tagger/_baseimpl.h:489:21: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   489 |     hist.pid = hist.id;
#       |                     ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/_baseimpl.cc:18:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/_baseimpl.cc:18:
# src/include/tagger/_baseimpl.h:490:15: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   490 |     hist.id = max_tag;
#       |               ^~~~~~~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/_baseimpl.cc:18:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# src/lib/tagger/_baseimpl.cc: In member function ‘void NLP::Taggers::Tagger::Impl::_read_attributes(const NLP::Model::Model&, const NLP::Model::Info&, std::vector<NLP::Model::Feature*>&)’:
# src/lib/tagger/_baseimpl.cc:133:25: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   133 |   }catch(NLP::Exception e){
#       |                         ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/tagger.o src/lib/tagger/tagger.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/tagger.cc:11:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/_baseimpl.h:42,
#                  from src/lib/tagger/tagger.cc:11:
# src/include/tagger/lattice.h: In member function ‘void NLP::Taggers::Node::update(const NLP::Taggers::Node*, float)’:
# src/include/tagger/lattice.h:42:27: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    42 |         this->pid = prev->id;
#       |                           ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/tagger.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/tagger.cc:11:
# src/include/tagger/_baseimpl.h: In member function ‘void NLP::Taggers::Tagger::Impl::_calc_greedy_probs(NLP::Taggers::State&, ulong, double) const’:
# src/include/tagger/_baseimpl.h:489:21: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   489 |     hist.pid = hist.id;
#       |                     ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/tagger.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/tagger.cc:11:
# src/include/tagger/_baseimpl.h:490:15: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   490 |     hist.id = max_tag;
#       |               ^~~~~~~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/tagger.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/taghist.o src/lib/tagger/taghist.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/types.o src/lib/model/types.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/types.cc:24:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/registry.o src/lib/model/registry.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/registry.cc:23:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/affix.o src/lib/model/affix.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/affix.cc:18:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/unigram.o src/lib/model/unigram.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/unigram.cc:21:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/bigram.o src/lib/model/bigram.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/bigram.cc:21:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/trigram.o src/lib/model/trigram.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/trigram.cc:21:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/model.o src/lib/model/model.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/model/model.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/model/cache.o src/lib/model/cache.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/gazetteers.o src/lib/gazetteers.cc
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/unigram.o src/lib/tagger/unigram.cc
# src/lib/tagger/unigram.cc: In member function ‘void NLP::Taggers::Unigram::_Impl::load(std::string)’:
# src/lib/tagger/unigram.cc:75:44: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    75 |           add(word)->value = tagset[max_tag];
#       |                                            ^
# In file included from src/include/base.h:48,
#                  from src/lib/tagger/unigram.cc:19:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# src/lib/tagger/unigram.cc:89:40: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    89 |       add(word)->value = tagset[max_tag];
#       |                                        ^
# In file included from src/include/base.h:48,
#                  from src/lib/tagger/unigram.cc:19:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/pos.o src/lib/tagger/pos.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/pos.cc:17:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/_baseimpl.h:42,
#                  from src/lib/tagger/pos.cc:17:
# src/include/tagger/lattice.h: In member function ‘void NLP::Taggers::Node::update(const NLP::Taggers::Node*, float)’:
# src/include/tagger/lattice.h:42:27: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    42 |         this->pid = prev->id;
#       |                           ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/pos.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/pos.cc:17:
# src/include/tagger/_baseimpl.h: In member function ‘void NLP::Taggers::Tagger::Impl::_calc_greedy_probs(NLP::Taggers::State&, ulong, double) const’:
# src/include/tagger/_baseimpl.h:489:21: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   489 |     hist.pid = hist.id;
#       |                     ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/pos.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/pos.cc:17:
# src/include/tagger/_baseimpl.h:490:15: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   490 |     hist.id = max_tag;
#       |               ^~~~~~~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/pos.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/pos.o src/main/pos.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/pos.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/pos.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/cluster_no_mpi.o src/lib/cluster_no_mpi.cc
# g++ -fPIC -o bin/pos src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/pos.o src/main/pos.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/mpos.o src/main/mpos.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/mpos.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/mpos.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/mpos src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/pos.o src/main/mpos.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/chunk.o src/lib/tagger/chunk.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/chunk.cc:11:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/_baseimpl.h:42,
#                  from src/lib/tagger/chunk.cc:11:
# src/include/tagger/lattice.h: In member function ‘void NLP::Taggers::Node::update(const NLP::Taggers::Node*, float)’:
# src/include/tagger/lattice.h:42:27: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    42 |         this->pid = prev->id;
#       |                           ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/chunk.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/chunk.cc:11:
# src/include/tagger/_baseimpl.h: In member function ‘void NLP::Taggers::Tagger::Impl::_calc_greedy_probs(NLP::Taggers::State&, ulong, double) const’:
# src/include/tagger/_baseimpl.h:489:21: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   489 |     hist.pid = hist.id;
#       |                     ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/chunk.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/chunk.cc:11:
# src/include/tagger/_baseimpl.h:490:15: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   490 |     hist.id = max_tag;
#       |               ^~~~~~~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/chunk.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/chunk.o src/main/chunk.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/chunk.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/chunk.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/chunk src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/chunk.o src/main/chunk.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/mchunk.o src/main/mchunk.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/mchunk.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/mchunk.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/mchunk src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/chunk.o src/main/mchunk.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/ner.o src/lib/tagger/ner.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/ner.cc:17:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/_baseimpl.h:42,
#                  from src/lib/tagger/ner.cc:17:
# src/include/tagger/lattice.h: In member function ‘void NLP::Taggers::Node::update(const NLP::Taggers::Node*, float)’:
# src/include/tagger/lattice.h:42:27: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    42 |         this->pid = prev->id;
#       |                           ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/ner.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/ner.cc:17:
# src/include/tagger/_baseimpl.h: In member function ‘void NLP::Taggers::Tagger::Impl::_calc_greedy_probs(NLP::Taggers::State&, ulong, double) const’:
# src/include/tagger/_baseimpl.h:489:21: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   489 |     hist.pid = hist.id;
#       |                     ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/ner.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/ner.cc:17:
# src/include/tagger/_baseimpl.h:490:15: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   490 |     hist.id = max_tag;
#       |               ^~~~~~~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/ner.cc:17:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# src/lib/tagger/ner.cc: In member function ‘void NLP::Taggers::NER::Impl::add_special(const RawWord&, NLP::PDF&) const’:
# src/lib/tagger/ner.cc:206:17: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   206 |         case 1: if(types.use_one_digit())
#       |                 ^~
# src/lib/tagger/ner.cc:208:19: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   208 |                   break;
#       |                   ^~~~~
# src/lib/tagger/ner.cc:209:17: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   209 |         case 2: if(types.use_two_digits())
#       |                 ^~
# src/lib/tagger/ner.cc:211:19: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   211 |                   break;
#       |                   ^~~~~
# src/lib/tagger/ner.cc:212:17: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   212 |         case 3: if(types.use_three_digits())
#       |                 ^~
# src/lib/tagger/ner.cc:214:19: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   214 |                   break;
#       |                   ^~~~~
# src/lib/tagger/ner.cc:215:17: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   215 |         case 4: if(types.use_four_digits())
#       |                 ^~
# src/lib/tagger/ner.cc:217:19: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   217 |                   break;
#       |                   ^~~~~
# src/lib/tagger/ner.cc:218:18: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   218 |         default: if(types.use_digits())
#       |                  ^~
# src/lib/tagger/ner.cc:220:19: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   220 |                   break;
#       |                   ^~~~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/ner.o src/main/ner.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/ner.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/ner.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/ner src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/ner.o src/main/ner.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/mner.o src/main/mner.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/mner.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/mner.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/mner src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/ner.o src/main/mner.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/tagger/super.o src/lib/tagger/super.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/_baseimpl.h:28,
#                  from src/lib/tagger/super.cc:11:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/_baseimpl.h:42,
#                  from src/lib/tagger/super.cc:11:
# src/include/tagger/lattice.h: In member function ‘void NLP::Taggers::Node::update(const NLP::Taggers::Node*, float)’:
# src/include/tagger/lattice.h:42:27: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#    42 |         this->pid = prev->id;
#       |                           ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/super.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/super.cc:11:
# src/include/tagger/_baseimpl.h: In member function ‘void NLP::Taggers::Tagger::Impl::_calc_greedy_probs(NLP::Taggers::State&, ulong, double) const’:
# src/include/tagger/_baseimpl.h:489:21: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   489 |     hist.pid = hist.id;
#       |                     ^~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/super.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# In file included from src/lib/tagger/super.cc:11:
# src/include/tagger/_baseimpl.h:490:15: warning: implicitly-declared ‘constexpr NLP::Tag& NLP::Tag::operator=(const NLP::Tag&)’ is deprecated [-Wdeprecated-copy]
#   490 |     hist.id = max_tag;
#       |               ^~~~~~~
# In file included from src/include/base.h:48,
#                  from src/include/tagger/_baseimpl.h:19,
#                  from src/lib/tagger/super.cc:11:
# src/include/tag.h:43:5: note: because ‘NLP::Tag’ has user-provided ‘NLP::Tag::Tag(const NLP::Tag&)’
#    43 |     Tag(const Tag &tag): _id(tag._id){}
#       |     ^~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/super.o src/main/super.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/super.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/super.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/super src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/super.o src/main/super.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/msuper.o src/main/msuper.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/include/tagger/main.h:15,
#                  from src/main/msuper.cc:13:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/include/tagger/main.h:17,
#                  from src/main/msuper.cc:13:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/msuper src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/tagger/super.o src/main/msuper.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/maxent/gis.o src/lib/maxent/gis.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/maxent/gis.cc:30:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/maxent/bfgs.o src/lib/maxent/bfgs.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/maxent/bfgs.cc:22:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/lib/maxent/bfgs.cc:32:
# src/include/maxent/solver.h: In instantiation of ‘void NLP::MaxEnt::Solver<T>::zoom_search(double, double, double, double, double, double, double, double, double) [with Objective = NLP::MaxEnt::BFGS]’:
# src/include/maxent/solver.h:198:20:   required from ‘void NLP::MaxEnt::Solver<T>::line_search() [with Objective = NLP::MaxEnt::BFGS]’
# src/include/maxent/solver.h:310:9:   required from ‘void NLP::MaxEnt::Solver<T>::lbfgs() [with Objective = NLP::MaxEnt::BFGS]’
# src/include/maxent/solver.h:345:9:   required from ‘bool NLP::MaxEnt::Solver<T>::iteration() [with Objective = NLP::MaxEnt::BFGS]’
# src/lib/maxent/bfgs.cc:92:28:   required from here
# src/include/maxent/solver.h:93:48: warning: parameter ‘hi_value’ set but not used [-Wunused-but-set-parameter]
#    93 |                        double lo_value, double hi_value,
#       |                                         ~~~~~~~^~~~~~~~
# src/include/maxent/solver.h:94:50: warning: parameter ‘hi_del_phi’ set but not used [-Wunused-but-set-parameter]
#    94 |                        double lo_del_phi, double hi_del_phi,
#       |                                           ~~~~~~~^~~~~~~~~~
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/lib/maxent/perceptron.o src/lib/maxent/perceptron.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/lib/maxent/perceptron.cc:29:
# ...
# g++ -W -Wall -Wextra -fPIC -O3 -Isrc/include -isystem ext/include   -c -o src/main/reestimate.o src/main/reestimate.cc
# In file included from src/include/config/options.h:15,
#                  from src/include/config/config.h:12,
#                  from src/main/reestimate.cc:18:
# src/include/config/option.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = std::__cxx11::basic_string<char>; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/option.h:182:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#   182 |       }catch(NLP::Exception e){
#       |                             ^
# In file included from src/main/reestimate.cc:20:
# src/include/config/format.h: In member function ‘void NLP::Config::Op<T>::set(const string&) [with T = NLP::IO::Format; std::string = std::__cxx11::basic_string<char>]’:
# src/include/config/format.h:40:29: warning: catching polymorphic type ‘class NLP::Exception’ by value [-Wcatch-value=]
#    40 |       }catch(NLP::Exception e){
#       |                             ^
# g++ -fPIC -o bin/reestimate src/lib/base.o src/lib/ports/unix.o src/lib/ports/unix_common.o src/lib/ports/colour.o src/lib/timer.o src/lib/input.o src/lib/word.o src/lib/version.o src/lib/licence.o src/lib/tagset.o src/lib/lexicon.o src/lib/utils/escape.o src/lib/config/node.o src/lib/config/option.o src/lib/config/config.o src/lib/io/format.o src/lib/io/stream.o src/lib/io/reader.o src/lib/io/reader_group.o src/lib/io/reader_horiz.o src/lib/io/reader_multi_horiz.o src/lib/io/reader_factory.o src/lib/io/writer.o src/lib/io/writer_stream.o src/lib/io/writer_group.o src/lib/io/writer_horiz.o src/lib/io/writer_multi_horiz.o src/lib/io/writer_vert.o src/lib/io/writer_multi_vert.o src/lib/io/writer_format.o src/lib/io/writer_factory.o src/lib/tagger/tagdict.o src/lib/tagger/tagsetdict.o src/lib/tagger/_baseimpl.o src/lib/tagger/tagger.o src/lib/tagger/taghist.o src/lib/model/types.o src/lib/model/registry.o src/lib/model/affix.o src/lib/model/unigram.o src/lib/model/bigram.o src/lib/model/trigram.o src/lib/model/model.o src/lib/model/cache.o src/lib/gazetteers.o src/lib/tagger/unigram.o src/lib/maxent/gis.o src/lib/maxent/bfgs.o src/lib/maxent/perceptron.o src/lib/extract/_baseimpl.o src/lib/extract/attributes.o src/lib/extract/contexts.o src/main/reestimate.o src/lib/cluster_no_mpi.o -Llib -lm -Lext/lib
# make: *** No rule to make target 'ext/bin/soapcpp2', needed by 'soap'.  Stop.
# bin/swipl -g "['src/prolog/nutcracker/ntokkie'], qsave_program('bin/t',[goal=start,stand_alone=true]), halt."
# %   library(error) compiled into error 0.00 sec, 81 clauses
# %   library(pairs) compiled into pairs 0.00 sec, 22 clauses
# %  library(lists) compiled into lists 0.01 sec, 206 clauses
# %   library(shlib) compiled into shlib 0.00 sec, 39 clauses
# %   library(option) compiled into swi_option 0.00 sec, 32 clauses
# %  library(readutil) compiled into read_util 0.01 sec, 112 clauses
# %  semlib(abbreviations) compiled into abbreviations 0.00 sec, 46 clauses
# %   semlib(options) compiled into options 0.00 sec, 112 clauses
# %  semlib(errors) compiled into errors 0.00 sec, 123 clauses
# % src/prolog/nutcracker/ntokkie compiled 0.02 sec, 635 clauses
# % autoloading prolog_codewalk:must_be/2 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/error
# % autoloading prolog_debug:backtrace/1 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_stack
# % autoloading oset:reverse/2 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/lists
# % autoloading record:member/2 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/lists
# % autoloading error:assertion/1 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/debug
# % autoloading qsave:current_foreign_library/2 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/shlib
# % autoloading prolog_codewalk:portray_clause/1 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/listing
# % autoloading prolog_codewalk:clause_info/4 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % autoloading prolog_codewalk:initialization_layout/4 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % autoloading prolog_codewalk:clause_name/2 from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % Autoloader: iteration 1 resolved 9 predicates and loaded 10 files in 0.064 seconds.  Restarting ...
# % Autoloader: loaded 9 files in 2 iterations in 0.089 seconds
# src/scripts/version unix
# src/scripts/version: line 53: svnversion: command not found
# Usage: grep [OPTION]... PATTERNS [FILE]...
# Try 'grep --help' for more information.
# bin/swipl -g "['src/prolog/boxer/boxer'], qsave_program('bin/boxer',[global=128000,local=128000,goal=start,stand_alone=true]), halt."
# %   library(error) compiled into error 0.00 sec, 81 clauses
# %   library(pairs) compiled into pairs 0.00 sec, 22 clauses
# %  library(lists) compiled into lists 0.01 sec, 206 clauses
# %   boxer(slashes) compiled into slashes 0.00 sec, 5 clauses
# %      semlib(options) compiled into options 0.00 sec, 112 clauses
# %     semlib(errors) compiled into errors 0.00 sec, 123 clauses
# %    boxer(alphaConversionDRT) compiled into alphaConversionDRT 0.01 sec, 166 clauses
# %     boxer(noncomp) compiled into noncomp 0.00 sec, 17 clauses
# %    boxer(mergeDRT) compiled into mergeDRT 0.00 sec, 89 clauses
# %   boxer(betaConversionDRT) compiled into betaConversionDRT 0.01 sec, 293 clauses
# %    boxer(bindingViolation) compiled into bindingViolation 0.00 sec, 33 clauses
# %    boxer(freeVarCheck) compiled into freeVarCheck 0.00 sec, 57 clauses
# %     lex(verbnet) compiled into verbnet 0.49 sec, 30,594 clauses
# %    boxer(categories) compiled into categories 0.49 sec, 30,662 clauses
# %    knowledge(antecedent) compiled into antecedent 0.01 sec, 825 clauses
# %   boxer(resolveDRT) compiled into resolveDRT 0.51 sec, 31,717 clauses
# %    boxer(morpha) compiled into morpha 0.00 sec, 62 clauses
# %   boxer(transform) compiled into transform 0.01 sec, 164 clauses
# %    knowledge(relations) compiled into relations 0.08 sec, 9,437 clauses
# %   boxer(relation) compiled into relation 0.09 sec, 9,460 clauses
# %     boxer(string2digit) compiled into string2digit 0.00 sec, 42 clauses
# %     knowledge(ne) compiled into ne 0.00 sec, 32 clauses
# %     knowledge(dates) compiled into dates 0.00 sec, 155 clauses
# %     knowledge(punctuation) compiled into punctuation 0.00 sec, 13 clauses
# %     lex(determiners) compiled into determiners 0.00 sec, 33 clauses
# %      lex(tense) compiled into tense 0.00 sec, 18 clauses
# %     lex(verbs) compiled into verbs 0.01 sec, 110 clauses
# %     boxer(coordination) compiled into coordination 0.00 sec, 11 clauses
# %     (lex/pp) compiled into lexicon 0.00 sec, 27 clauses
# %     (lex/n) compiled into lexicon 0.01 sec, 93 clauses
# %    boxer(lexicon) compiled into lexicon 0.05 sec, 844 clauses
# %   boxer(closure) compiled into closure 0.05 sec, 881 clauses
# %   boxer(typechange) compiled into typechange 0.00 sec, 26 clauses
# %   boxer(evaluation) compiled into evaluation 0.00 sec, 6 clauses
# %   boxer(input) compiled into input 0.00 sec, 23 clauses
# %   boxer(sdrt) compiled into sdrt 0.00 sec, 27 clauses
# %   boxer(drs2fdrs) compiled into drs2fdrs 0.00 sec, 76 clauses
# %    semlib(drs2tacitus) compiled into drs2tacitus 0.00 sec, 104 clauses
# %   boxer(tuples) compiled into tuples 0.01 sec, 235 clauses
# %    knowledge(amrmfs) compiled into amrmfs 0.00 sec, 244 clauses
# %    knowledge(verbalization-list-v1.01) compiled into verbalization 0.00 sec, 475 clauses
# %    knowledge(role91) compiled into role91 0.00 sec, 121 clauses
# %    knowledge(negprefix) compiled into negprefix 0.02 sec, 1,597 clauses
# %    knowledge(negsuffix) compiled into negsuffix 0.00 sec, 472 clauses
# %    knowledge(nationality) compiled into nationality 0.00 sec, 305 clauses
# %    knowledge(wiki) compiled into wiki 0.04 sec, 3,158 clauses
# %   semlib(drs2amr) compiled into drs2amr 0.09 sec, 6,840 clauses
# %   semlib(pdrs2drs) compiled into pdrs2drs 0.00 sec, 35 clauses
# %   semlib(drs2fol) compiled into drs2fol 0.00 sec, 126 clauses
# %  boxer(ccg2drs) compiled into ccg2drs 0.79 sec, 50,070 clauses
# %  boxer(version) compiled into version 0.00 sec, 2 clauses
# %  boxer(printCCG) compiled into printCCG 0.00 sec, 53 clauses
# %   boxer(xdrs2xml) compiled into xdrs2xml 0.01 sec, 127 clauses
# %   boxer(printDrs) compiled into printDrs 0.00 sec, 106 clauses
# %   semlib(drs2tex) compiled into drs2tex 0.00 sec, 32 clauses
# %  boxer(output) compiled into output 0.02 sec, 338 clauses
# % src/prolog/boxer/boxer compiled 0.82 sec, 50,723 clauses
# % autoloading prolog_codewalk:(must_be/2) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/error
# % autoloading prolog_debug:(backtrace/1) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_stack
# % autoloading oset:(reverse/2) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/lists
# % autoloading record:(member/2) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/lists
# % autoloading error:(assertion/1) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/debug
# % autoloading qsave:(current_foreign_library/2) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/shlib
# % autoloading prolog_codewalk:(portray_clause/1) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/listing
# % autoloading prolog_codewalk:(clause_info/4) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % autoloading prolog_codewalk:(initialization_layout/4) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % autoloading prolog_codewalk:(clause_name/2) from /content/learningbyreading/ext/candc/lib/swipl-6.6.6/library/prolog_clause
# % Autoloader: iteration 1 resolved 10 predicates and loaded 10 files in 0.105 seconds.  Restarting ...
# % Autoloader: loaded 10 files in 2 iterations in 0.181 seconds
# models/
# models/config
# models/pos
# models/super
# models/parser/
# models/parser/log
# models/parser/cats/
# models/parser/cats/markedup
# models/parser/cats/trAP
# models/parser/cats/trNP
# models/parser/cats/trPP
# models/parser/cats/trPP_qus
# models/parser/cats/trVP_to
# models/parser/features
# models/parser/lexicon
# models/parser/rules
# models/parser/model.config
# models/parser/info
# models/parser/weights
# models/parser/stats
# models/parser/config
# models/pos_quotes/
# models/pos_quotes/log
# models/pos_quotes/classes
# models/pos_quotes/lexicon
# models/pos_quotes/tagdict
# models/pos_quotes/attributes
# models/pos_quotes/unknowns
# models/pos_quotes/number_unknowns
# models/pos_quotes/info
# models/pos_quotes/config
# models/pos_quotes/weights
# models/super_quotes/
# models/super_quotes/log
# models/super_quotes/classes
# models/super_quotes/lexicon
# models/super_quotes/tagdict
# models/super_quotes/postags
# models/super_quotes/posdict
# models/super_quotes/attributes
# models/super_quotes/unknowns
# models/super_quotes/info
# models/super_quotes/config
# models/super_quotes/weights
# models/muc/
# models/muc/gazetteer/
# models/muc/gazetteer/common
# models/muc/gazetteer/firstnames
# models/muc/gazetteer/lastnames
# models/muc/gazetteers
# models/muc/classes
# models/muc/lexicon
# models/muc/tagdict
# models/muc/postags
# models/muc/chunktags
# models/muc/attributes
# models/muc/unknowns
# models/muc/info
# models/muc/config
# models/muc/weights
# models/chunk_quotes/
# models/chunk_quotes/classes
# models/chunk_quotes/lexicon
# models/chunk_quotes/tagdict
# models/chunk_quotes/postags
# models/chunk_quotes/attributes
# models/chunk_quotes/unknowns
# models/chunk_quotes/info
# models/chunk_quotes/config
# models/chunk_quotes/weights
# models/pos_questions/
# models/pos_questions/log
# models/pos_questions/classes
# models/pos_questions/lexicon
# models/pos_questions/tagdict
# models/pos_questions/attributes
# models/pos_questions/unknowns
# models/pos_questions/number_unknowns
# models/pos_questions/info
# models/pos_questions/config
# models/pos_questions/weights
# models/super_questions/
# models/super_questions/log
# models/super_questions/classes
# models/super_questions/lexicon
# models/super_questions/tagdict
# models/super_questions/postags
# models/super_questions/posdict
# models/super_questions/attributes
# models/super_questions/unknowns
# models/super_questions/info
# models/super_questions/config
# models/super_questions/weights
# models/questions/
# models/questions/parser
# models/questions/ner
# models/questions/pos
# models/questions/super
# models/questions/chunk
# models/questions/verbstem.list
# models/questions/config
# models/noquotes/
# models/noquotes/pos
# models/noquotes/super
# models/noquotes/parser
# models/noquotes/muc
# models/noquotes/chunk
# models/noquotes/config
# models/noquotes/verbstem.list
# models/pos_noquotes/
# models/pos_noquotes/log
# models/pos_noquotes/classes
# models/pos_noquotes/lexicon
# models/pos_noquotes/tagdict
# models/pos_noquotes/attributes
# models/pos_noquotes/unknowns
# models/pos_noquotes/number_unknowns
# models/pos_noquotes/info
# models/pos_noquotes/config
# models/pos_noquotes/weights
# models/super_noquotes/
# models/super_noquotes/log
# models/super_noquotes/classes
# models/super_noquotes/lexicon
# models/super_noquotes/tagdict
# models/super_noquotes/postags
# models/super_noquotes/posdict
# models/super_noquotes/attributes
# models/super_noquotes/unknowns
# models/super_noquotes/info
# models/super_noquotes/config
# models/super_noquotes/weights
# models/ner
# models/chunk
# models/verbstem.list
# models/boxer/
# models/boxer/config
# models/boxer/super
# models/boxer/parser
# models/boxer/pos
# models/boxer/ner
# models/boxer/chunk
# models/boxer/verbstem.list

# %%
# # Gera boxer em xml
# command = "./install_candc.sh"
# subprocess.run(command, shell=True, check=True, capture_output=True)

# %%
# Import das bibliotecas.
import sys # Biblioteca para acessar módulos do sistema

# Se estiver executando no Google Colaboratory
# Retorna true ou false se estiver no Google Colaboratory
IN_COLAB = "google.colab" in sys.modules

# %%
# Importando as bibliotecas.
import os

# Cria o diretório para receber os arquivos Originais e Permutados
# Diretório a ser criado
dirbase = DIRETORIO_LOCAL[:-1]

if not os.path.exists(dirbase):
    # Cria o diretório
    os.makedirs(dirbase)
    logging.info("Diretório criado: {}".format(dirbase))
else:
    logging.info("Diretório já existe: {}".format(dirbase))

# %% [markdown]
# ## Verifica se arquivos estão corretos

# %%
os.chdir('/content/learningbyreading/ext/candc')
# !ls
# Out:
# bin	    lib		       Makefile.cygwin	 Makefile.mingw    models	     RELEASE.txt
# doc	    LICENCE-BOXER.txt  Makefile.deps	 Makefile.sunos    models-1.02.tbz2  share
# ext	    LICENCE.txt        Makefile.macosx	 Makefile.targets  pl-6.6.6	     src
# grepsource  Makefile	       Makefile.macosxu  Makefile.unix	   pl-6.6.6.tar.gz   working

# %%
#!chmod +x bin/candc
# !bin/candc --version
# !bin/boxer --version
# Out:
# candc v1.00 (unix build on 26 November 2024, 16:03:35)
# boxer v1.00 (unix build on 26 November 2024, 16:07:44)

# %% [markdown]
# Roda teste

# %% [markdown]
# #Importa word2vec

# %%
import re
import numpy as np

# %%
from nltk.corpus import wordnet as wn
from scipy.spatial.distance import cosine
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# #Carrega word2vec

# %%
# from gensim.models import KeyedVectors
# import gensim.downloader as api

# # Carregar o modelo Word2Vec
# word2vec_model = api.load('glove-wiki-gigaword-300')

# %%
# word2vec_model.init_sims(replace=True)

# %% [markdown]
# #Carrega bert

# %%
from transformers import BertTokenizer, BertModel
import torch

# Inicializa o tokenizer e o modelo
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased',
                                          do_lower_case=False)
model = BertModel.from_pretrained('bert-base-multilingual-cased',
                                  output_attentions=False,
                                  output_hidden_states=True)

# Função para obter embeddings do BERT
def get_bert_embeddings(text):
    # Tokeniza a entrada e converte para tensor
    inputs = tokenizer(text, return_tensors="pt")

    # Obtém os embeddings
    with torch.no_grad():
        outputs = model(**inputs)

    # Retorna os embeddings da última camada
    return outputs.last_hidden_state
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]

# %%
# from transformers import BertTokenizer, BertModel
# import torch

# # Initialize the tokenizer and the model
# tokenizer = BertTokenizer.from_pretrained('bert-large-cased')
# model = BertModel.from_pretrained('bert-large-cased')

# # Set the model to evaluation mode
# model.eval()

# # Function to obtain BERT embeddings
# def get_bert_embeddings(text_list):
#     # Ensure text_list is not empty
#     if not text_list:
#         return None

#     # Tokenize the input batch and convert to tensors
#     inputs = tokenizer(text_list, return_tensors="pt", padding=True, truncation=True)

#     # Obtain the embeddings
#     with torch.no_grad():
#         outputs = model(**inputs)

#     # Return the embeddings from the last layer
#     return outputs.last_hidden_state

# # Example usage
# text_list = ["This is an example sentence.", "Another sentence for illustration."]
# embeddings = get_bert_embeddings(text_list)
# print(embeddings.shape)  # Print the shape of the embeddings tensor

# %%
# Exemplo de uso
embeddings = get_bert_embeddings("Hello, world!")
print(embeddings)

# %% [markdown]
# # Importa Paragram300

# %%
# from gensim.models import KeyedVectors

# # Path to the downloaded model files
# model_path = DIRETORIO_DRIVE + 'paragram-300-sl999.model'

# # # Carregar o modelo Word2Vec
# word2vec_model = KeyedVectors.load(model_path)

# %%
# word2vec_model.init_sims(replace=True)

# %% [markdown]
# #Define função do grafo

# %%
class Graph:
    def __init__(self, sentence: str, debug: bool = False):
        self.words = sentence.split(" ")
        self.count = len([word for word in self.words if len(word) > 0])
        self.gLen = self.count
        self.nodes = [None] * (self.count * 2)  # Armazenamento para conceitos
        self.edges = [None] * (self.count * 2)  # Armazenamento para arestas
        self.conceptCount = 0  # Contador para conceitos
        self.edgeCount = 0  # Contador para arestas
        self.repeated = 0
        self.autoInc = 0  # Variável para auto-incremento
        self.debug = debug  # Variável para debug

        if debug:
            print(sentence)

    def get_vector(self, word):
        return word2vec_model[word] if word in word2vec_model else np.zeros(word2vec_model.vector_size)

    def get_vector_bert(self, dic, word):
      # Sua lógica para obter o vetor BERT
      return dic[word] if word in dic else np.zeros(len(next(iter(dic.values()))))

    def getCode(self):
        # Implementação do método getCode
        code = f"ma{self.autoInc}"
        self.autoInc += 1
        return code

    def addConcept(self, name: str, code: str, pos: str):
        # Verifica se o conceito já existe e adiciona uma nova instância se necessário
        for i in range(self.conceptCount):
            if self.nodes[i]['code'] == code:
                nCode = self.getCode()
                self.addConcept(name, nCode, pos)
                rName = self.getCode()
                self.addRelationIn("equality", rName, code)
                self.addRelationEx("equality", rName, nCode)
                return

        # Expandir a lista se necessário
        if self.conceptCount >= len(self.nodes):
            self.nodes.append(None)

        # Adicionar o novo conceito
        self.nodes[self.conceptCount] = {'lemma': name, 'code': code, 'pos': pos}
        self.conceptCount += 1

    def addRelationIn(self, name: str, code: str, in_relation: str):
        found = False
        for i in range(self.edgeCount):
            if self.edges[i]['code'] == code:
                found = True
                self.edges[i]['in'] = in_relation
                break
        if not found:
            if self.edgeCount >= len(self.edges):
                self.edges.append(None)  # Expande a lista
            self.edges[self.edgeCount] = {'code': code, 'name': name, 'in': in_relation}
            self.edgeCount += 1

    def addRelationEx(self, name: str, code: str, ex: str):
        found = False
        for i in range(self.edgeCount):
            if self.edges[i]['code'] == code:
                found = True
                self.edges[i]['ex'] = ex
                break
        if not found:
            if self.edgeCount >= len(self.edges):
                self.edges.append(None)  # Expande a lista
            self.edges[self.edgeCount] = {'code': code, 'name': name, 'ex': ex}
            self.edgeCount += 1

    def addIsRelation(self, name: str, code: str):
        found = False
        for i in range(self.edgeCount):
            if self.edges[i]['code'] == code:
                self.edges[i]['name'] = name
                return
        self.edges[self.edgeCount] = {'code': code, 'name': name}
        self.edgeCount += 1

    def getWeight(self, relation: str) -> int:
        if relation == "equality":
            return 1
        elif relation == "is":
            return 4
        elif relation == "rep":
            return 1
        elif relation == "for":
            return 1
        elif relation == "on":
            return 1
        elif relation == "of":
            return 1
        elif relation == "in":
            return 3
        elif relation == "experiencer":
            return 6
        elif relation == "agent":
            return 8
        elif relation == "theme":
            return 8
        else:
            return 1

    def printNodes(self):
        for i in range(self.conceptCount):
            node = self.nodes[i]
            print(f"{node['code']}   {node['lemma']}   {node['pos']}")

    def printEdges(self):
        for i in range(self.edgeCount):
            edge = self.edges[i]
            print(f"{edge['name']}\t{edge.get('in', '')}\t{edge.get('ex', '')}")

    def getNode(self, code: str):
        for i in range(self.conceptCount):
            if self.nodes[i] and self.nodes[i]['code'] == code:
                return self.nodes[i]

        for i in range(self.edgeCount):
            edge = self.edges[i]
            if edge:
                if 'name' in edge and edge['name'] == "equality":
                    if 'ex' in edge and edge['ex'] == code:
                        in_code = edge.get('in')  # Use .get() to avoid KeyError
                        if in_code:
                            return self.getNode(in_code)
        return None  # Return None or a default value if no node is found

    def finalize(self):
        for i in range(self.edgeCount):
            if self.edges[i]['name'] == "is":
                for j in range(self.edgeCount):
                    if self.edges[i]['code'] == self.edges[j]['code']:
                        self.edges[i]['ex'] = self.edges[j]['ex']
                        self.edges[i]['in'] = self.edges[j]['in']
                        print("found")
                        break

    def checkGraph(self) -> bool:
            if self.debug:
                for i in range(self.conceptCount):
                    node = self.nodes[i]
                    if node:
                        print(f"{node['code']}   {node['lemma']}")

            for i in range(self.edgeCount):
                print(i)
                edge = self.edges[i]
                print(edge)
                if edge:
                    in_node_obj = self.getNode(edge.get('in'))
                    ex_node_obj = self.getNode(edge.get('ex'))

                    in_node = in_node_obj['lemma'] if in_node_obj is not None else None
                    ex_node = ex_node_obj['lemma'] if ex_node_obj is not None else None

                    print(f"{in_node}  {edge['name']}   {ex_node}")

                    if edge['name'] == "equality" and in_node == ex_node:
                        self.repeated += 1

                    for j in range(self.edgeCount):
                        other_edge = self.edges[j]
                        if other_edge and edge['name'] == other_edge['name']:
                            in_node_other_obj = self.getNode(other_edge.get('in'))
                            ex_node_other_obj = self.getNode(other_edge.get('ex'))
                            in_node_other = in_node_other_obj['lemma'] if in_node_other_obj is not None else None
                            ex_node_other = ex_node_other_obj['lemma'] if ex_node_other_obj is not None else None

                            if in_node == in_node_other and ex_node == ex_node_other:
                                other_edge['name'] = "rep"
                                self.repeated += 1

            return True if self.repeated > 0 else False

    def matchRelationNameSTS(self, r1, r2):
        print(f"{r1}    {r2}")
        if r1 == "rep" or r2 == "rep":
            return 0.5
        if r1 == "topic" or r2 == "topic":
            return 0.3
        if r1 == "is" and r2 == "is":
            return 0.7
        if r1 == "equality" and r2 == "equality":
            return 0.7
        if r1 == "rep":
            return 0.0
        if r1 == r2:
            return 1
        if (r1 == "experiencer" and r2 == "of") or (r1 == "of" and r2 == "experiencer"):
            return 0.8
        if (r1 == "theme" and r2 == "agent") or (r1 == "agent" and r2 == "theme"):
            return 0.6
        else:
            return 0.79 - 0.01 * (self.getWeight(r1) + self.getWeight(r2))

    # Convertendo a função matchRelationName para Python
    def matchRelationName(self, r1: str, r2: str) -> float:
        if r1 == "is" and r2 == "is":
            return 0.7
        if r1 == "equality" and r2 == "equality":
            return 0.7
        if r1 == "rep":
            return 0.0
        if r1 == r2:
            return 1.0
        else:
            return 0.73


    # Corrigindo a função stringSim uma última vez
    def stringSim(self, s1: str, s2: str) -> float:
        m, n = len(s1), len(s2)

        if m == 0 and n == 0: return 1.0
        if m == 0 or n == 0: return 0.0

        costs = [0] * (n + 1)

        # Initialize the array
        for k in range(n + 1):
            costs[k] = k

        for i, c1 in enumerate(s1):
            costs[0] = i + 1
            corner = i

            for j, c2 in enumerate(s2):
                upper = costs[j + 1]
                if c1 == c2:
                    costs[j + 1] = corner
                else:
                    t = min(upper, corner)
                    costs[j + 1] = min(costs[j], t) + 1
                corner = upper

        result = costs[n]
        return 1 - float(result) / max(m, n)

    def expand(self, word):
      ewords = [word]
      for edge in self.edges:
          if edge and edge['name'] in ["equality", "is", "of"]:
              node_ex = self.getNode(edge['ex'])
              node_in = self.getNode(edge['in'])

              if node_ex and node_ex['lemma'] == word:
                  ewords.append(node_in['lemma']) if node_in else None
              elif node_in and node_in['lemma'] == word:
                  ewords.append(node_ex['lemma']) if node_ex else None

      return ewords

# %% [markdown]
# #GraphSTSBert

# %%
class GraphSTSBert(Graph):
    def __init__(self, sentence: str, debug: bool = False):
        super().__init__(sentence, debug)

    def matchConceptBert(self, dic1, dic2, c1, c2):
        vec1 = self.get_vector_bert(dic1, c1)
        vec2 = self.get_vector_bert(dic2, c2)
        # Similaridade do cosseno
        return 1 - cosine(vec1, vec2) if np.any(vec1) and np.any(vec2) else 0

    def matchConceptWithExpansionBert(self, dic1, dic2, g1, c1, g2, c2):
        all1 = g1.expand(c1)
        all2 = g2.expand(c2)
        print("expansions:", all1, all2)
        max_similarity = 0

        for word1 in all1:
            for word2 in all2:
                similarity = self.matchConceptBert(dic1, dic2, word1, word2)
                if similarity > max_similarity:
                    max_similarity = similarity

        return max_similarity

    def matchRelationBert(self, dic1, dic2, g1, r1, g2, r2):
        node_g1_in = g1.getNode(r1['in'])
        node_g1_ex = g1.getNode(r1['ex'])
        node_g2_in = g2.getNode(r2['in'])
        node_g2_ex = g2.getNode(r2['ex'])

        # Verifica se algum dos nós é None e retorna 0 em tal caso
        if not all([node_g1_in, node_g1_ex, node_g2_in, node_g2_ex]):
            return 0

        node_in_g1 = node_g1_in['lemma']
        node_ex_g1 = node_g1_ex['lemma']
        node_in_g2 = node_g2_in['lemma']
        node_ex_g2 = node_g2_ex['lemma']

        # d1 = self.matchConceptWithExpansionBert(dic1, dic2, g1, node_in_g1, g2, node_in_g2)
        # d2 = self.matchConceptWithExpansionBert(dic2, dic2, g1, node_ex_g1, g2, node_ex_g2)
        d1 = self.matchConceptBert(dic1, dic2, node_in_g1, node_in_g2)
        d2 = self.matchConceptBert(dic1, dic2, node_ex_g1, node_ex_g2)
        d3 = self.matchRelationNameSTS(r1['name'], r2['name'])

        return ((d2 + d1) / 2.0) * d3

    def matchGraphBert(self, dic1, dic2, g):
        matrix = np.zeros((self.edgeCount, g.edgeCount))

        for i in range(self.edgeCount):
            for j in range(g.edgeCount):
                similarity = self.matchRelationBert(dic1, dic2, self, self.edges[i], g, g.edges[j])
                matrix[i, j] = similarity

        sum_d1, sum_d2, weight_sum_d1, weight_sum_d2 = 0, 0, 0, 0
        nan_count_d1, nan_count_d2 = 0, 0

        for i in range(self.edgeCount):
            max_val = np.max(matrix[i, :])
            if max_val == 0:
                nan_count_d1 += 1
            else:
                rel = g.edges[np.argmax(matrix[i, :])]['name']
                weight = self.getWeight(rel)
                sum_d1 += max_val * weight
                weight_sum_d1 += weight

        for j in range(g.edgeCount):
            max_val = np.max(matrix[:, j])
            if max_val == 0:
                nan_count_d2 += 1
            else:
                rel = self.edges[np.argmax(matrix[:, j])]['name']
                weight = self.getWeight(rel)
                sum_d2 += max_val * weight
                weight_sum_d2 += weight

        d1 = sum_d1 / weight_sum_d1 if weight_sum_d1 > 0 else 0
        d2 = sum_d2 / weight_sum_d2 if weight_sum_d2 > 0 else 0

        g1.printRelationMatrix(matrix, g1, g2, export_csv=True, filename="relation_matrix.csv")

        return (d1 + d2) / 2 if self.edgeCount - nan_count_d1 > 0 and g.edgeCount - nan_count_d2 > 0 else 0


    def getNodeLemma(self, code):
        node = self.getNode(code)
        return node['lemma'] if node else 'N/A'

    def printRelationMatrix(self, matrix, g1, g2, export_csv=False, filename="relation_matrix.csv"):
        print("Matriz de Relações:")
        header = [""] + [f"{g2.edges[j]['name']} ({self.getNodeLemma(g2.edges[j]['in'])} - {self.getNodeLemma(g2.edges[j]['ex'])})" for j in range(g2.edgeCount)]
        print("     ".join(header))

        rows = []
        for i in range(self.edgeCount):
            row = [f"{g1.edges[i]['name']} ({self.getNodeLemma(g1.edges[i]['in'])} - {self.getNodeLemma(g1.edges[i]['ex'])})"]
            for j in range(g2.edgeCount):
                cell_value = f"{matrix[i, j]:.4f} ({self.getNodeLemma(g1.edges[i]['in'])} - {self.getNodeLemma(g1.edges[i]['ex'])}, {self.getNodeLemma(g2.edges[j]['in'])} - {self.getNodeLemma(g2.edges[j]['ex'])})"
                row.append(cell_value)
            rows.append(row)

        # Imprimir a matriz de relações
        for row in rows:
            print("     ".join(row))

        # Exportar para CSV se necessário
        if export_csv:
            with open(filename, 'w', newline='') as csvfile:
                csvwriter = csv.writer(csvfile)
                csvwriter.writerow(header)
                csvwriter.writerows(rows)
            print(f"Matriz exportada para {filename}")


    def calculateGraph(self):
        matrix = np.zeros((self.edgeCount, g.edgeCount))
        for j in range(self.edgeCount):
            max_val = np.max(matrix[:, j])
            if max_val == 0:
                nan_count_d2 += 1
            else:
                rel = self.edges[np.argmax(matrix[:, j])]['name']
                weight = self.getWeight(rel)
                sum_d2 += max_val * weight
                weight_sum_d2 += weight

# %% [markdown]
# #Define função similaridade dos grafos

# %%
class GraphSTS(Graph):
    def __init__(self, sentence: str, debug: bool = False):
        super().__init__(sentence, debug)

    def matchConcept(self, c1, c2):
        vec1 = self.get_vector(c1)
        vec2 = self.get_vector(c2)
        # Similaridade do cosseno
        return 1 - cosine(vec1, vec2) if np.any(vec1) and np.any(vec2) else 0

    def matchConceptWithExpansion(self, g1, c1, g2, c2):
        all1 = g1.expand(c1)
        all2 = g2.expand(c2)
        print("expansions:", all1, all2)
        max_similarity = 0

        for word1 in all1:
            for word2 in all2:
                similarity = self.matchConcept(word1, word2)
                if similarity > max_similarity:
                    max_similarity = similarity

        return max_similarity

    def matchRelation(self, g1, r1, g2, r2):
        node_g1_in = g1.getNode(r1['in'])
        node_g1_ex = g1.getNode(r1['ex'])
        node_g2_in = g2.getNode(r2['in'])
        node_g2_ex = g2.getNode(r2['ex'])

        # Verifica se algum dos nós é None e retorna 0 em tal caso
        if not all([node_g1_in, node_g1_ex, node_g2_in, node_g2_ex]):
            return 0

        node_in_g1 = node_g1_in['lemma']
        node_ex_g1 = node_g1_ex['lemma']
        node_in_g2 = node_g2_in['lemma']
        node_ex_g2 = node_g2_ex['lemma']

        # d1 = self.matchConceptWithExpansion(g1, node_in_g1, g2, node_in_g2)
        # d2 = self.matchConceptWithExpansion(g1, node_ex_g1, g2, node_ex_g2)
        d1 = self.matchConcept(node_in_g1, node_in_g2)
        d2 = self.matchConcept(node_ex_g1, node_ex_g2)
        d3 = self.matchRelationNameSTS(r1['name'], r2['name'])

        return ((d2 + d1) / 2.0) * d3

    def calculateGraph(self):
        matrix = np.zeros((self.edgeCount, g.edgeCount))
        for j in range(self.edgeCount):
            max_val = np.max(matrix[:, j])
            if max_val == 0:
                nan_count_d2 += 1
            else:
                rel = self.edges[np.argmax(matrix[:, j])]['name']
                weight = self.getWeight(rel)
                sum_d2 += max_val * weight
                weight_sum_d2 += weight

    def printRelationMatrix(self, matrix, g, export_csv=False, filename="relation_matrix.csv"):
        print("Matriz de Relações:")
        print("     ", end="")
        header = [""] + [g.edges[j]['name'] for j in range(g.edgeCount)]
        print("     ".join(header))

        rows = []
        for i in range(self.edgeCount):
            row = [self.edges[i]['name']]
            print(f"{self.edges[i]['name']:>12}", end="     ")
            for j in range(g.edgeCount):
                print(f"{matrix[i, j]:>12.4f}", end="     ")
                row.append(matrix[i, j])
            rows.append(row)
            print()

        if export_csv:
            with open(filename, 'w', newline='') as csvfile:
                csvwriter = csv.writer(csvfile)
                csvwriter.writerow(header)
                csvwriter.writerows(rows)
            print(f"Matriz exportada para {filename}")

    def matchGraph(self, g):
        matrix = np.zeros((self.edgeCount, g.edgeCount))

        for i in range(self.edgeCount):
            for j in range(g.edgeCount):
                similarity = self.matchRelation(self, self.edges[i], g, g.edges[j])
                matrix[i, j] = similarity

        sum_d1, sum_d2, weight_sum_d1, weight_sum_d2 = 0, 0, 0, 0
        nan_count_d1, nan_count_d2 = 0, 0

        for i in range(self.edgeCount):
            max_val = np.max(matrix[i, :])
            if max_val == 0:
                nan_count_d1 += 1
            else:
                rel = g.edges[np.argmax(matrix[i, :])]['name']
                weight = self.getWeight(rel)
                sum_d1 += max_val * weight
                weight_sum_d1 += weight

        for j in range(g.edgeCount):
            max_val = np.max(matrix[:, j])
            if max_val == 0:
                nan_count_d2 += 1
            else:
                rel = self.edges[np.argmax(matrix[:, j])]['name']
                weight = self.getWeight(rel)
                sum_d2 += max_val * weight
                weight_sum_d2 += weight

        d1 = sum_d1 / weight_sum_d1 if weight_sum_d1 > 0 else 0
        d2 = sum_d2 / weight_sum_d2 if weight_sum_d2 > 0 else 0

        self.printRelationMatrix(matrix, g)

        return (d1 + d2) / 2 if self.edgeCount - nan_count_d1 > 0 and g.edgeCount - nan_count_d2 > 0 else 0

# %%
# # Exemplo de uso
# graph = GraphSTS("A cock is an adult male chicken")
# idf_value = graph.get_idf("is")
# print(f"Valor IDF para 'cock': {idf_value}")

# %% [markdown]
# #Gera os grafos a partir da classe

# %%
def generate_graphs(fres):
    # Regular expressions
    conceptReg = re.compile(r"c\d+:(.+?):.+instance (.+?) ")
    argReg = re.compile(r"c\d+:(.+?):.+arg (.+?) ")
    inRelReg = re.compile(r"(.*?):(.*?):.* int (.*?) ")
    exRelReg = re.compile(r"(.*?):(.*?):.* ext (.*?) ")
    inEqRelReg = re.compile(r"(.*?):equality int (.*?) ")
    exEqRelReg = re.compile(r"(.*?):equality ext (.*?) ")
    isReg = re.compile(r".* (.*?):equality \d+ . is ")
    refReg = re.compile(r".+referent (.+?) .* (.+?) ")

    for i in range(3):
      sentence = fres.readline()

    sentence = sentence.replace("%%% ", "")
    g1 = GraphSTSBert(sentence, True)
    # g1 = GraphSTS(sentence, True)

    # print(g1.words)
    for line in fres:
        # Initialize your GraphSTS object here (Placeholder)
        if line and line[0] == '%':
            continue
        else:
            match = conceptReg.search(line)
        if match:
            g1.addConcept(match.group(1), match.group(2), "")
            pass
        elif (match := argReg.search(line)):
            g1.addConcept(match.group(1), match.group(2), "jj")
            pass
        elif (match := inRelReg.search(line)):
            g1.addRelationIn(match.group(2), match.group(1), match.group(3))
            pass
        elif (match := exRelReg.search(line)):
            g1.addRelationEx(match.group(2), match.group(1), match.group(3))
            pass
        elif (match := inEqRelReg.search(line)):
            g1.addRelationIn("equality", match.group(1), match.group(2))
            pass
        elif (match := exEqRelReg.search(line)):
            g1.addRelationEx("equality", match.group(1), match.group(2))
            pass
        elif (match := isReg.search(line)):
            g1.addIsRelation("is", match.group(1))
            pass
        elif (match := refReg.search(line)):
            temp = match.group(2)
            if len(temp) > 3:
                g1.addConcept(match.group(2), match.group(1), "ref")
                pass

    return g1

# %% [markdown]
# # Processa usando BERT

# %%
# Função para obter embeddings de uma sentença
def get_sentence_embeddings(sentence):
  # Tokeniza a sentença
  inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True, max_length=512)

  # Obtém os embeddings
  with torch.no_grad():
      outputs = model(**inputs)

  # Mapeia tokens para palavras
  token_embeddings = outputs.last_hidden_state.squeeze().numpy()
  tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"][0])

  # Cria um dicionário para mapear palavras aos seus embeddings
  word_embeddings = {}
  current_word = ""
  word_embedding = None

  for i, token in enumerate(tokens):
      # Se é o primeiro subtoken de uma nova palavra
      if token.startswith("##"):
          token = token[2:]  # Remove o prefixo '##'
          current_word += token
          word_embedding += token_embeddings[i]
      else:
          if current_word:
              # Adiciona a palavra anterior ao dicionário
              word_embeddings[current_word] = word_embedding / len(current_word.split("##"))
          current_word = token
          word_embedding = token_embeddings[i]

  # Adiciona a última palavra
  if current_word:
      word_embeddings[current_word] = word_embedding / len(current_word.split("##"))

  return word_embeddings

# %% [markdown]
# #Importa dataset

# %%
# Nome do arquivo
NOME_ARQUIVO_ORIGINAL_COMPACTADO = "cohquad_sick_test.xlsx"

# %%
# Se estiver executando no Google Colaboratory
if IN_COLAB:

  # !cp "$DIRETORIO_DRIVE$NOME_ARQUIVO_ORIGINAL_COMPACTADO" "$DIRETORIO_LOCAL"

  logging.info("Terminei a cópia.")

# %% [markdown]
# #Processa dataset

# %%
import pandas as pd
import os
import subprocess

# Função para processar sentenças e gerar os grafos
def process_sentence(sentence, file_name):
    # Grava a sentença em um arquivo temporário
    with open(file_name, 'w') as file:
        file.write(sentence)

    # Chama o CandC e o Boxer
    subprocess.run(f'echo "{sentence}" | bin/candc --models models/boxer --candc-printer boxer --output /content/CANDC/{file_name}_candc', shell=True)
    subprocess.run(f'bin/boxer --input /content/CANDC/{file_name}_candc --output /content/CANDC/{file_name}_drg --semantics drg', shell=True)

# %%
# Lê o arquivo CSV
# df = pd.read_csv('/content/CANDC/dataset.csv')
df = pd.read_excel('/content/CANDC/cohquad_sick_test.xlsx')
df = df[:100]
df
# Out:
#     Quality     #1 ID      #2 ID  \
# 0         1    SENT_1  SENT_1333
# 1         0    SENT_2  SENT_1334
# 2         0    SENT_3  SENT_1335
# 3         0    SENT_4  SENT_1336
# 4         1    SENT_5  SENT_1337
# ..      ...       ...        ...
# 95        0   SENT_96  SENT_1428
# 96        1   SENT_97  SENT_1429
# 97        0   SENT_98  SENT_1430
# 98        1   SENT_99  SENT_1431
# 99        1  SENT_100  SENT_1432
#
#                                             #1 String  \
# 0           Rugby players are not tackling each other
# 1    A soccer player is being tackled by his opponent
# 2   There is no soccer player who is being tackled...
# 3    A soccer player is being tackled by his opponent
# 4   A dog, which is white, is standing on fallen l...
# ..                                                ...
# 95                A dog is catching a ball in mid air
# 96  A brown and white dog is jumping in the air wi...
# 97  A brown and white dog is jumping in the air wi...
# 98  A brown and white dog is jumping in the air wi...
# 99  A woman is speaking loudly on her cell phone a...
#
#                                             #2 String
# 0               Rugby players are tackling each other
# 1   Some people playing rugby are tackling each other
# 2               Rugby players are tackling each other
# 3               Rugby players are tackling each other
# 4            A white dog is standing on fallen leaves
# ..                                                ...
# 95  A brown and white dog is resting on the ground...
# 96         A ball is being caught by a dog in mid air
# 97               A dog is missing the ball in mid air
# 98                A dog is caught mid air with a ball
# 99  A woman is speaking on her cell phone and is k...
#
# [100 rows x 5 columns]

# %% [markdown]
# ##Processa usando word2vec

# %%
import re

# Nova função para converter similaridade em binário
def convert_to_binary(similarity, threshold=0.5):
    return 1 if similarity >= threshold else 0

# Função para limpar a sentença removendo pontos e vírgulas
def clean_sentence(sentence):
    return re.sub(r'[.,]', '', sentence)

# Lista para armazenar os resultados de similaridade
similarities = []
binary_predictions = []

for index, row in df.iterrows():
    # Limpa e processa as duas sentenças
    sentence1_clean = clean_sentence(row['#1 String'])
    process_sentence(sentence1_clean, 'sentence1')
    print(sentence1_clean)
    dict1 = get_sentence_embeddings(sentence1_clean)
    sentence2_clean = clean_sentence(row['#2 String'])
    process_sentence(sentence2_clean, 'sentence2')
    print(sentence2_clean)
    dict2 = get_sentence_embeddings(sentence2_clean)

    # Abre os arquivos processados
    with open("/content/CANDC/sentence1_drg", "r") as fres, open("/content/CANDC/sentence2_drg", "r") as fres2:
        # Gera os grafos
        g1 = generate_graphs(fres)
        g2 = generate_graphs(fres2)

        # Calcula e armazena a similaridade
        similarity = g1.matchGraphBert(dict1, dict2, g2)
        # similarity = g1.matchGraph(g2)
        similarities.append(similarity)
        binary_predictions.append(convert_to_binary(similarity))

# Adiciona a coluna de similaridade ao DataFrame
df['Similarity'] = similarities

# Salva o DataFrame modificado como CSV
# df.to_csv('/content/CANDC/results.csv', index=False)
# Out:
# Rugby players are not tackling each other
# Rugby players are tackling each other
# Rugby players are not tackling each other
#
# Rugby players are tackling each other
#
# equality    equality
# equality    Actor
# equality    Theme
# equality    equality
# Actor    equality
# Actor    Actor
# Actor    Theme
# Actor    equality
# Theme    equality
# Theme    Actor
# Theme    Theme
# Theme    equality
# equality    equality
# equality    Actor
# equality    Theme
# equality    equality
# Matriz de Relações:
#      equality (N/A - N/A)     Actor (N/A - N/A)     Theme (N/A - N/A)     equality (N/A - other)
# equality (player - rugby)     0.0000 (player - rugby, N/A - N/A)     0.0000 (player - rugby, N/A - N/A)     0.0000 (player - rugby, N/A - N/A)     0.0000 (player - rugby, N/A - other)
# Actor (tackle - player)     0.0000 (tackle - player, N/A - N/A)     0.0000 (tackle - player, N/A - N/A)     0.0000 (tackle - player, N/A - N/A)     0.0000 (tackle - player, N/A - other)
# Theme (tackle - each)     0.0000 (tackle - each, N/A - N/A)     0.0000 (tackle - each, N/A - N/A)     0.4738 (tackle - each, N/A - N/A)     0.2323 (tackle - each, N/A - other)
# equality (each - other)     0.0000 (each - other, N/A - N/A)     0.0000 (each - other, N/A - N/A)     0.2329 (each - other, N/A - N/A)     0.6674 (each - other, N/A - other)
# Matriz exportada para relation_matrix.csv
# A soccer player is being tackled by his opponent
# Some people playing rugby are tackling each other
# A soccer player is being tackled by his opponent
#
# Some people playing rugby are tackling each other
#
# of    equality
# of    Theme
# of    Theme
# of    Actor
# of    Actor
# of    equality
# of    equality
# Theme    equality
# Theme    Theme
# Theme    Theme
# Theme    Actor
# Theme    Actor
# Theme    equality
# Theme    equality
# of    equality
# of    Theme
# of    Theme
# of    Actor
# of    Actor
# of    equality
# of    equality
# Actor    equality
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    Actor
# Actor    equality
# Actor    equality
# Matriz de Relações:
#      equality (N/A - N/A)     Theme (N/A - N/A)     Theme (N/A - N/A)     Actor (N/A - N/A)     Actor (N/A - N/A)     equality (N/A - N/A)     equality (N/A - N/A)
# of (player - soccer)     0.2613 (player - soccer, N/A - N/A)     0.1148 (player - soccer, N/A - N/A)     0.1904 (player - soccer, N/A - N/A)     0.1384 (player - soccer, N/A - N/A)     0.1229 (player - soccer, N/A - N/A)     0.2695 (player - soccer, N/A - N/A)     0.2198 (player - soccer, N/A - N/A)
# Theme (tackle - player)     0.1229 (tackle - player, N/A - N/A)     0.1545 (tackle - player, N/A - N/A)     0.2169 (tackle - player, N/A - N/A)     0.1229 (tackle - player, N/A - N/A)     0.0000 (tackle - player, N/A - N/A)     0.1452 (tackle - player, N/A - N/A)     0.1200 (tackle - player, N/A - N/A)
# of (opponent - male)     0.0829 (opponent - male, N/A - N/A)     0.0000 (opponent - male, N/A - N/A)     0.0000 (opponent - male, N/A - N/A)     0.0000 (opponent - male, N/A - N/A)     0.0829 (opponent - male, N/A - N/A)     0.0829 (opponent - male, N/A - N/A)     0.1304 (opponent - male, N/A - N/A)
# Actor (tackle - opponent)     0.0829 (tackle - opponent, N/A - N/A)     0.1304 (tackle - opponent, N/A - N/A)     0.1514 (tackle - opponent, N/A - N/A)     0.1077 (tackle - opponent, N/A - N/A)     0.0000 (tackle - opponent, N/A - N/A)     0.1159 (tackle - opponent, N/A - N/A)     0.1528 (tackle - opponent, N/A - N/A)
# Matriz exportada para relation_matrix.csv
# There is no soccer player who is being tackled by an opponent
# Rugby players are tackling each other
# There is no soccer player who is being tackled by an opponent
#
# Rugby players are tackling each other
#
# of    equality
# of    Actor
# of    Theme
# of    equality
# equality    equality
# equality    Actor
# equality    Theme
# equality    equality
# is    equality
# is    Actor
# is    Theme
# is    equality
# Theme    equality
# Theme    Actor
# Theme    Theme
# Theme    equality
# Actor    equality
# Actor    Actor
# Actor    Theme
# Actor    equality
# Matriz de Relações:
#      equality (There - N/A)     Actor (N/A - There)     Theme (N/A - soccer)     equality (soccer - N/A)
# of (player - soccer)     0.0000 (player - soccer, There - N/A)     0.0000 (player - soccer, N/A - There)     0.1161 (player - soccer, N/A - soccer)     0.2374 (player - soccer, soccer - N/A)
# equality (player - player)     0.0000 (player - player, There - N/A)     0.0000 (player - player, N/A - There)     0.1228 (player - player, N/A - soccer)     0.2295 (player - player, soccer - N/A)
# is (There - player)     0.0000 (There - player, There - N/A)     0.0000 (There - player, N/A - There)     0.1180 (There - player, N/A - soccer)     0.2273 (There - player, soccer - N/A)
# Theme (player - tackle)     0.0000 (player - tackle, There - N/A)     0.0000 (player - tackle, N/A - There)     0.0000 (player - tackle, N/A - soccer)     0.1228 (player - tackle, soccer - N/A)
# Actor (tackle - opponent)     0.0000 (tackle - opponent, There - N/A)     0.0000 (tackle - opponent, N/A - There)     0.1330 (tackle - opponent, N/A - soccer)     0.1617 (tackle - opponent, soccer - N/A)
# Matriz exportada para relation_matrix.csv
# A soccer player is being tackled by his opponent
# Rugby players are tackling each other
# A soccer player is being tackled by his opponent
#
# Rugby players are tackling each other
#
# of    equality
# of    Actor
# of    Theme
# of    equality
# Theme    equality
# Theme    Actor
# Theme    Theme
# Theme    equality
# of    equality
# of    Actor
# of    Theme
# of    equality
# Actor    equality
# Actor    Actor
# Actor    Theme
# Actor    equality
# Matriz de Relações:
#      equality (player - soccer)     Actor (N/A - player)     Theme (N/A - N/A)     equality (N/A - N/A)
# of (player - soccer)     0.0000 (player - soccer, player - soccer)     0.0000 (player - soccer, N/A - player)     0.1315 (player - soccer, N/A - N/A)     0.2610 (player - soccer, N/A - N/A)
# Theme (tackle - player)     0.0000 (tackle - player, player - soccer)     0.0000 (tackle - player, N/A - player)     0.1852 (tackle - player, N/A - N/A)     0.1396 (tackle - player, N/A - N/A)
# of (opponent - male)     0.0000 (opponent - male, player - soccer)     0.0000 (opponent - male, N/A - player)     0.0000 (opponent - male, N/A - N/A)     0.1494 (opponent - male, N/A - N/A)
# Actor (tackle - opponent)     0.0000 (tackle - opponent, player - soccer)     0.0000 (tackle - opponent, N/A - player)     0.1494 (tackle - opponent, N/A - N/A)     0.1799 (tackle - opponent, N/A - N/A)
# Matriz exportada para relation_matrix.csv
# A dog which is white is standing on fallen leaves
# A white dog is standing on fallen leaves
# A dog which is white is standing on fallen leaves
#
# A white dog is standing on fallen leaves
#
# equality    Theme
# equality    Actor
# equality    Theme
# equality    on
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    on
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    on
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    on
# on    Theme
# on    Actor
# on    Theme
# on    on
# Matriz de Relações:
#      Theme (dog - white)     Actor (stand - dog)     Theme (which - fallen)     on (stand - which)
# equality (dog - which)     0.5700 (dog - which, dog - white)     0.2494 (dog - which, stand - dog)     0.1532 (dog - which, which - fallen)     0.0000 (dog - which, stand - which)
# Actor (stand - dog)     0.3021 (stand - dog, dog - white)     0.4549 (stand - dog, stand - dog)     0.1833 (stand - dog, which - fallen)     0.0000 (stand - dog, stand - which)
# Theme (leaf - fallen)     0.2418 (leaf - fallen, dog - white)     0.1658 (leaf - fallen, stand - dog)     0.4887 (leaf - fallen, which - fallen)     0.0000 (leaf - fallen, stand - which)
# Theme (which - white)     0.7102 (which - white, dog - white)     0.2519 (which - white, stand - dog)     0.2453 (which - white, which - fallen)     0.0000 (which - white, stand - which)
# on (stand - leaf)     0.0000 (stand - leaf, dog - white)     0.0000 (stand - leaf, stand - dog)     0.0000 (stand - leaf, which - fallen)     0.0000 (stand - leaf, stand - which)
# Matriz exportada para relation_matrix.csv
# A white dog is standing on the leaves on the ground
# One white dog is standing on the leaves on the ground
# A white dog is standing on the leaves on the ground
#
# One white dog is standing on the leaves on the ground
#
# Theme    Theme
# Theme    Actor
# Theme    equality
# Theme    on
# Theme    on
# Actor    Theme
# Actor    Actor
# Actor    equality
# Actor    on
# Actor    on
# on    Theme
# on    Actor
# on    equality
# on    on
# on    on
# on    Theme
# on    Actor
# on    equality
# on    on
# on    on
# Matriz de Relações:
#      Theme (dog - white)     Actor (stand - dog)     equality (dog - N/A)     on (stand - leaf)     on (stand - ground)
# Theme (dog - white)     0.4744 (dog - white, dog - white)     0.0000 (dog - white, stand - dog)     0.2904 (dog - white, dog - N/A)     0.0000 (dog - white, stand - leaf)     0.1937 (dog - white, stand - ground)
# Actor (stand - dog)     0.2849 (stand - dog, dog - white)     0.0000 (stand - dog, stand - dog)     0.3746 (stand - dog, dog - N/A)     0.0000 (stand - dog, stand - leaf)     0.2264 (stand - dog, stand - ground)
# on (stand - leaf)     0.0000 (stand - leaf, dog - white)     0.0000 (stand - leaf, stand - dog)     0.0000 (stand - leaf, dog - N/A)     0.0000 (stand - leaf, stand - leaf)     0.0000 (stand - leaf, stand - ground)
# on (stand - ground)     0.1919 (stand - ground, dog - white)     0.0000 (stand - ground, stand - dog)     0.2316 (stand - ground, dog - N/A)     0.0000 (stand - ground, stand - leaf)     0.4948 (stand - ground, stand - ground)
# Matriz exportada para relation_matrix.csv
# There is no white dog standing on the leaves on the ground
# A white dog is standing on the leaves on the ground
# There is no white dog standing on the leaves on the ground
#
# A white dog is standing on the leaves on the ground
#
# Theme    Theme
# Theme    Actor
# Theme    on
# Theme    on
# is    Theme
# is    Actor
# is    on
# is    on
# of    Theme
# of    Actor
# of    on
# of    on
# on    Theme
# on    Actor
# on    on
# on    on
# on    Theme
# on    Actor
# on    on
# on    on
# Matriz de Relações:
#      Theme (N/A - white)     Actor (N/A - N/A)     on (N/A - standing)     on (N/A - dog)
# Theme (standing - white)     0.7386 (standing - white, N/A - white)     0.2743 (standing - white, N/A - N/A)     0.0000 (standing - white, N/A - standing)     0.1970 (standing - white, N/A - dog)
# is (There - standing)     0.3694 (There - standing, N/A - white)     0.2155 (There - standing, N/A - N/A)     0.0000 (There - standing, N/A - standing)     0.1938 (There - standing, N/A - dog)
# of (standing - dog)     0.5035 (standing - dog, N/A - white)     0.3574 (standing - dog, N/A - N/A)     0.0000 (standing - dog, N/A - standing)     0.2405 (standing - dog, N/A - dog)
# on (standing - leaf)     0.2242 (standing - leaf, N/A - white)     0.0000 (standing - leaf, N/A - N/A)     0.0000 (standing - leaf, N/A - standing)     0.0000 (standing - leaf, N/A - dog)
# on (leaf - ground)     0.2032 (leaf - ground, N/A - white)     0.2304 (leaf - ground, N/A - N/A)     0.0000 (leaf - ground, N/A - standing)     0.4819 (leaf - ground, N/A - dog)
# Matriz exportada para relation_matrix.csv
# A white dog is lying on fallen leaves
# A white dog is standing on the leaves on the ground
# A white dog is lying on fallen leaves
#
# A white dog is standing on the leaves on the ground
#
# Theme    Theme
# Theme    Actor
# Theme    on
# Theme    on
# Actor    Theme
# Actor    Actor
# Actor    on
# Actor    on
# Theme    Theme
# Theme    Actor
# Theme    on
# Theme    on
# on    Theme
# on    Actor
# on    on
# on    on
# Matriz de Relações:
#      Theme (dog - white)     Actor (lie - dog)     on (lie - leaf)     on (lie - N/A)
# Theme (dog - white)     0.9424 (dog - white, dog - white)     0.2822 (dog - white, lie - dog)     0.0000 (dog - white, lie - leaf)     0.1931 (dog - white, lie - N/A)
# Actor (lie - dog)     0.2789 (lie - dog, dog - white)     0.4682 (lie - dog, lie - dog)     0.0000 (lie - dog, lie - leaf)     0.2239 (lie - dog, lie - N/A)
# Theme (leaf - fallen)     0.2244 (leaf - fallen, dog - white)     0.1506 (leaf - fallen, lie - dog)     0.0000 (leaf - fallen, lie - leaf)     0.2105 (leaf - fallen, lie - N/A)
# on (lie - leaf)     0.0000 (lie - leaf, dog - white)     0.0000 (lie - leaf, lie - dog)     0.0000 (lie - leaf, lie - leaf)     0.0000 (lie - leaf, lie - N/A)
# Matriz exportada para relation_matrix.csv
# Two girls are not playing inside the jumper house
# Two girls are playing inside a jumper house
# Two girls are not playing inside the jumper house
#
# Two girls are playing inside a jumper house
#
# Actor    Actor
# Actor    of
# Actor    equality
# Actor    inside
# of    Actor
# of    of
# of    equality
# of    inside
# equality    Actor
# equality    of
# equality    equality
# equality    inside
# inside    Actor
# inside    of
# inside    equality
# inside    inside
# Matriz de Relações:
#      Actor (N/A - N/A)     of (N/A - N/A)     equality (N/A - girl)     inside (N/A - N/A)
# Actor (play - 2)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - girl)     0.0000 (play - 2, N/A - N/A)
# of (house - jumper)     0.0000 (house - jumper, N/A - N/A)     0.9362 (house - jumper, N/A - N/A)     0.0000 (house - jumper, N/A - girl)     0.2070 (house - jumper, N/A - N/A)
# equality (2 - girl)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - girl)     0.0000 (2 - girl, N/A - N/A)
# inside (play - house)     0.0000 (play - house, N/A - N/A)     0.2026 (play - house, N/A - N/A)     0.0000 (play - house, N/A - girl)     0.4668 (play - house, N/A - N/A)
# Matriz exportada para relation_matrix.csv
# A child in light colored clothing is standing with his arms extended outward
# A child in light colored clothing is lying with his arms crossed
# A child in light colored clothing is standing with his arms extended outward
#
# A child in light colored clothing is lying with his arms crossed
#
# Theme    Theme
# Theme    of
# Theme    equality
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    in
# Theme    with
# of    Theme
# of    of
# of    equality
# of    Theme
# of    Actor
# of    Theme
# of    in
# of    with
# equality    Theme
# equality    of
# equality    equality
# equality    Theme
# equality    Actor
# equality    Theme
# equality    in
# equality    with
# Time    Theme
# Time    of
# Time    equality
# Time    Theme
# Time    Actor
# Time    Theme
# Time    in
# Time    with
# Theme    Theme
# Theme    of
# Theme    equality
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    in
# Theme    with
# Actor    Theme
# Actor    of
# Actor    equality
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    in
# Actor    with
# Theme    Theme
# Theme    of
# Theme    equality
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    in
# Theme    with
# in    Theme
# in    of
# in    equality
# in    Theme
# in    Actor
# in    Theme
# in    in
# in    with
# with    Theme
# with    of
# with    equality
# with    Theme
# with    Actor
# with    Theme
# with    in
# with    with
# Matriz de Relações:
#      Theme (clothing - light)     of (arm - male)     equality (arm - arm)     Theme (clothing - color)     Actor (stand - child)     Theme (arm - extend)     in (child - clothing)     with (stand - arm)
# Theme (clothing - light)     0.9662 (clothing - light, clothing - light)     0.0000 (clothing - light, arm - male)     0.0000 (clothing - light, arm - arm)     0.4826 (clothing - light, clothing - color)     0.2106 (clothing - light, stand - child)     0.0000 (clothing - light, arm - extend)     0.4466 (clothing - light, child - clothing)     0.0000 (clothing - light, stand - arm)
# of (arm - male)     0.0000 (arm - male, clothing - light)     0.0000 (arm - male, arm - male)     0.0000 (arm - male, arm - arm)     0.0000 (arm - male, clothing - color)     0.0000 (arm - male, stand - child)     0.0000 (arm - male, arm - extend)     0.0000 (arm - male, child - clothing)     0.0000 (arm - male, stand - arm)
# equality (arm - arm)     0.0000 (arm - arm, clothing - light)     0.0000 (arm - arm, arm - male)     0.0000 (arm - arm, arm - arm)     0.0000 (arm - arm, clothing - color)     0.0000 (arm - arm, stand - child)     0.0000 (arm - arm, arm - extend)     0.0000 (arm - arm, child - clothing)     0.0000 (arm - arm, stand - arm)
# Time (extend - outward)     0.1579 (extend - outward, clothing - light)     0.0000 (extend - outward, arm - male)     0.0000 (extend - outward, arm - arm)     0.0000 (extend - outward, clothing - color)     0.2173 (extend - outward, stand - child)     0.0000 (extend - outward, arm - extend)     0.1973 (extend - outward, child - clothing)     0.0000 (extend - outward, stand - arm)
# Theme (clothing - color)     0.4826 (clothing - color, clothing - light)     0.0000 (clothing - color, arm - male)     0.0000 (clothing - color, arm - arm)     0.4826 (clothing - color, clothing - color)     0.0000 (clothing - color, stand - child)     0.0000 (clothing - color, arm - extend)     0.2261 (clothing - color, child - clothing)     0.0000 (clothing - color, stand - arm)
# Actor (stand - child)     0.2085 (stand - child, clothing - light)     0.0000 (stand - child, arm - male)     0.0000 (stand - child, arm - arm)     0.0000 (stand - child, clothing - color)     0.4736 (stand - child, stand - child)     0.0000 (stand - child, arm - extend)     0.2087 (stand - child, child - clothing)     0.0000 (stand - child, stand - arm)
# Theme (arm - extend)     0.0000 (arm - extend, clothing - light)     0.0000 (arm - extend, arm - male)     0.0000 (arm - extend, arm - arm)     0.0000 (arm - extend, clothing - color)     0.0000 (arm - extend, stand - child)     0.0000 (arm - extend, arm - extend)     0.0000 (arm - extend, child - clothing)     0.0000 (arm - extend, stand - arm)
# in (child - clothing)     0.4435 (child - clothing, clothing - light)     0.0000 (child - clothing, arm - male)     0.0000 (child - clothing, arm - arm)     0.2087 (child - clothing, clothing - color)     0.2261 (child - clothing, stand - child)     0.0000 (child - clothing, arm - extend)     0.9562 (child - clothing, child - clothing)     0.0000 (child - clothing, stand - arm)
# with (stand - arm)     0.0000 (stand - arm, clothing - light)     0.0000 (stand - arm, arm - male)     0.0000 (stand - arm, arm - arm)     0.0000 (stand - arm, clothing - color)     0.0000 (stand - arm, stand - child)     0.0000 (stand - arm, arm - extend)     0.0000 (stand - arm, child - clothing)     0.0000 (stand - arm, stand - arm)
# Matriz exportada para relation_matrix.csv
# Two girls are playing inside a jumper house
# A child in clothing which is light colored is standing with his arms extended outward
# Two girls are playing inside a jumper house
#
# A child in clothing which is light colored is standing with his arms extended outward
#
# Actor    Actor
# Actor    of
# Actor    equality
# Actor    Time
# Actor    equality
# Actor    for
# Actor    Theme
# Actor    Theme
# Actor    Theme
# Actor    in
# Actor    with
# of    Actor
# of    of
# of    equality
# of    Time
# of    equality
# of    for
# of    Theme
# of    Theme
# of    Theme
# of    in
# of    with
# equality    Actor
# equality    of
# equality    equality
# equality    Time
# equality    equality
# equality    for
# equality    Theme
# equality    Theme
# equality    Theme
# equality    in
# equality    with
# inside    Actor
# inside    of
# inside    equality
# inside    Time
# inside    equality
# inside    for
# inside    Theme
# inside    Theme
# inside    Theme
# inside    in
# inside    with
# Matriz de Relações:
#      Actor (N/A - N/A)     of (N/A - N/A)     equality (N/A - N/A)     Time (N/A - N/A)     equality (N/A - N/A)     for (N/A - N/A)     Theme (N/A - N/A)     Theme (N/A - N/A)     Theme (N/A - N/A)     in (N/A - N/A)     with (N/A - N/A)
# Actor (play - 2)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)
# of (house - jumper)     0.1458 (house - jumper, N/A - N/A)     0.0000 (house - jumper, N/A - N/A)     0.0000 (house - jumper, N/A - N/A)     0.1647 (house - jumper, N/A - N/A)     0.2779 (house - jumper, N/A - N/A)     0.1195 (house - jumper, N/A - N/A)     0.0000 (house - jumper, N/A - N/A)     0.2662 (house - jumper, N/A - N/A)     0.1493 (house - jumper, N/A - N/A)     0.2837 (house - jumper, N/A - N/A)     0.0000 (house - jumper, N/A - N/A)
# equality (2 - girl)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)
# inside (play - house)     0.1500 (play - house, N/A - N/A)     0.0000 (play - house, N/A - N/A)     0.0000 (play - house, N/A - N/A)     0.1483 (play - house, N/A - N/A)     0.1493 (play - house, N/A - N/A)     0.0000 (play - house, N/A - N/A)     0.0000 (play - house, N/A - N/A)     0.1195 (play - house, N/A - N/A)     0.0000 (play - house, N/A - N/A)     0.1335 (play - house, N/A - N/A)     0.0000 (play - house, N/A - N/A)
# Matriz exportada para relation_matrix.csv
# A child in light colored clothing is lying with his arms crossed
# Two girls are playing inside a jumper house
# A child in light colored clothing is lying with his arms crossed
#
# Two girls are playing inside a jumper house
#
# Theme    Actor
# Theme    of
# Theme    equality
# Theme    inside
# of    Actor
# of    of
# of    equality
# of    inside
# equality    Actor
# equality    of
# equality    equality
# equality    inside
# Theme    Actor
# Theme    of
# Theme    equality
# Theme    inside
# Actor    Actor
# Actor    of
# Actor    equality
# Actor    inside
# Theme    Actor
# Theme    of
# Theme    equality
# Theme    inside
# in    Actor
# in    of
# in    equality
# in    inside
# with    Actor
# with    of
# with    equality
# with    inside
# Matriz de Relações:
#      Actor (N/A - N/A)     of (N/A - N/A)     equality (N/A - N/A)     inside (N/A - N/A)
# Theme (clothing - light)     0.0000 (clothing - light, N/A - N/A)     0.2939 (clothing - light, N/A - N/A)     0.0000 (clothing - light, N/A - N/A)     0.1435 (clothing - light, N/A - N/A)
# of (arm - male)     0.0000 (arm - male, N/A - N/A)     0.0000 (arm - male, N/A - N/A)     0.0000 (arm - male, N/A - N/A)     0.0000 (arm - male, N/A - N/A)
# equality (arm - arm)     0.0000 (arm - arm, N/A - N/A)     0.0000 (arm - arm, N/A - N/A)     0.0000 (arm - arm, N/A - N/A)     0.0000 (arm - arm, N/A - N/A)
# Theme (clothing - color)     0.0000 (clothing - color, N/A - N/A)     0.1531 (clothing - color, N/A - N/A)     0.0000 (clothing - color, N/A - N/A)     0.0000 (clothing - color, N/A - N/A)
# Actor (lie - child)     0.0000 (lie - child, N/A - N/A)     0.1590 (lie - child, N/A - N/A)     0.0000 (lie - child, N/A - N/A)     0.1846 (lie - child, N/A - N/A)
# Theme (arm - cross)     0.0000 (arm - cross, N/A - N/A)     0.0000 (arm - cross, N/A - N/A)     0.0000 (arm - cross, N/A - N/A)     0.0000 (arm - cross, N/A - N/A)
# in (child - clothing)     0.0000 (child - clothing, N/A - N/A)     0.3187 (child - clothing, N/A - N/A)     0.0000 (child - clothing, N/A - N/A)     0.1491 (child - clothing, N/A - N/A)
# with (lie - arm)     0.0000 (lie - arm, N/A - N/A)     0.0000 (lie - arm, N/A - N/A)     0.0000 (lie - arm, N/A - N/A)     0.0000 (lie - arm, N/A - N/A)
# Matriz exportada para relation_matrix.csv
# A child in light colored clothing is standing with his arms extended outward
# Two girls are happily playing inside a jumper house
# A child in light colored clothing is standing with his arms extended outward
#
# Two girls are happily playing inside a jumper house
#
# Theme    Actor
# Theme    of
# Theme    Manner
# Theme    equality
# Theme    inside
# of    Actor
# of    of
# of    Manner
# of    equality
# of    inside
# equality    Actor
# equality    of
# equality    Manner
# equality    equality
# equality    inside
# Time    Actor
# Time    of
# Time    Manner
# Time    equality
# Time    inside
# Theme    Actor
# Theme    of
# Theme    Manner
# Theme    equality
# Theme    inside
# Actor    Actor
# Actor    of
# Actor    Manner
# Actor    equality
# Actor    inside
# Theme    Actor
# Theme    of
# Theme    Manner
# Theme    equality
# Theme    inside
# in    Actor
# in    of
# in    Manner
# in    equality
# in    inside
# with    Actor
# with    of
# with    Manner
# with    equality
# with    inside
# Matriz de Relações:
#      Actor (N/A - N/A)     of (N/A - N/A)     Manner (N/A - N/A)     equality (N/A - N/A)     inside (N/A - N/A)
# Theme (clothing - light)     0.0000 (clothing - light, N/A - N/A)     0.2641 (clothing - light, N/A - N/A)     0.0000 (clothing - light, N/A - N/A)     0.0000 (clothing - light, N/A - N/A)     0.1225 (clothing - light, N/A - N/A)
# of (arm - male)     0.0000 (arm - male, N/A - N/A)     0.0000 (arm - male, N/A - N/A)     0.0000 (arm - male, N/A - N/A)     0.0000 (arm - male, N/A - N/A)     0.0000 (arm - male, N/A - N/A)
# equality (arm - arm)     0.0000 (arm - arm, N/A - N/A)     0.0000 (arm - arm, N/A - N/A)     0.0000 (arm - arm, N/A - N/A)     0.0000 (arm - arm, N/A - N/A)     0.0000 (arm - arm, N/A - N/A)
# Time (extend - outward)     0.0000 (extend - outward, N/A - N/A)     0.1589 (extend - outward, N/A - N/A)     0.0000 (extend - outward, N/A - N/A)     0.0000 (extend - outward, N/A - N/A)     0.1424 (extend - outward, N/A - N/A)
# Theme (clothing - color)     0.0000 (clothing - color, N/A - N/A)     0.1377 (clothing - color, N/A - N/A)     0.0000 (clothing - color, N/A - N/A)     0.0000 (clothing - color, N/A - N/A)     0.0000 (clothing - color, N/A - N/A)
# Actor (stand - child)     0.0000 (stand - child, N/A - N/A)     0.1382 (stand - child, N/A - N/A)     0.0000 (stand - child, N/A - N/A)     0.0000 (stand - child, N/A - N/A)     0.1539 (stand - child, N/A - N/A)
# Theme (arm - extend)     0.0000 (arm - extend, N/A - N/A)     0.0000 (arm - extend, N/A - N/A)     0.0000 (arm - extend, N/A - N/A)     0.0000 (arm - extend, N/A - N/A)     0.0000 (arm - extend, N/A - N/A)
# in (child - clothing)     0.0000 (child - clothing, N/A - N/A)     0.2797 (child - clothing, N/A - N/A)     0.0000 (child - clothing, N/A - N/A)     0.0000 (child - clothing, N/A - N/A)     0.1341 (child - clothing, N/A - N/A)
# with (stand - arm)     0.0000 (stand - arm, N/A - N/A)     0.0000 (stand - arm, N/A - N/A)     0.0000 (stand - arm, N/A - N/A)     0.0000 (stand - arm, N/A - N/A)     0.0000 (stand - arm, N/A - N/A)
# Matriz exportada para relation_matrix.csv
# Two girls are playing inside a jumper house
# A child in light colored clothing is standing with his arms extended outward
# Two girls are playing inside a jumper house
#
# A child in light colored clothing is standing with his arms extended outward
#
# Actor    Theme
# Actor    of
# Actor    equality
# Actor    Time
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    in
# Actor    with
# of    Theme
# of    of
# of    equality
# of    Time
# of    Theme
# of    Actor
# of    Theme
# of    in
# of    with
# equality    Theme
# equality    of
# equality    equality
# equality    Time
# equality    Theme
# equality    Actor
# equality    Theme
# equality    in
# equality    with
# inside    Theme
# inside    of
# inside    equality
# inside    Time
# inside    Theme
# inside    Actor
# inside    Theme
# inside    in
# inside    with
# Matriz de Relações:
#      Theme (N/A - N/A)     of (N/A - N/A)     equality (N/A - N/A)     Time (N/A - N/A)     Theme (N/A - N/A)     Actor (N/A - N/A)     Theme (N/A - N/A)     in (N/A - N/A)     with (N/A - N/A)
# Actor (play - 2)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)     0.0000 (play - 2, N/A - N/A)
# of (house - jumper)     0.2760 (house - jumper, N/A - N/A)     0.0000 (house - jumper, N/A - N/A)     0.0000 (house - jumper, N/A - N/A)     0.1616 (house - jumper, N/A - N/A)     0.1432 (house - jumper, N/A - N/A)     0.1445 (house - jumper, N/A - N/A)     0.0000 (house - jumper, N/A - N/A)     0.2892 (house - jumper, N/A - N/A)     0.0000 (house - jumper, N/A - N/A)
# equality (2 - girl)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)     0.0000 (2 - girl, N/A - N/A)
# inside (play - house)     0.1308 (play - house, N/A - N/A)     0.0000 (play - house, N/A - N/A)     0.0000 (play - house, N/A - N/A)     0.1441 (play - house, N/A - N/A)     0.0000 (play - house, N/A - N/A)     0.1568 (play - house, N/A - N/A)     0.0000 (play - house, N/A - N/A)     0.1395 (play - house, N/A - N/A)     0.0000 (play - house, N/A - N/A)
# Matriz exportada para relation_matrix.csv
# The boy and girl are playing on the outdoor gym
# A boy and a girl are playing on the outdoor gym
# The boy and girl are playing on the outdoor gym
#
# A boy and a girl are playing on the outdoor gym
#
# of    of
# of    on
# on    of
# on    on
# Matriz de Relações:
#      superset_of (N/A - boy)     superset_of (N/A - girl)     Actor (play - N/A)     of (gym - outdoor)     on (play - gym)
# superset_of (N/A - boy)     0.0000 (N/A - boy, N/A - boy)     0.0000 (N/A - boy, N/A - girl)     0.0000 (N/A - boy, play - N/A)     0.0000 (N/A - boy, gym - outdoor)     0.0000 (N/A - boy, play - gym)
# superset_of (N/A - girl)     0.0000 (N/A - girl, N/A - boy)     0.0000 (N/A - girl, N/A - girl)     0.0000 (N/A - girl, play - N/A)     0.0000 (N/A - girl, gym - outdoor)     0.0000 (N/A - girl, play - gym)
# Actor (play - N/A)     0.0000 (play - N/A, N/A - boy)     0.0000 (play - N/A, N/A - girl)     0.0000 (play - N/A, play - N/A)     0.0000 (play - N/A, gym - outdoor)     0.0000 (play - N/A, play - gym)
# of (gym - outdoor)     0.0000 (gym - outdoor, N/A - boy)     0.0000 (gym - outdoor, N/A - girl)     0.0000 (gym - outdoor, play - N/A)     0.9767 (gym - outdoor, gym - outdoor)     0.2742 (gym - outdoor, play - gym)
# on (play - gym)     0.0000 (play - gym, N/A - boy)     0.0000 (play - gym, N/A - girl)     0.0000 (play - gym, play - N/A)     0.2730 (play - gym, gym - outdoor)     0.4880 (play - gym, play - gym)
# Matriz exportada para relation_matrix.csv
# Some children are playing on a playground
# Some kids are playing on a playground
# Some children are playing on a playground
#
# Some kids are playing on a playground
#
# Actor    Actor
# Actor    equality
# Actor    on
# equality    Actor
# equality    equality
# equality    on
# on    Actor
# on    equality
# on    on
# Matriz de Relações:
#      Actor (play - Some)     equality (Some - child)     on (play - playground)
# Actor (play - Some)     0.4607 (play - Some, play - Some)     0.0000 (play - Some, Some - child)     0.2078 (play - Some, play - playground)
# equality (Some - child)     0.0000 (Some - child, play - Some)     0.3225 (Some - child, Some - child)     0.0000 (Some - child, play - playground)
# on (play - playground)     0.1914 (play - playground, play - Some)     0.0000 (play - playground, Some - child)     0.4830 (play - playground, play - playground)
# Matriz exportada para relation_matrix.csv
# The motocross rider is wearing blue and black pants
# Blue and black pants are being worn by the motocross rider
# The motocross rider is wearing blue and black pants
#
# Blue and black pants are being worn by the motocross rider
#
# of    Theme
# of    of
# of    Actor
# Theme    Theme
# Theme    of
# Theme    Actor
# Theme    Theme
# Theme    of
# Theme    Actor
# Theme    Theme
# Theme    of
# Theme    Actor
# Actor    Theme
# Actor    of
# Actor    Actor
# Matriz de Relações:
#      superset_of (rider - motocross)     Theme (pants - blue)     superset_of (rider - pants)     Theme (wear - rider)     of (N/A - N/A)     Actor (wear - N/A)
# of (rider - motocross)     0.0000 (rider - motocross, rider - motocross)     0.4345 (rider - motocross, pants - blue)     0.0000 (rider - motocross, rider - pants)     0.0000 (rider - motocross, wear - rider)     0.8890 (rider - motocross, N/A - N/A)     0.2566 (rider - motocross, wear - N/A)
# Theme (wear - pants)     0.0000 (wear - pants, rider - motocross)     0.3277 (wear - pants, pants - blue)     0.0000 (wear - pants, rider - pants)     0.0000 (wear - pants, wear - rider)     0.1798 (wear - pants, N/A - N/A)     0.1734 (wear - pants, wear - N/A)
# Theme (pants - blue)     0.0000 (pants - blue, rider - motocross)     0.8343 (pants - blue, pants - blue)     0.0000 (pants - blue, rider - pants)     0.0000 (pants - blue, wear - rider)     0.3645 (pants - blue, N/A - N/A)     0.1733 (pants - blue, wear - N/A)
# Theme (pants - black)     0.0000 (pants - black, rider - motocross)     0.8773 (pants - black, pants - blue)     0.0000 (pants - black, rider - pants)     0.0000 (pants - black, wear - rider)     0.3610 (pants - black, N/A - N/A)     0.1756 (pants - black, wear - N/A)
# Actor (wear - rider)     0.0000 (wear - rider, rider - motocross)     0.1971 (wear - rider, pants - blue)     0.0000 (wear - rider, rider - pants)     0.0000 (wear - rider, wear - rider)     0.2724 (wear - rider, N/A - N/A)     0.4277 (wear - rider, wear - N/A)
# Matriz exportada para relation_matrix.csv
# The motocross rider is wearing blue and black pants
# A biker with a blue jacket black pants and a white helmet is driving recklessly on dirt and people watch
# The motocross rider is wearing blue and black pants
#
# A biker with a blue jacket black pants and a white helmet is driving recklessly on dirt people watch
#
# of    Theme
# of    Actor
# of    Manner
# of    equality
# of    Actor
# of    of
# of    Theme
# of    Theme
# of    Theme
# of    on
# Theme    Theme
# Theme    Actor
# Theme    Manner
# Theme    equality
# Theme    Actor
# Theme    of
# Theme    Theme
# Theme    Theme
# Theme    Theme
# Theme    on
# Theme    Theme
# Theme    Actor
# Theme    Manner
# Theme    equality
# Theme    Actor
# Theme    of
# Theme    Theme
# Theme    Theme
# Theme    Theme
# Theme    on
# Theme    Theme
# Theme    Actor
# Theme    Manner
# Theme    equality
# Theme    Actor
# Theme    of
# Theme    Theme
# Theme    Theme
# Theme    Theme
# Theme    on
# Actor    Theme
# Actor    Actor
# Actor    Manner
# Actor    equality
# Actor    Actor
# Actor    of
# Actor    Theme
# Actor    Theme
# Actor    Theme
# Actor    on
# Matriz de Relações:
#      Theme (N/A - N/A)     superset_of (N/A - N/A)     Actor (N/A - N/A)     Manner (N/A - N/A)     equality (N/A - N/A)     Actor (N/A - N/A)     of (N/A - N/A)     Theme (N/A - N/A)     superset_of (N/A - N/A)     Theme (N/A - N/A)     Theme (N/A - N/A)     with (N/A - N/A)     on (N/A - N/A)
# of (rider - motocross)     0.3519 (rider - motocross, N/A - N/A)     0.0000 (rider - motocross, N/A - N/A)     0.2125 (rider - motocross, N/A - N/A)     0.0000 (rider - motocross, N/A - N/A)     0.2830 (rider - motocross, N/A - N/A)     0.2272 (rider - motocross, N/A - N/A)     0.4714 (rider - motocross, N/A - N/A)     0.3328 (rider - motocross, N/A - N/A)     0.0000 (rider - motocross, N/A - N/A)     0.3585 (rider - motocross, N/A - N/A)     0.2521 (rider - motocross, N/A - N/A)     0.0000 (rider - motocross, N/A - N/A)     0.1448 (rider - motocross, N/A - N/A)
# Theme (wear - pants)     0.2842 (wear - pants, N/A - N/A)     0.0000 (wear - pants, N/A - N/A)     0.1711 (wear - pants, N/A - N/A)     0.0000 (wear - pants, N/A - N/A)     0.1639 (wear - pants, N/A - N/A)     0.1219 (wear - pants, N/A - N/A)     0.2740 (wear - pants, N/A - N/A)     0.2955 (wear - pants, N/A - N/A)     0.0000 (wear - pants, N/A - N/A)     0.2770 (wear - pants, N/A - N/A)     0.1776 (wear - pants, N/A - N/A)     0.0000 (wear - pants, N/A - N/A)     0.1639 (wear - pants, N/A - N/A)
# Theme (pants - blue)     0.7957 (pants - blue, N/A - N/A)     0.0000 (pants - blue, N/A - N/A)     0.1766 (pants - blue, N/A - N/A)     0.0000 (pants - blue, N/A - N/A)     0.3183 (pants - blue, N/A - N/A)     0.2662 (pants - blue, N/A - N/A)     0.5840 (pants - blue, N/A - N/A)     0.7860 (pants - blue, N/A - N/A)     0.0000 (pants - blue, N/A - N/A)     0.7016 (pants - blue, N/A - N/A)     0.3977 (pants - blue, N/A - N/A)     0.0000 (pants - blue, N/A - N/A)     0.1544 (pants - blue, N/A - N/A)
# Theme (pants - black)     0.7780 (pants - black, N/A - N/A)     0.0000 (pants - black, N/A - N/A)     0.1715 (pants - black, N/A - N/A)     0.0000 (pants - black, N/A - N/A)     0.3194 (pants - black, N/A - N/A)     0.2739 (pants - black, N/A - N/A)     0.5854 (pants - black, N/A - N/A)     0.8050 (pants - black, N/A - N/A)     0.0000 (pants - black, N/A - N/A)     0.7083 (pants - black, N/A - N/A)     0.4027 (pants - black, N/A - N/A)     0.0000 (pants - black, N/A - N/A)     0.1555 (pants - black, N/A - N/A)
# Actor (wear - rider)     0.1535 (wear - rider, N/A - N/A)     0.0000 (wear - rider, N/A - N/A)     0.2772 (wear - rider, N/A - N/A)     0.0000 (wear - rider, N/A - N/A)     0.1382 (wear - rider, N/A - N/A)     0.1654 (wear - rider, N/A - N/A)     0.1776 (wear - rider, N/A - N/A)     0.1532 (wear - rider, N/A - N/A)     0.0000 (wear - rider, N/A - N/A)     0.1622 (wear - rider, N/A - N/A)     0.1152 (wear - rider, N/A - N/A)     0.0000 (wear - rider, N/A - N/A)     0.1382 (wear - rider, N/A - N/A)
# Matriz exportada para relation_matrix.csv
# A biker with a blue jacket black pants and a white helmet is driving on dirt and people are watching
# The motocross rider is wearing blue and black pants
# A biker with a blue jacket black pants and a white helmet is driving on dirt and people are watching
#
# The motocross rider is wearing blue and black pants
#
# Theme    of
# Theme    Theme
# Theme    Theme
# Theme    Theme
# Theme    Actor
# Actor    of
# Actor    Theme
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    of
# Actor    Theme
# Actor    Theme
# Actor    Theme
# Actor    Actor
# of    of
# of    Theme
# of    Theme
# of    Theme
# of    Actor
# Theme    of
# Theme    Theme
# Theme    Theme
# Theme    Theme
# Theme    Actor
# Theme    of
# Theme    Theme
# Theme    Theme
# Theme    Theme
# Theme    Actor
# on    of
# on    Theme
# on    Theme
# on    Theme
# on    Actor
# Matriz de Relações:
#      of (N/A - N/A)     Theme (N/A - N/A)     Theme (N/A - N/A)     Theme (N/A - N/A)     Actor (N/A - N/A)
# Theme (pants - blue)     0.3529 (pants - blue, N/A - N/A)     0.2920 (pants - blue, N/A - N/A)     0.8042 (pants - blue, N/A - N/A)     0.7863 (pants - blue, N/A - N/A)     0.1540 (pants - blue, N/A - N/A)
# superset_of (N/A - helmet)     0.0000 (N/A - helmet, N/A - N/A)     0.0000 (N/A - helmet, N/A - N/A)     0.0000 (N/A - helmet, N/A - N/A)     0.0000 (N/A - helmet, N/A - N/A)     0.0000 (N/A - helmet, N/A - N/A)
# Actor (drive - biker)     0.2206 (drive - biker, N/A - N/A)     0.1837 (drive - biker, N/A - N/A)     0.1910 (drive - biker, N/A - N/A)     0.1854 (drive - biker, N/A - N/A)     0.2834 (drive - biker, N/A - N/A)
# Actor (watch - people)     0.1270 (watch - people, N/A - N/A)     0.1337 (watch - people, N/A - N/A)     0.1501 (watch - people, N/A - N/A)     0.1520 (watch - people, N/A - N/A)     0.1687 (watch - people, N/A - N/A)
# of (pants - jacket)     0.4739 (pants - jacket, N/A - N/A)     0.2786 (pants - jacket, N/A - N/A)     0.5902 (pants - jacket, N/A - N/A)     0.5918 (pants - jacket, N/A - N/A)     0.1780 (pants - jacket, N/A - N/A)
# Theme (pants - black)     0.3355 (pants - black, N/A - N/A)     0.3038 (pants - black, N/A - N/A)     0.7921 (pants - black, N/A - N/A)     0.8111 (pants - black, N/A - N/A)     0.1542 (pants - black, N/A - N/A)
# superset_of (N/A - pants)     0.0000 (N/A - pants, N/A - N/A)     0.0000 (N/A - pants, N/A - N/A)     0.0000 (N/A - pants, N/A - N/A)     0.0000 (N/A - pants, N/A - N/A)     0.0000 (N/A - pants, N/A - N/A)
# Theme (helmet - white)     0.3590 (helmet - white, N/A - N/A)     0.2802 (helmet - white, N/A - N/A)     0.7257 (helmet - white, N/A - N/A)     0.7315 (helmet - white, N/A - N/A)     0.1596 (helmet - white, N/A - N/A)
# with (biker - N/A)     0.0000 (biker - N/A, N/A - N/A)     0.0000 (biker - N/A, N/A - N/A)     0.0000 (biker - N/A, N/A - N/A)     0.0000 (biker - N/A, N/A - N/A)     0.0000 (biker - N/A, N/A - N/A)
# on (drive - dirt)     0.1567 (drive - dirt, N/A - N/A)     0.1728 (drive - dirt, N/A - N/A)     0.1707 (drive - dirt, N/A - N/A)     0.1683 (drive - dirt, N/A - N/A)     0.1433 (drive - dirt, N/A - N/A)
# Matriz exportada para relation_matrix.csv
# A female wearing pink gloves and a brown jacket is smiling in the snow
# A young Asian woman with pink gloves is standing in the snow
# A female wearing pink gloves and a brown jacket is smiling in the snow
#
# A young Asian woman with pink gloves is standing in the snow
#
# equality    Theme
# equality    Actor
# equality    Theme
# equality    Theme
# equality    with
# equality    in
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Theme
# Theme    with
# Theme    in
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Theme
# Theme    with
# Theme    in
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Theme
# Theme    with
# Theme    in
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    with
# Actor    in
# in    Theme
# in    Actor
# in    Theme
# in    Theme
# in    with
# in    in
# Matriz de Relações:
#      Theme (N/A - N/A)     Actor (N/A - N/A)     Theme (N/A - N/A)     Theme (N/A - N/A)     with (N/A - N/A)     in (N/A - N/A)
# equality (female - female)     0.5691 (female - female, N/A - N/A)     0.2999 (female - female, N/A - N/A)     0.2999 (female - female, N/A - N/A)     0.2184 (female - female, N/A - N/A)     0.2999 (female - female, N/A - N/A)     0.2191 (female - female, N/A - N/A)
# superset_of (N/A - jacket)     0.0000 (N/A - jacket, N/A - N/A)     0.0000 (N/A - jacket, N/A - N/A)     0.0000 (N/A - jacket, N/A - N/A)     0.0000 (N/A - jacket, N/A - N/A)     0.0000 (N/A - jacket, N/A - N/A)     0.0000 (N/A - jacket, N/A - N/A)
# Actor (smile - N/A)     0.0000 (smile - N/A, N/A - N/A)     0.0000 (smile - N/A, N/A - N/A)     0.0000 (smile - N/A, N/A - N/A)     0.0000 (smile - N/A, N/A - N/A)     0.0000 (smile - N/A, N/A - N/A)     0.0000 (smile - N/A, N/A - N/A)
# Theme (glove - pink)     0.2994 (glove - pink, N/A - N/A)     0.2243 (glove - pink, N/A - N/A)     0.0000 (glove - pink, N/A - N/A)     0.4479 (glove - pink, N/A - N/A)     0.0000 (glove - pink, N/A - N/A)     0.1948 (glove - pink, N/A - N/A)
# Theme (wear - glove)     0.0000 (wear - glove, N/A - N/A)     0.0000 (wear - glove, N/A - N/A)     0.0000 (wear - glove, N/A - N/A)     0.0000 (wear - glove, N/A - N/A)     0.0000 (wear - glove, N/A - N/A)     0.0000 (wear - glove, N/A - N/A)
# superset_of (N/A - female)     0.0000 (N/A - female, N/A - N/A)     0.0000 (N/A - female, N/A - N/A)     0.0000 (N/A - female, N/A - N/A)     0.0000 (N/A - female, N/A - N/A)     0.0000 (N/A - female, N/A - N/A)     0.0000 (N/A - female, N/A - N/A)
# Theme (jacket - brown)     0.6075 (jacket - brown, N/A - N/A)     0.2241 (jacket - brown, N/A - N/A)     0.2982 (jacket - brown, N/A - N/A)     0.3860 (jacket - brown, N/A - N/A)     0.2296 (jacket - brown, N/A - N/A)     0.1700 (jacket - brown, N/A - N/A)
# Actor (female - wear)     0.2999 (female - wear, N/A - N/A)     0.0000 (female - wear, N/A - N/A)     0.2999 (female - wear, N/A - N/A)     0.0000 (female - wear, N/A - N/A)     0.2999 (female - wear, N/A - N/A)     0.0000 (female - wear, N/A - N/A)
# in (smile - snow)     0.1872 (smile - snow, N/A - N/A)     0.2086 (smile - snow, N/A - N/A)     0.0000 (smile - snow, N/A - N/A)     0.1673 (smile - snow, N/A - N/A)     0.0000 (smile - snow, N/A - N/A)     0.4555 (smile - snow, N/A - N/A)
# Matriz exportada para relation_matrix.csv
# A man is drinking orange juice and walking
# A man is spilling orange juice and standing still
# A man is drinking orange juice and walking
#
# A man is spilling orange juice and standing still
#
# of    Manner
# of    of
# of    Actor
# Actor    Manner
# Actor    of
# Actor    Actor
# Matriz de Relações:
#      superset_of (N/A - juice)     Manner (drink - N/A)     superset_of (N/A - walking)     of (juice - orange)     Actor (drink - man)     Theme (drink - N/A)
# superset_of (N/A - juice)     0.0000 (N/A - juice, N/A - juice)     0.0000 (N/A - juice, drink - N/A)     0.0000 (N/A - juice, N/A - walking)     0.0000 (N/A - juice, juice - orange)     0.0000 (N/A - juice, drink - man)     0.0000 (N/A - juice, drink - N/A)
# superset_of (N/A - walking)     0.0000 (N/A - walking, N/A - juice)     0.0000 (N/A - walking, drink - N/A)     0.0000 (N/A - walking, N/A - walking)     0.0000 (N/A - walking, juice - orange)     0.0000 (N/A - walking, drink - man)     0.0000 (N/A - walking, drink - N/A)
# of (juice - orange)     0.0000 (juice - orange, N/A - juice)     0.1770 (juice - orange, drink - N/A)     0.0000 (juice - orange, N/A - walking)     0.9004 (juice - orange, juice - orange)     0.1575 (juice - orange, drink - man)     0.0000 (juice - orange, drink - N/A)
# Actor (drink - man)     0.0000 (drink - man, N/A - juice)     0.1503 (drink - man, drink - N/A)     0.0000 (drink - man, N/A - walking)     0.1308 (drink - man, juice - orange)     0.4680 (drink - man, drink - man)     0.0000 (drink - man, drink - N/A)
# Theme (drink - N/A)     0.0000 (drink - N/A, N/A - juice)     0.0000 (drink - N/A, drink - N/A)     0.0000 (drink - N/A, N/A - walking)     0.0000 (drink - N/A, juice - orange)     0.0000 (drink - N/A, drink - man)     0.0000 (drink - N/A, drink - N/A)
# Matriz exportada para relation_matrix.csv
# A man is drinking orange juice and walking on a sunny day
# There is no man drinking orange juice and walking on a sunny day
# A man is drinking orange juice and walking on a sunny day
#
# There is no man drinking orange juice and walking on a sunny day
#
# Theme    Theme
# Theme    of
# Theme    of
# Theme    of
# of    Theme
# of    of
# of    of
# of    of
# Actor    Theme
# Actor    of
# Actor    of
# Actor    of
# on    Theme
# on    of
# on    of
# on    of
# Matriz de Relações:
#      superset_of (N/A - juice)     Theme (N/A - sunny)     is (N/A - N/A)     superset_of (N/A - walking)     of (juice - orange)     of (juice - day)     of (juice - N/A)     on (N/A - N/A)
# superset_of (N/A - juice)     0.0000 (N/A - juice, N/A - juice)     0.0000 (N/A - juice, N/A - sunny)     0.0000 (N/A - juice, N/A - N/A)     0.0000 (N/A - juice, N/A - walking)     0.0000 (N/A - juice, juice - orange)     0.0000 (N/A - juice, juice - day)     0.0000 (N/A - juice, juice - N/A)     0.0000 (N/A - juice, N/A - N/A)
# Theme (day - sunny)     0.0000 (day - sunny, N/A - juice)     0.9650 (day - sunny, N/A - sunny)     0.0000 (day - sunny, N/A - N/A)     0.0000 (day - sunny, N/A - walking)     0.3725 (day - sunny, juice - orange)     0.3963 (day - sunny, juice - day)     0.3890 (day - sunny, juice - N/A)     0.0000 (day - sunny, N/A - N/A)
# superset_of (N/A - walking)     0.0000 (N/A - walking, N/A - juice)     0.0000 (N/A - walking, N/A - sunny)     0.0000 (N/A - walking, N/A - N/A)     0.0000 (N/A - walking, N/A - walking)     0.0000 (N/A - walking, juice - orange)     0.0000 (N/A - walking, juice - day)     0.0000 (N/A - walking, juice - N/A)     0.0000 (N/A - walking, N/A - N/A)
# of (juice - orange)     0.0000 (juice - orange, N/A - juice)     0.3562 (juice - orange, N/A - sunny)     0.0000 (juice - orange, N/A - N/A)     0.0000 (juice - orange, N/A - walking)     0.6602 (juice - orange, juice - orange)     0.7599 (juice - orange, juice - day)     0.9588 (juice - orange, juice - N/A)     0.0000 (juice - orange, N/A - N/A)
# Actor (drink - man)     0.0000 (drink - man, N/A - juice)     0.2023 (drink - man, N/A - sunny)     0.0000 (drink - man, N/A - N/A)     0.0000 (drink - man, N/A - walking)     0.3012 (drink - man, juice - orange)     0.1920 (drink - man, juice - day)     0.1510 (drink - man, juice - N/A)     0.0000 (drink - man, N/A - N/A)
# Theme (drink - N/A)     0.0000 (drink - N/A, N/A - juice)     0.0000 (drink - N/A, N/A - sunny)     0.0000 (drink - N/A, N/A - N/A)     0.0000 (drink - N/A, N/A - walking)     0.0000 (drink - N/A, juice - orange)     0.0000 (drink - N/A, juice - day)     0.0000 (drink - N/A, juice - N/A)     0.0000 (drink - N/A, N/A - N/A)
# ...
# with (jump - ball)     0.2038 (jump - ball, dog - brown)     0.0000 (jump - ball, mouth - thing)     0.1749 (jump - ball, dog - white)     0.2269 (jump - ball, jump - dog)     0.2728 (jump - ball, ball - tennis)     0.1995 (jump - ball, jump - air)     0.4808 (jump - ball, air - ball)     0.1981 (jump - ball, ball - mouth)
# in (ball - mouth)     0.3988 (ball - mouth, dog - brown)     0.1981 (ball - mouth, mouth - thing)     0.3821 (ball - mouth, dog - white)     0.2211 (ball - mouth, jump - dog)     0.5468 (ball - mouth, ball - tennis)     0.2210 (ball - mouth, jump - air)     0.4068 (ball - mouth, air - ball)     0.9503 (ball - mouth, ball - mouth)
# Matriz exportada para relation_matrix.csv
# A dog is catching a ball in mid air
# A brown and white dog is resting on the ground with a tennis ball in its mouth
# A dog is catching a ball in mid air
#
# A brown and white dog is resting on the ground with a tennis ball in its mouth
#
# Theme    Theme
# Theme    of
# Theme    Theme
# Theme    Actor
# Theme    of
# Theme    on
# Theme    with
# Theme    in
# Actor    Theme
# Actor    of
# Actor    Theme
# Actor    Actor
# Actor    of
# Actor    on
# Actor    with
# Actor    in
# Theme    Theme
# Theme    of
# Theme    Theme
# Theme    Actor
# Theme    of
# Theme    on
# Theme    with
# Theme    in
# in    Theme
# in    of
# in    Theme
# in    Actor
# in    of
# in    on
# in    with
# in    in
# Matriz de Relações:
#      Theme (dog - mid)     of (N/A - N/A)     Theme (dog - N/A)     Actor (catch - dog)     of (air - N/A)     on (catch - ball)     with (ball - air)     in (air - N/A)
# Theme (air - mid)     0.4181 (air - mid, dog - mid)     0.1916 (air - mid, N/A - N/A)     0.3896 (air - mid, dog - N/A)     0.1408 (air - mid, catch - dog)     0.3171 (air - mid, air - N/A)     0.1328 (air - mid, catch - ball)     0.3362 (air - mid, ball - air)     0.3172 (air - mid, air - N/A)
# Actor (catch - dog)     0.2509 (catch - dog, dog - mid)     0.0000 (catch - dog, N/A - N/A)     0.2129 (catch - dog, dog - N/A)     0.3941 (catch - dog, catch - dog)     0.1955 (catch - dog, air - N/A)     0.1979 (catch - dog, catch - ball)     0.1904 (catch - dog, ball - air)     0.1584 (catch - dog, air - N/A)
# Theme (catch - ball)     0.2965 (catch - ball, dog - mid)     0.0000 (catch - ball, N/A - N/A)     0.2388 (catch - ball, dog - N/A)     0.2413 (catch - ball, catch - dog)     0.2268 (catch - ball, air - N/A)     0.2007 (catch - ball, catch - ball)     0.2668 (catch - ball, ball - air)     0.1743 (catch - ball, air - N/A)
# in (ball - air)     0.3939 (ball - air, dog - mid)     0.1743 (ball - air, N/A - N/A)     0.3915 (ball - air, dog - N/A)     0.1720 (ball - air, catch - dog)     0.3963 (ball - air, air - N/A)     0.1933 (ball - air, catch - ball)     0.3661 (ball - air, ball - air)     0.5953 (ball - air, air - N/A)
# Matriz exportada para relation_matrix.csv
# A brown and white dog is jumping in the air with a tennis ball in its mouth
# A ball is being caught by a dog in mid air
# A brown and white dog is jumping in the air with a tennis ball in its mouth
#
# A ball is being caught by a dog in mid air
#
# Theme    Theme
# Theme    Theme
# Theme    Actor
# Theme    in
# of    Theme
# of    Theme
# of    Actor
# of    in
# of    Theme
# of    Theme
# of    Actor
# of    in
# Theme    Theme
# Theme    Theme
# Theme    Actor
# Theme    in
# Actor    Theme
# Actor    Theme
# Actor    Actor
# Actor    in
# in    Theme
# in    Theme
# in    Actor
# in    in
# with    Theme
# with    Theme
# with    Actor
# with    in
# in    Theme
# in    Theme
# in    Actor
# in    in
# Matriz de Relações:
#      Theme (jump - dog)     Theme (ball - brown)     Actor (jump - air)     in (air - ball)
# Theme (dog - brown)     0.3051 (dog - brown, jump - dog)     0.4710 (dog - brown, ball - brown)     0.2606 (dog - brown, jump - air)     0.4796 (dog - brown, air - ball)
# of (ball - tennis)     0.2413 (ball - tennis, jump - dog)     0.3346 (ball - tennis, ball - brown)     0.2219 (ball - tennis, jump - air)     0.3589 (ball - tennis, air - ball)
# of (mouth - thing)     0.0000 (mouth - thing, jump - dog)     0.2296 (mouth - thing, ball - brown)     0.0000 (mouth - thing, jump - air)     0.2045 (mouth - thing, air - ball)
# Theme (dog - white)     0.2333 (dog - white, jump - dog)     0.4426 (dog - white, ball - brown)     0.2190 (dog - white, jump - air)     0.4741 (dog - white, air - ball)
# Actor (jump - dog)     0.2365 (jump - dog, jump - dog)     0.1632 (jump - dog, ball - brown)     0.4020 (jump - dog, jump - air)     0.1956 (jump - dog, air - ball)
# in (jump - air)     0.1981 (jump - air, jump - dog)     0.1941 (jump - air, ball - brown)     0.2099 (jump - air, jump - air)     0.3948 (jump - air, air - ball)
# with (jump - ball)     0.2740 (jump - ball, jump - dog)     0.1391 (jump - ball, ball - brown)     0.2171 (jump - ball, jump - air)     0.1774 (jump - ball, air - ball)
# in (ball - mouth)     0.1893 (ball - mouth, jump - dog)     0.3484 (ball - mouth, ball - brown)     0.2045 (ball - mouth, jump - air)     0.5800 (ball - mouth, air - ball)
# Matriz exportada para relation_matrix.csv
# A brown and white dog is jumping in the air with a tennis ball in its mouth
# A dog is missing the ball in mid air
# A brown and white dog is jumping in the air with a tennis ball in its mouth
#
# A dog is missing the ball in mid air
#
# Theme    Actor
# Theme    Theme
# Theme    Theme
# Theme    in
# of    Actor
# of    Theme
# of    Theme
# of    in
# of    Actor
# of    Theme
# of    Theme
# of    in
# Theme    Actor
# Theme    Theme
# Theme    Theme
# Theme    in
# Actor    Actor
# Actor    Theme
# Actor    Theme
# Actor    in
# in    Actor
# in    Theme
# in    Theme
# in    in
# with    Actor
# with    Theme
# with    Theme
# with    in
# in    Actor
# in    Theme
# in    Theme
# in    in
# Matriz de Relações:
#      Actor (jump - dog)     Theme (jump - air)     Theme (ball - brown)     in (jump - ball)
# Theme (dog - brown)     0.2589 (dog - brown, jump - dog)     0.2745 (dog - brown, jump - air)     0.4643 (dog - brown, ball - brown)     0.1811 (dog - brown, jump - ball)
# of (ball - tennis)     0.1987 (ball - tennis, jump - dog)     0.2112 (ball - tennis, jump - air)     0.3480 (ball - tennis, ball - brown)     0.1490 (ball - tennis, jump - ball)
# of (mouth - thing)     0.0000 (mouth - thing, jump - dog)     0.0000 (mouth - thing, jump - air)     0.2196 (mouth - thing, ball - brown)     0.0000 (mouth - thing, jump - ball)
# Theme (dog - white)     0.2185 (dog - white, jump - dog)     0.2396 (dog - white, jump - air)     0.4341 (dog - white, ball - brown)     0.1725 (dog - white, jump - ball)
# Actor (jump - dog)     0.3934 (jump - dog, jump - dog)     0.2246 (jump - dog, jump - air)     0.1565 (jump - dog, ball - brown)     0.1898 (jump - dog, jump - ball)
# in (jump - air)     0.1859 (jump - air, jump - dog)     0.2249 (jump - air, jump - air)     0.1871 (jump - air, ball - brown)     0.3805 (jump - air, jump - ball)
# with (jump - ball)     0.1900 (jump - ball, jump - dog)     0.2696 (jump - ball, jump - air)     0.1483 (jump - ball, ball - brown)     0.1855 (jump - ball, jump - ball)
# in (ball - mouth)     0.1767 (ball - mouth, jump - dog)     0.1955 (ball - mouth, jump - air)     0.3522 (ball - mouth, ball - brown)     0.2852 (ball - mouth, jump - ball)
# Matriz exportada para relation_matrix.csv
# A brown and white dog is jumping in the air with a tennis ball in its mouth
# A dog is caught mid air with a ball
# A brown and white dog is jumping in the air with a tennis ball in its mouth
#
# A dog is caught mid air with a ball
#
# Theme    Theme
# Theme    mid
# Theme    with
# of    Theme
# of    mid
# of    with
# of    Theme
# of    mid
# of    with
# Theme    Theme
# Theme    mid
# Theme    with
# Actor    Theme
# Actor    mid
# Actor    with
# in    Theme
# in    mid
# in    with
# with    Theme
# with    mid
# with    with
# in    Theme
# in    mid
# in    with
# Matriz de Relações:
#      Theme (jump - dog)     mid (jump - air)     with (air - ball)
# Theme (dog - brown)     0.3472 (dog - brown, jump - dog)     0.1887 (dog - brown, jump - air)     0.4312 (dog - brown, air - ball)
# of (ball - tennis)     0.2153 (ball - tennis, jump - dog)     0.1450 (ball - tennis, jump - air)     0.4415 (ball - tennis, air - ball)
# of (mouth - thing)     0.0000 (mouth - thing, jump - dog)     0.0000 (mouth - thing, jump - air)     0.2081 (mouth - thing, air - ball)
# Theme (dog - white)     0.2911 (dog - white, jump - dog)     0.1836 (dog - white, jump - air)     0.3844 (dog - white, air - ball)
# Actor (jump - dog)     0.3200 (jump - dog, jump - dog)     0.2031 (jump - dog, jump - air)     0.2397 (jump - dog, air - ball)
# in (jump - air)     0.2057 (jump - air, jump - dog)     0.2844 (jump - air, jump - air)     0.2131 (jump - air, air - ball)
# with (jump - ball)     0.2116 (jump - ball, jump - dog)     0.1869 (jump - ball, jump - air)     0.3725 (jump - ball, air - ball)
# in (ball - mouth)     0.1938 (ball - mouth, jump - dog)     0.2027 (ball - mouth, jump - air)     0.3996 (ball - mouth, air - ball)
# Matriz exportada para relation_matrix.csv
# A woman is speaking loudly on her cell phone and is keeping a purse and a yellow bag on the near ledge
# A woman is speaking on her cell phone and is keeping a purse and a yellow bag on the near ledge
# A woman is speaking loudly on her cell phone and is keeping a purse and a yellow bag on the near ledge
#
# A woman is speaking on her cell phone and is keeping a purse and a yellow bag on the near ledge
#
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Actor
# Theme    of
# Theme    of
# Theme    on
# Theme    on
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Actor
# Actor    of
# Actor    of
# Actor    on
# Actor    on
# Actor    Theme
# Actor    Actor
# Actor    Theme
# Actor    Actor
# Actor    of
# Actor    of
# Actor    on
# Actor    on
# Theme    Theme
# Theme    Actor
# Theme    Theme
# Theme    Actor
# Theme    of
# Theme    of
# Theme    on
# Theme    on
# Manner    Theme
# Manner    Actor
# Manner    Theme
# Manner    Actor
# Manner    of
# Manner    of
# Manner    on
# Manner    on
# of    Theme
# of    Actor
# of    Theme
# of    Actor
# of    of
# of    of
# of    on
# of    on
# of    Theme
# of    Actor
# of    Theme
# of    Actor
# of    of
# of    of
# of    on
# of    on
# on    Theme
# on    Actor
# on    Theme
# on    Actor
# on    of
# on    of
# on    on
# on    on
# on    Theme
# on    Actor
# on    Theme
# on    Actor
# on    of
# on    of
# on    on
# on    on
# Matriz de Relações:
#      superset_of (N/A - purse)     Theme (bag - loud)     superset_of (N/A - bag)     Actor (keep - woman)     Theme (keep - N/A)     Theme (ledge - yellow)     Actor (speak - woman)     of (phone - female)     of (phone - cell)     on (speak - phone)     on (keep - ledge)
# superset_of (N/A - purse)     0.0000 (N/A - purse, N/A - purse)     0.0000 (N/A - purse, bag - loud)     0.0000 (N/A - purse, N/A - bag)     0.0000 (N/A - purse, keep - woman)     0.0000 (N/A - purse, keep - N/A)     0.0000 (N/A - purse, ledge - yellow)     0.0000 (N/A - purse, speak - woman)     0.0000 (N/A - purse, phone - female)     0.0000 (N/A - purse, phone - cell)     0.0000 (N/A - purse, speak - phone)     0.0000 (N/A - purse, keep - ledge)
# Theme (bag - yellow)     0.0000 (bag - yellow, N/A - purse)     0.9933 (bag - yellow, bag - loud)     0.0000 (bag - yellow, N/A - bag)     0.2107 (bag - yellow, keep - woman)     0.0000 (bag - yellow, keep - N/A)     0.6341 (bag - yellow, ledge - yellow)     0.2107 (bag - yellow, speak - woman)     0.2568 (bag - yellow, phone - female)     0.4921 (bag - yellow, phone - cell)     0.2041 (bag - yellow, speak - phone)     0.2180 (bag - yellow, keep - ledge)
# superset_of (N/A - bag)     0.0000 (N/A - bag, N/A - purse)     0.0000 (N/A - bag, bag - loud)     0.0000 (N/A - bag, N/A - bag)     0.0000 (N/A - bag, keep - woman)     0.0000 (N/A - bag, keep - N/A)     0.0000 (N/A - bag, ledge - yellow)     0.0000 (N/A - bag, speak - woman)     0.0000 (N/A - bag, phone - female)     0.0000 (N/A - bag, phone - cell)     0.0000 (N/A - bag, speak - phone)     0.0000 (N/A - bag, keep - ledge)
# Actor (keep - woman)     0.0000 (keep - woman, N/A - purse)     0.2044 (keep - woman, bag - loud)     0.0000 (keep - woman, N/A - bag)     0.4960 (keep - woman, keep - woman)     0.0000 (keep - woman, keep - N/A)     0.1846 (keep - woman, ledge - yellow)     0.4960 (keep - woman, speak - woman)     0.0000 (keep - woman, phone - female)     0.1971 (keep - woman, phone - cell)     0.2129 (keep - woman, speak - phone)     0.1979 (keep - woman, keep - ledge)
# Actor (speak - woman)     0.0000 (speak - woman, N/A - purse)     0.2044 (speak - woman, bag - loud)     0.0000 (speak - woman, N/A - bag)     0.4960 (speak - woman, keep - woman)     0.0000 (speak - woman, keep - N/A)     0.1846 (speak - woman, ledge - yellow)     0.4960 (speak - woman, speak - woman)     0.0000 (speak - woman, phone - female)     0.1971 (speak - woman, phone - cell)     0.2129 (speak - woman, speak - phone)     0.1979 (speak - woman, keep - ledge)
# Theme (keep - N/A)     0.0000 (keep - N/A, N/A - purse)     0.0000 (keep - N/A, bag - loud)     0.0000 (keep - N/A, N/A - bag)     0.0000 (keep - N/A, keep - woman)     0.0000 (keep - N/A, keep - N/A)     0.0000 (keep - N/A, ledge - yellow)     0.0000 (keep - N/A, speak - woman)     0.0000 (keep - N/A, phone - female)     0.0000 (keep - N/A, phone - cell)     0.0000 (keep - N/A, speak - phone)     0.0000 (keep - N/A, keep - ledge)
# Theme (ledge - near)     0.0000 (ledge - near, N/A - purse)     0.6288 (ledge - near, bag - loud)     0.0000 (ledge - near, N/A - bag)     0.1824 (ledge - near, keep - woman)     0.0000 (ledge - near, keep - N/A)     0.9927 (ledge - near, ledge - yellow)     0.1824 (ledge - near, speak - woman)     0.2314 (ledge - near, phone - female)     0.4531 (ledge - near, phone - cell)     0.1834 (ledge - near, speak - phone)     0.2525 (ledge - near, keep - ledge)
# Manner (speak - loud)     0.0000 (speak - loud, N/A - purse)     0.0000 (speak - loud, bag - loud)     0.0000 (speak - loud, N/A - bag)     0.0000 (speak - loud, keep - woman)     0.0000 (speak - loud, keep - N/A)     0.0000 (speak - loud, ledge - yellow)     0.0000 (speak - loud, speak - woman)     0.0000 (speak - loud, phone - female)     0.0000 (speak - loud, phone - cell)     0.0000 (speak - loud, speak - phone)     0.0000 (speak - loud, keep - ledge)
# of (phone - female)     0.0000 (phone - female, N/A - purse)     0.2475 (phone - female, bag - loud)     0.0000 (phone - female, N/A - bag)     0.0000 (phone - female, keep - woman)     0.0000 (phone - female, keep - N/A)     0.2201 (phone - female, ledge - yellow)     0.0000 (phone - female, speak - woman)     0.4943 (phone - female, phone - female)     0.4943 (phone - female, phone - cell)     0.0000 (phone - female, speak - phone)     0.0000 (phone - female, keep - ledge)
# of (phone - cell)     0.0000 (phone - cell, N/A - purse)     0.4714 (phone - cell, bag - loud)     0.0000 (phone - cell, N/A - bag)     0.1918 (phone - cell, keep - woman)     0.0000 (phone - cell, keep - N/A)     0.4384 (phone - cell, ledge - yellow)     0.1918 (phone - cell, speak - woman)     0.4943 (phone - cell, phone - female)     0.9896 (phone - cell, phone - cell)     0.2476 (phone - cell, speak - phone)     0.1965 (phone - cell, keep - ledge)
# on (speak - phone)     0.0000 (speak - phone, N/A - purse)     0.1875 (speak - phone, bag - loud)     0.0000 (speak - phone, N/A - bag)     0.2046 (speak - phone, keep - woman)     0.0000 (speak - phone, keep - N/A)     0.1750 (speak - phone, ledge - yellow)     0.2046 (speak - phone, speak - woman)     0.0000 (speak - phone, phone - female)     0.2481 (speak - phone, phone - cell)     0.4943 (speak - phone, speak - phone)     0.2859 (speak - phone, keep - ledge)
# on (keep - ledge)     0.0000 (keep - ledge, N/A - purse)     0.2147 (keep - ledge, bag - loud)     0.0000 (keep - ledge, N/A - bag)     0.1946 (keep - ledge, keep - woman)     0.0000 (keep - ledge, keep - N/A)     0.2560 (keep - ledge, ledge - yellow)     0.1946 (keep - ledge, speak - woman)     0.0000 (keep - ledge, phone - female)     0.2022 (keep - ledge, phone - cell)     0.3005 (keep - ledge, speak - phone)     0.4961 (keep - ledge, keep - ledge)
# Matriz exportada para relation_matrix.csv

# %%
similarities
# Out:
# [0.5706433539451308,
#  0.1950057793303372,
#  0.19047601896822441,
#  0.20852013274936357,
#  0.5536224646017605,
#  0.4479130980174013,
#  0.49474977026946526,
#  0.5449232575981887,
#  0.7015375946968232,
#  0.7569878874233134,
#  0.22597328181611961,
#  0.2613835288567886,
#  0.22352536923540256,
#  0.23073200470008975,
#  0.7323624163624558,
#  0.4220656598666743,
#  0.7012792720561727,
#  0.5051043754752965,
#  0.5221841220217773,
#  0.4426766807398266,
#  0.5996515837900438,
#  0.7312632378371235,
#  0.6393445402520442,
#  0.5667723130782167,
#  0.6102863641840157,
#  0.45987445416602124,
#  0.31206942375033864,
#  0.633013080751544,
#  0.4870795077443987,
#  0.49738496892365963,
#  0.5608288908510116,
#  0.6364502611697247,
#  0.387098622131071,
#  0.42401625656006675,
#  0.44179075513815547,
#  0.31934814803539435,
#  0.2483593215588641,
#  0.2651725453552233,
#  0.41817306013843253,
#  0.2644285746798459,
#  0.2540530949710261,
#  0.27588807308787155,
#  0.6122739316172469,
#  0.6197205933991702,
#  0.6430434085331533,
#  0.5024300199510765,
#  0.44712181367680986,
#  0.8151276537470835,
#  0.5685420694265292,
#  0.560688037185793,
#  0.36529872362661364,
#  0.5722238074181639,
#  0.6563174108569885,
#  0.6736910864080419,
#  0.567569523241295,
#  0.6600911159804389,
#  0.5502617116962949,
#  0.39692448497016775,
#  0.39346731585270833,
#  0.29421265754821285,
#  0.5457745446516113,
#  0.5651934241145709,
#  0.7385707862091242,
#  0.3896570605039548,
#  0.6045362904121503,
#  0.6508641278626615,
#  0.6523605906313567,
#  0.6176246825476219,
#  0.4192917584057854,
#  0.4267137635988374,
#  0.397041149134221,
#  0.744421940127891,
#  0.2774274221494504,
#  0.2186144282787474,
#  0.49220775470824324,
#  0.2654757620882205,
#  0.6132329400771398,
#  0.5444389722638372,
#  0.45627727979204896,
#  0.5429979963022489,
#  0.4087352295463027,
#  0.3970309901783774,
#  0.7406962805758696,
#  0.426225652325388,
#  0.45387660348523956,
#  0.50977497870902,
#  0.5183791511587699,
#  0.7331333865531426,
#  0.7003595105843368,
#  0.5099815785854325,
#  0.2886297205353503,
#  0.3063891341281716,
#  0.5687252108113461,
#  0.40249823629891346,
#  0.6595390317604222,
#  0.4428542141766586,
#  0.4589561258343081,
#  0.3706177144259081,
#  0.3417800168919447,
#  0.681564210823647]

# %%
from scipy import stats
from sklearn.metrics import accuracy_score, precision_score
# Função para converter para binário com arredondamento especial
def convert_to_binary_rounded(similarity):
    if similarity >= 0.45:  # Se for 0.45 ou maior, arredonda para 1
        return 1
    return 0

# Recalcula as predições binárias
binary_predictions_rounded = [convert_to_binary_rounded(sim) for sim in similarities]

# Adiciona as colunas ao DataFrame
df['Similarity'] = similarities
df['Prediction'] = binary_predictions_rounded  # Usa as novas predições

# Calcula as métricas com os novos valores
pearson_corr, _ = stats.pearsonr(similarities, df['Quality'])
spearman_corr, _ = stats.spearmanr(similarities, df['Quality'])
accuracy = accuracy_score(df['Quality'], binary_predictions_rounded)
precision = precision_score(df['Quality'], binary_predictions_rounded)

# Imprime os resultados
print("Resultados com arredondamento especial (>=0.45 -> 1):")
print(f"Correlação de Pearson: {pearson_corr:.4f}")
print(f"Correlação de Spearman: {spearman_corr:.4f}")
print(f"Acurácia: {accuracy:.4f}")
print(f"Precisão: {precision:.4f}")

# Imprime uma comparação das predições
print("\nComparação de algumas predições:")
comparison_df = pd.DataFrame({
    'Similarity': similarities,
    'Original_Binary': binary_predictions,
    'Rounded_Binary': binary_predictions_rounded,
    'Ground_Truth': df['Quality']
}).head(10)
print(comparison_df)

# Salva os resultados
df.to_csv('/content/CANDC/sick_evaluation_results_rounded.csv', index=False)
# Out:
# Resultados com arredondamento especial (>=0.45 -> 1):
# Correlação de Pearson: 0.4336
# Correlação de Spearman: 0.4282
# Acurácia: 0.6600
# Precisão: 0.7069
#
# Comparação de algumas predições:
#    Similarity  Original_Binary  Rounded_Binary  Ground_Truth
# 0    0.570643                1               1             1
# 1    0.195006                0               0             0
# 2    0.190476                0               0             0
# 3    0.208520                0               0             0
# 4    0.553622                1               1             1
# 5    0.447913                0               0             1
# 6    0.494750                0               1             1
# 7    0.544923                1               1             0
# 8    0.701538                1               1             1
# 9    0.756988                1               1             1
